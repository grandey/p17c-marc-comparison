# %% [markdown]
# # budget_cdo_nco_draft2017b.ipynb
#
# ## Purpose
# Use CDO and NCO to post-process MARC aerosol budget data from project [p17c-marc-comparison](https://github.com/grandey/p17c-marc-comparison).
#
# ## Requirements
# - Climate Data Operators (CDO)
# - NetCDF Operators (NCO)
# - CESM output data, post-processed to time-series format, as described in [data_management.org](https://github.com/grandey/p17c-marc-comparison/blob/master/manage_data/data_management.org#syncing-to-local-machine-for-analysis). These data are archived at https://doi.org/10.6084/m9.figshare.5687812.
#
# ## Author
# Benjamin S. Grandey, 2018
#
# ## Acknowledgments
# Thanks are due to **Alex Avramov**.  The interpretation of the diagnostics are informed by *print_MARC_budget_Benjamin.pro*, an IDL script written by Alex Avramov.

# %%
! date
# Out:
# Fri Aug 17 15:17:50 +08 2018

# %%
from glob import glob
import os
import re
import shutil

# %% [markdown]
# ## CDO and NCO version information

# %%
! cdo --version
! ncks --version
# Out:
# Climate Data Operators version 1.9.1 (http://mpimet.mpg.de/cdo)
# Compiled: by root on squall2.local (x86_64-apple-darwin17.2.0) Nov  2 2017 18:28:19
# CXX Compiler: /usr/bin/clang++ -std=gnu++11 -pipe -Os -stdlib=libc++ -arch x86_64  -D_THREAD_SAFE -pthread
# CXX version : unknown
# C Compiler: /usr/bin/clang -pipe -Os -arch x86_64  -D_THREAD_SAFE -pthread
# C version : unknown
# Features: DATA PTHREADS HDF5 NC4/HDF5 OPeNDAP SZ UDUNITS2 PROJ.4 CURL FFTW3 SSE4_1
# Libraries: HDF5/1.10.1 proj/4.93 curl/7.56.1
# Filetypes: srv ext ieg grb1 nc1 nc2 nc4 nc4c nc5
#      CDI library version : 1.9.1 of Nov  2 2017 18:27:49
#  CGRIBEX library version : 1.9.0 of Sep 29 2017 10:16:02
#   NetCDF library version : 4.4.1.1 of Oct  6 2017 14:14:42 $
#     HDF5 library version : 1.10.1
#  SERVICE library version : 1.4.0 of Nov  2 2017 18:27:47
#    EXTRA library version : 1.4.0 of Nov  2 2017 18:27:46
#      IEG library version : 1.4.0 of Nov  2 2017 18:27:46
#     FILE library version : 1.8.3 of Nov  2 2017 18:27:46
#
# NCO netCDF Operators version 4.6.6 built by root on squall2.local at Nov  3 2017 12:13:40
# ncks version 4.6.6

# %% [markdown]
# ## Directory locations for input and output NetCDF files
# The data in the input directory (*in_dir*) are available via Figshare: https://doi.org/10.6084/m9.figshare.5687812.

# %%
# Input data directory
in_dir = os.path.expandvars('$HOME/data/figshare/figshare5687812/')
#in_dir = os.path.expandvars('$HOME/data/projects/p17c_marc_comparison/output_timeseries/')

# Output data directory
out_dir = os.path.expandvars('$HOME/data/projects/p17c_marc_comparison/budget_cdo_nco_draft2017b/')

# %% [markdown]
# ## Clean output data directory

# %%
for filename in glob('{}/*.nc'.format(out_dir)):
    print('Deleting {}'.format(filename.split('/')[-1]))
    os.remove(filename)
for filename in glob('{}/*.nco'.format(out_dir)):
    print('Deleting {}'.format(filename.split('/')[-1]))
    os.remove(filename)
for filename in glob('{}/*.tmp'.format(out_dir)):
    print('Deleting {}'.format(filename.split('/')[-1]))
    os.remove(filename)
! date
# Out:
# Fri Aug 17 15:17:50 +08 2018

# %% [markdown]
# ## Calculate annual means of standard MARC 2D diagnostic variables

# %%
variable_list = ['mOCSF', 'mBCSF',  # surface emissions
                 'DST01SF', 'DST02SF', 'DST03SF', 'DST04SF',
                 'SSLT01SF', 'SSLT02SF', 'SSLT03SF', 'SSLT04SF',
                 'mACCDRY', 'mAITDRY', 'mNUCDRY',  # dry deposition
                 'mOCDRY', 'mMOSDRY', 'mOIMDRY', 'mBCDRY', 'mMBSDRY', 'mBIMDRY',
                 'DST01DD', 'DST02DD', 'DST03DD', 'DST04DD',
                 'SSLT01DD', 'SSLT02DD', 'SSLT03DD', 'SSLT04DD'
                ]
for variable in variable_list:
    for year in ['2000', '1850']:
        # Check if input file exists
        in_filename = '{}/p17c_marc_s2_{}.cam.h0.{}.nc'.format(in_dir, year, variable)
        if os.path.isfile(in_filename):
            print('{}, marc_s2, {}'.format(variable, year))
            # Calculate annual means using NCO (with years starting in January)
            annual_filename = '{}/marc_s2_{}_{}_ANN.nc'.format(out_dir, year, variable)
            ! ncra -O --mro -d time,,,12,12 {in_filename} {annual_filename}
            print('  Written {}'.format(annual_filename.split('/')[-1]))
! date
# Out:
# mOCSF, marc_s2, 2000
#   Written marc_s2_2000_mOCSF_ANN.nc
# mOCSF, marc_s2, 1850
#   Written marc_s2_1850_mOCSF_ANN.nc
# mBCSF, marc_s2, 2000
#   Written marc_s2_2000_mBCSF_ANN.nc
# mBCSF, marc_s2, 1850
#   Written marc_s2_1850_mBCSF_ANN.nc
# DST01SF, marc_s2, 2000
#   Written marc_s2_2000_DST01SF_ANN.nc
# DST01SF, marc_s2, 1850
#   Written marc_s2_1850_DST01SF_ANN.nc
# DST02SF, marc_s2, 2000
#   Written marc_s2_2000_DST02SF_ANN.nc
# DST02SF, marc_s2, 1850
#   Written marc_s2_1850_DST02SF_ANN.nc
# DST03SF, marc_s2, 2000
#   Written marc_s2_2000_DST03SF_ANN.nc
# DST03SF, marc_s2, 1850
#   Written marc_s2_1850_DST03SF_ANN.nc
# DST04SF, marc_s2, 2000
#   Written marc_s2_2000_DST04SF_ANN.nc
# DST04SF, marc_s2, 1850
#   Written marc_s2_1850_DST04SF_ANN.nc
# SSLT01SF, marc_s2, 2000
#   Written marc_s2_2000_SSLT01SF_ANN.nc
# SSLT01SF, marc_s2, 1850
#   Written marc_s2_1850_SSLT01SF_ANN.nc
# SSLT02SF, marc_s2, 2000
#   Written marc_s2_2000_SSLT02SF_ANN.nc
# SSLT02SF, marc_s2, 1850
#   Written marc_s2_1850_SSLT02SF_ANN.nc
# SSLT03SF, marc_s2, 2000
#   Written marc_s2_2000_SSLT03SF_ANN.nc
# SSLT03SF, marc_s2, 1850
#   Written marc_s2_1850_SSLT03SF_ANN.nc
# SSLT04SF, marc_s2, 2000
#   Written marc_s2_2000_SSLT04SF_ANN.nc
# SSLT04SF, marc_s2, 1850
#   Written marc_s2_1850_SSLT04SF_ANN.nc
# mACCDRY, marc_s2, 2000
#   Written marc_s2_2000_mACCDRY_ANN.nc
# mACCDRY, marc_s2, 1850
#   Written marc_s2_1850_mACCDRY_ANN.nc
# mAITDRY, marc_s2, 2000
#   Written marc_s2_2000_mAITDRY_ANN.nc
# mAITDRY, marc_s2, 1850
#   Written marc_s2_1850_mAITDRY_ANN.nc
# mNUCDRY, marc_s2, 2000
#   Written marc_s2_2000_mNUCDRY_ANN.nc
# mNUCDRY, marc_s2, 1850
#   Written marc_s2_1850_mNUCDRY_ANN.nc
# mOCDRY, marc_s2, 2000
#   Written marc_s2_2000_mOCDRY_ANN.nc
# mOCDRY, marc_s2, 1850
#   Written marc_s2_1850_mOCDRY_ANN.nc
# mMOSDRY, marc_s2, 2000
#   Written marc_s2_2000_mMOSDRY_ANN.nc
# mMOSDRY, marc_s2, 1850
#   Written marc_s2_1850_mMOSDRY_ANN.nc
# mOIMDRY, marc_s2, 2000
#   Written marc_s2_2000_mOIMDRY_ANN.nc
# mOIMDRY, marc_s2, 1850
#   Written marc_s2_1850_mOIMDRY_ANN.nc
# mBCDRY, marc_s2, 2000
#   Written marc_s2_2000_mBCDRY_ANN.nc
# mBCDRY, marc_s2, 1850
#   Written marc_s2_1850_mBCDRY_ANN.nc
# mMBSDRY, marc_s2, 2000
#   Written marc_s2_2000_mMBSDRY_ANN.nc
# mMBSDRY, marc_s2, 1850
#   Written marc_s2_1850_mMBSDRY_ANN.nc
# mBIMDRY, marc_s2, 2000
#   Written marc_s2_2000_mBIMDRY_ANN.nc
# mBIMDRY, marc_s2, 1850
#   Written marc_s2_1850_mBIMDRY_ANN.nc
# DST01DD, marc_s2, 2000
#   Written marc_s2_2000_DST01DD_ANN.nc
# DST01DD, marc_s2, 1850
#   Written marc_s2_1850_DST01DD_ANN.nc
# DST02DD, marc_s2, 2000
#   Written marc_s2_2000_DST02DD_ANN.nc
# DST02DD, marc_s2, 1850
#   Written marc_s2_1850_DST02DD_ANN.nc
# DST03DD, marc_s2, 2000
#   Written marc_s2_2000_DST03DD_ANN.nc
# DST03DD, marc_s2, 1850
#   Written marc_s2_1850_DST03DD_ANN.nc
# DST04DD, marc_s2, 2000
#   Written marc_s2_2000_DST04DD_ANN.nc
# DST04DD, marc_s2, 1850
#   Written marc_s2_1850_DST04DD_ANN.nc
# SSLT01DD, marc_s2, 2000
#   Written marc_s2_2000_SSLT01DD_ANN.nc
# SSLT01DD, marc_s2, 1850
#   Written marc_s2_1850_SSLT01DD_ANN.nc
# SSLT02DD, marc_s2, 2000
#   Written marc_s2_2000_SSLT02DD_ANN.nc
# SSLT02DD, marc_s2, 1850
#   Written marc_s2_1850_SSLT02DD_ANN.nc
# SSLT03DD, marc_s2, 2000
#   Written marc_s2_2000_SSLT03DD_ANN.nc
# SSLT03DD, marc_s2, 1850
#   Written marc_s2_1850_SSLT03DD_ANN.nc
# SSLT04DD, marc_s2, 2000
#   Written marc_s2_2000_SSLT04DD_ANN.nc
# SSLT04DD, marc_s2, 1850
#   Written marc_s2_1850_SSLT04DD_ANN.nc
# Fri Aug 17 15:18:33 +08 2018

# %% [markdown]
# ## Calculate column integrals from 3D rate data
# kg/kg/s -> kg/m2/s

# %%
# List of 3D rate variables of interest
variable_list = [
    'mACCWET', 'mAITWET', 'mNUCWET',  # impaction scavenging
    'mOCWET', 'mMOSWET', 'mOIMWET', 'mBCWET', 'mMBSWET', 'mBIMWET',
    'DST01PP', 'DST02PP', 'DST03PP', 'DST04PP', 'SSLT01PP', 'SSLT02PP', 'SSLT03PP', 'SSLT04PP',
    'AGEmOC', 'AGEmMOS', 'AGEmBC', 'AGEmMBS', # aging
    'mACCACT', 'mAITACT', 'mNUCACT',  # nucleation scavenging by stratiform clouds
    'mOCACT', 'mMOSACT', 'mOIMACT', 'mBCACT', 'mMBSACT', 'mBIMACT',
    'mACCSCV', 'mAITSCV', 'mNUCSCV',  # nucleation scavenging by convection
    'mOCSCV', 'mMOSSCV', 'mOIMSCV', 'mBCSCV', 'mMBSSCV', 'mBIMSCV',
    'mSO4evap',  # SO4 cloud evaporation -> ACC
    'BNUCmNUC',  # binary nucleation -> NUC
    'CNDmACC', 'CNDmAIT', 'CNDmNUC', 'CNDmMOS', 'CNDmMBS',  # H2SO4 condensation
    'MVmNUC', 'MVmAIT',  # mass mode adjustment, NUC->AIT, AIT->ACC
    'CGmNUCAC', 'CGmNUCAI', 'CGmNUCMB', 'CGmNUCMO',  # coagulation
    'CGmAITAC', 'CGmAITMB', 'CGmAITMO', 'CGmACCMB', 'CGmACCMO', 'CGmOCMOS']

# %%
# Calculate column integrals
for year in ['2000', '1850']:  # loop over emission years
    ! date
    print('year = {}'.format(year))
    # Copy the surface pressure file - necessary for decoding of the hybrid coordinates
    print('  Copying surface pressure file')
    in_filename = '{}/p17c_marc_s2_{}.cam.h0.PS.nc'.format(in_dir, year)
    ps_filename = '{}/temp_marc_s2_{}_PS.nc'.format(out_dir, year)
    shutil.copy2(in_filename, ps_filename)
    # Create file containing NCO commands for calculation of air mass in each model level
    nco_filename = '{}/temp_marc_s2_{}.nco'.format(out_dir, year)
    nco_file = open(nco_filename, 'w')
    nco_file.writelines(['*P_bnds[time,ilev,lat,lon]=hyai*P0+hybi*PS;\n',  # pressures at bounds
                         '*P_delta[time,lev,lat,lon]=P_bnds(:,1:30,:,:)-P_bnds(:,0:29,:,:);\n',  # deltas
                         'mass_air=P_delta/9.807;'])  # mass of air
    nco_file.close()
    # Calculate mass of air in each model level
    print('  Calculating mass of air in each model level')
    mass_air_filename = '{}/temp_marc_s2_{}_mass_air.nc'.format(out_dir, year)
    ! ncap2 -O -v -S {nco_filename} {ps_filename} {mass_air_filename}
    # Loop over rate data variables
    for variable in variable_list:  # dust
        ! date
        print('  variable = {}'.format(variable))
        # Copy the rate file
        print('    Copying the file for {}'.format(variable))
        in_filename = '{}/p17c_marc_s2_{}.cam.h0.{}.nc'.format(in_dir, year, variable)
        rate_filename = '{}/temp_marc_s2_{}_{}.nc'.format(out_dir, year, variable)
        shutil.copy2(in_filename, rate_filename)
        # Append the mass of air in each model level
        print('    Appending mass_air')
        ! ncks -A {mass_air_filename} {rate_filename}
        # Calculate the mass rate of the variable
        print('    Calculating the mass rate of {} in each model level'.format(variable))
        mass_variable_filename = '{}/temp_marc_s2_{}_mass_{}.nc'.format(out_dir, year, variable)
        ! ncap2 -O -s 'mass_{variable}=mass_air*{variable}' {rate_filename} {mass_variable_filename}
        # Sum over levels to calculate column integral (and exclude unwanted variables)
        print('    Summing over levels')
        column_filename = '{}/temp_marc_s2_{}_column_{}.nc'.format(out_dir, year, variable)
        ! ncwa -O -x -v mass_air,{variable} -a lev -y sum {mass_variable_filename} {column_filename}
        # Rename variable
        print('    Renaming variable to c{}'.format(variable))
        ! ncrename -v mass_{variable},c{variable} {column_filename} >/dev/null 2>/dev/null
        # Set units and long_name
        print('    Setting units and long_name')
        ! ncatted -a 'units',c{variable},o,c,'kg/m2/s' {column_filename}
        ! ncatted -a 'long_name',c{variable},o,c,'{variable} column integral' {column_filename}
        # Calculate annual means (with years starting in January)
        print('    Calculating annual means')
        annual_filename = '{}/marc_s2_{}_c{}_ANN.nc'.format(out_dir, year, variable)
        ! ncra -O --mro -d time,,,12,12 {column_filename} {annual_filename}
        print('    Written {}'.format(annual_filename.split('/')[-1]))
        # Remove three temporary files
        for filename in [rate_filename, mass_variable_filename, column_filename]:
            print('    Removing {}'.format(filename.split('/')[-1]))
            os.remove(filename)
    # Remove another two temporary files
    for filename in [ps_filename, mass_air_filename, nco_filename]:
            print('  Removing {}'.format(filename.split('/')[-1]))
            os.remove(filename)
! date
# Out:
# Fri Aug 17 15:18:33 +08 2018
# year = 2000
#   Copying surface pressure file
#   Calculating mass of air in each model level
# Fri Aug 17 15:19:30 +08 2018
#   variable = mACCWET
#     Copying the file for mACCWET
#     Appending mass_air
#     Calculating the mass rate of mACCWET in each model level
#     Summing over levels
#     Renaming variable to cmACCWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmACCWET_ANN.nc
#     Removing temp_marc_s2_2000_mACCWET.nc
#     Removing temp_marc_s2_2000_mass_mACCWET.nc
#     Removing temp_marc_s2_2000_column_mACCWET.nc
# Fri Aug 17 15:20:43 +08 2018
#   variable = mAITWET
#     Copying the file for mAITWET
#     Appending mass_air
#     Calculating the mass rate of mAITWET in each model level
#     Summing over levels
#     Renaming variable to cmAITWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmAITWET_ANN.nc
#     Removing temp_marc_s2_2000_mAITWET.nc
#     Removing temp_marc_s2_2000_mass_mAITWET.nc
#     Removing temp_marc_s2_2000_column_mAITWET.nc
# Fri Aug 17 15:21:50 +08 2018
#   variable = mNUCWET
#     Copying the file for mNUCWET
#     Appending mass_air
#     Calculating the mass rate of mNUCWET in each model level
#     Summing over levels
#     Renaming variable to cmNUCWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmNUCWET_ANN.nc
#     Removing temp_marc_s2_2000_mNUCWET.nc
#     Removing temp_marc_s2_2000_mass_mNUCWET.nc
#     Removing temp_marc_s2_2000_column_mNUCWET.nc
# Fri Aug 17 15:22:59 +08 2018
#   variable = mOCWET
#     Copying the file for mOCWET
#     Appending mass_air
#     Calculating the mass rate of mOCWET in each model level
#     Summing over levels
#     Renaming variable to cmOCWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmOCWET_ANN.nc
#     Removing temp_marc_s2_2000_mOCWET.nc
#     Removing temp_marc_s2_2000_mass_mOCWET.nc
#     Removing temp_marc_s2_2000_column_mOCWET.nc
# Fri Aug 17 15:24:05 +08 2018
#   variable = mMOSWET
#     Copying the file for mMOSWET
#     Appending mass_air
#     Calculating the mass rate of mMOSWET in each model level
#     Summing over levels
#     Renaming variable to cmMOSWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmMOSWET_ANN.nc
#     Removing temp_marc_s2_2000_mMOSWET.nc
#     Removing temp_marc_s2_2000_mass_mMOSWET.nc
#     Removing temp_marc_s2_2000_column_mMOSWET.nc
# Fri Aug 17 15:25:17 +08 2018
#   variable = mOIMWET
#     Copying the file for mOIMWET
#     Appending mass_air
#     Calculating the mass rate of mOIMWET in each model level
#     Summing over levels
#     Renaming variable to cmOIMWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmOIMWET_ANN.nc
#     Removing temp_marc_s2_2000_mOIMWET.nc
#     Removing temp_marc_s2_2000_mass_mOIMWET.nc
#     Removing temp_marc_s2_2000_column_mOIMWET.nc
# Fri Aug 17 15:26:17 +08 2018
#   variable = mBCWET
#     Copying the file for mBCWET
#     Appending mass_air
#     Calculating the mass rate of mBCWET in each model level
#     Summing over levels
#     Renaming variable to cmBCWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmBCWET_ANN.nc
#     Removing temp_marc_s2_2000_mBCWET.nc
#     Removing temp_marc_s2_2000_mass_mBCWET.nc
#     Removing temp_marc_s2_2000_column_mBCWET.nc
# Fri Aug 17 15:27:18 +08 2018
#   variable = mMBSWET
#     Copying the file for mMBSWET
#     Appending mass_air
#     Calculating the mass rate of mMBSWET in each model level
#     Summing over levels
#     Renaming variable to cmMBSWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmMBSWET_ANN.nc
#     Removing temp_marc_s2_2000_mMBSWET.nc
#     Removing temp_marc_s2_2000_mass_mMBSWET.nc
#     Removing temp_marc_s2_2000_column_mMBSWET.nc
# Fri Aug 17 15:28:20 +08 2018
#   variable = mBIMWET
#     Copying the file for mBIMWET
#     Appending mass_air
#     Calculating the mass rate of mBIMWET in each model level
#     Summing over levels
#     Renaming variable to cmBIMWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmBIMWET_ANN.nc
#     Removing temp_marc_s2_2000_mBIMWET.nc
#     Removing temp_marc_s2_2000_mass_mBIMWET.nc
#     Removing temp_marc_s2_2000_column_mBIMWET.nc
# Fri Aug 17 15:29:23 +08 2018
#   variable = DST01PP
#     Copying the file for DST01PP
#     Appending mass_air
#     Calculating the mass rate of DST01PP in each model level
#     Summing over levels
#     Renaming variable to cDST01PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cDST01PP_ANN.nc
#     Removing temp_marc_s2_2000_DST01PP.nc
#     Removing temp_marc_s2_2000_mass_DST01PP.nc
#     Removing temp_marc_s2_2000_column_DST01PP.nc
# Fri Aug 17 15:30:31 +08 2018
#   variable = DST02PP
#     Copying the file for DST02PP
#     Appending mass_air
#     Calculating the mass rate of DST02PP in each model level
#     Summing over levels
#     Renaming variable to cDST02PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cDST02PP_ANN.nc
#     Removing temp_marc_s2_2000_DST02PP.nc
#     Removing temp_marc_s2_2000_mass_DST02PP.nc
#     Removing temp_marc_s2_2000_column_DST02PP.nc
# Fri Aug 17 15:31:38 +08 2018
#   variable = DST03PP
#     Copying the file for DST03PP
#     Appending mass_air
#     Calculating the mass rate of DST03PP in each model level
#     Summing over levels
#     Renaming variable to cDST03PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cDST03PP_ANN.nc
#     Removing temp_marc_s2_2000_DST03PP.nc
#     Removing temp_marc_s2_2000_mass_DST03PP.nc
#     Removing temp_marc_s2_2000_column_DST03PP.nc
# Fri Aug 17 15:32:41 +08 2018
#   variable = DST04PP
#     Copying the file for DST04PP
#     Appending mass_air
#     Calculating the mass rate of DST04PP in each model level
#     Summing over levels
#     Renaming variable to cDST04PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cDST04PP_ANN.nc
#     Removing temp_marc_s2_2000_DST04PP.nc
#     Removing temp_marc_s2_2000_mass_DST04PP.nc
#     Removing temp_marc_s2_2000_column_DST04PP.nc
# Fri Aug 17 15:33:45 +08 2018
#   variable = SSLT01PP
#     Copying the file for SSLT01PP
#     Appending mass_air
#     Calculating the mass rate of SSLT01PP in each model level
#     Summing over levels
#     Renaming variable to cSSLT01PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cSSLT01PP_ANN.nc
#     Removing temp_marc_s2_2000_SSLT01PP.nc
#     Removing temp_marc_s2_2000_mass_SSLT01PP.nc
#     Removing temp_marc_s2_2000_column_SSLT01PP.nc
# Fri Aug 17 15:34:48 +08 2018
#   variable = SSLT02PP
#     Copying the file for SSLT02PP
#     Appending mass_air
#     Calculating the mass rate of SSLT02PP in each model level
#     Summing over levels
#     Renaming variable to cSSLT02PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cSSLT02PP_ANN.nc
#     Removing temp_marc_s2_2000_SSLT02PP.nc
#     Removing temp_marc_s2_2000_mass_SSLT02PP.nc
#     Removing temp_marc_s2_2000_column_SSLT02PP.nc
# Fri Aug 17 15:35:55 +08 2018
#   variable = SSLT03PP
#     Copying the file for SSLT03PP
#     Appending mass_air
#     Calculating the mass rate of SSLT03PP in each model level
#     Summing over levels
#     Renaming variable to cSSLT03PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cSSLT03PP_ANN.nc
#     Removing temp_marc_s2_2000_SSLT03PP.nc
#     Removing temp_marc_s2_2000_mass_SSLT03PP.nc
#     Removing temp_marc_s2_2000_column_SSLT03PP.nc
# Fri Aug 17 15:36:58 +08 2018
#   variable = SSLT04PP
#     Copying the file for SSLT04PP
#     Appending mass_air
#     Calculating the mass rate of SSLT04PP in each model level
#     Summing over levels
#     Renaming variable to cSSLT04PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cSSLT04PP_ANN.nc
#     Removing temp_marc_s2_2000_SSLT04PP.nc
#     Removing temp_marc_s2_2000_mass_SSLT04PP.nc
#     Removing temp_marc_s2_2000_column_SSLT04PP.nc
# Fri Aug 17 15:37:57 +08 2018
#   variable = AGEmOC
#     Copying the file for AGEmOC
#     Appending mass_air
#     Calculating the mass rate of AGEmOC in each model level
#     Summing over levels
#     Renaming variable to cAGEmOC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cAGEmOC_ANN.nc
#     Removing temp_marc_s2_2000_AGEmOC.nc
#     Removing temp_marc_s2_2000_mass_AGEmOC.nc
#     Removing temp_marc_s2_2000_column_AGEmOC.nc
# Fri Aug 17 15:39:10 +08 2018
#   variable = AGEmMOS
#     Copying the file for AGEmMOS
#     Appending mass_air
#     Calculating the mass rate of AGEmMOS in each model level
#     Summing over levels
#     Renaming variable to cAGEmMOS
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cAGEmMOS_ANN.nc
#     Removing temp_marc_s2_2000_AGEmMOS.nc
#     Removing temp_marc_s2_2000_mass_AGEmMOS.nc
#     Removing temp_marc_s2_2000_column_AGEmMOS.nc
# Fri Aug 17 15:40:18 +08 2018
#   variable = AGEmBC
#     Copying the file for AGEmBC
#     Appending mass_air
#     Calculating the mass rate of AGEmBC in each model level
#     Summing over levels
#     Renaming variable to cAGEmBC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cAGEmBC_ANN.nc
#     Removing temp_marc_s2_2000_AGEmBC.nc
#     Removing temp_marc_s2_2000_mass_AGEmBC.nc
#     Removing temp_marc_s2_2000_column_AGEmBC.nc
# Fri Aug 17 15:41:30 +08 2018
#   variable = AGEmMBS
#     Copying the file for AGEmMBS
#     Appending mass_air
#     Calculating the mass rate of AGEmMBS in each model level
#     Summing over levels
#     Renaming variable to cAGEmMBS
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cAGEmMBS_ANN.nc
#     Removing temp_marc_s2_2000_AGEmMBS.nc
#     Removing temp_marc_s2_2000_mass_AGEmMBS.nc
#     Removing temp_marc_s2_2000_column_AGEmMBS.nc
# Fri Aug 17 15:42:40 +08 2018
#   variable = mACCACT
#     Copying the file for mACCACT
#     Appending mass_air
#     Calculating the mass rate of mACCACT in each model level
#     Summing over levels
#     Renaming variable to cmACCACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmACCACT_ANN.nc
#     Removing temp_marc_s2_2000_mACCACT.nc
#     Removing temp_marc_s2_2000_mass_mACCACT.nc
#     Removing temp_marc_s2_2000_column_mACCACT.nc
# Fri Aug 17 15:43:54 +08 2018
#   variable = mAITACT
#     Copying the file for mAITACT
#     Appending mass_air
#     Calculating the mass rate of mAITACT in each model level
#     Summing over levels
#     Renaming variable to cmAITACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmAITACT_ANN.nc
#     Removing temp_marc_s2_2000_mAITACT.nc
#     Removing temp_marc_s2_2000_mass_mAITACT.nc
#     Removing temp_marc_s2_2000_column_mAITACT.nc
# Fri Aug 17 15:45:06 +08 2018
#   variable = mNUCACT
#     Copying the file for mNUCACT
#     Appending mass_air
#     Calculating the mass rate of mNUCACT in each model level
#     Summing over levels
#     Renaming variable to cmNUCACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmNUCACT_ANN.nc
#     Removing temp_marc_s2_2000_mNUCACT.nc
#     Removing temp_marc_s2_2000_mass_mNUCACT.nc
#     Removing temp_marc_s2_2000_column_mNUCACT.nc
# Fri Aug 17 15:46:08 +08 2018
#   variable = mOCACT
#     Copying the file for mOCACT
#     Appending mass_air
#     Calculating the mass rate of mOCACT in each model level
#     Summing over levels
#     Renaming variable to cmOCACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmOCACT_ANN.nc
#     Removing temp_marc_s2_2000_mOCACT.nc
#     Removing temp_marc_s2_2000_mass_mOCACT.nc
#     Removing temp_marc_s2_2000_column_mOCACT.nc
# Fri Aug 17 15:47:17 +08 2018
#   variable = mMOSACT
#     Copying the file for mMOSACT
#     Appending mass_air
#     Calculating the mass rate of mMOSACT in each model level
#     Summing over levels
#     Renaming variable to cmMOSACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmMOSACT_ANN.nc
#     Removing temp_marc_s2_2000_mMOSACT.nc
#     Removing temp_marc_s2_2000_mass_mMOSACT.nc
#     Removing temp_marc_s2_2000_column_mMOSACT.nc
# Fri Aug 17 15:48:23 +08 2018
#   variable = mOIMACT
#     Copying the file for mOIMACT
#     Appending mass_air
#     Calculating the mass rate of mOIMACT in each model level
#     Summing over levels
#     Renaming variable to cmOIMACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmOIMACT_ANN.nc
#     Removing temp_marc_s2_2000_mOIMACT.nc
#     Removing temp_marc_s2_2000_mass_mOIMACT.nc
#     Removing temp_marc_s2_2000_column_mOIMACT.nc
# Fri Aug 17 15:49:40 +08 2018
#   variable = mBCACT
#     Copying the file for mBCACT
#     Appending mass_air
#     Calculating the mass rate of mBCACT in each model level
#     Summing over levels
#     Renaming variable to cmBCACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmBCACT_ANN.nc
#     Removing temp_marc_s2_2000_mBCACT.nc
#     Removing temp_marc_s2_2000_mass_mBCACT.nc
#     Removing temp_marc_s2_2000_column_mBCACT.nc
# Fri Aug 17 15:50:55 +08 2018
#   variable = mMBSACT
#     Copying the file for mMBSACT
#     Appending mass_air
#     Calculating the mass rate of mMBSACT in each model level
#     Summing over levels
#     Renaming variable to cmMBSACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmMBSACT_ANN.nc
#     Removing temp_marc_s2_2000_mMBSACT.nc
#     Removing temp_marc_s2_2000_mass_mMBSACT.nc
#     Removing temp_marc_s2_2000_column_mMBSACT.nc
# Fri Aug 17 15:52:06 +08 2018
#   variable = mBIMACT
#     Copying the file for mBIMACT
#     Appending mass_air
#     Calculating the mass rate of mBIMACT in each model level
#     Summing over levels
#     Renaming variable to cmBIMACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmBIMACT_ANN.nc
#     Removing temp_marc_s2_2000_mBIMACT.nc
#     Removing temp_marc_s2_2000_mass_mBIMACT.nc
#     Removing temp_marc_s2_2000_column_mBIMACT.nc
# Fri Aug 17 15:53:24 +08 2018
#   variable = mACCSCV
#     Copying the file for mACCSCV
#     Appending mass_air
#     Calculating the mass rate of mACCSCV in each model level
#     Summing over levels
#     Renaming variable to cmACCSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmACCSCV_ANN.nc
#     Removing temp_marc_s2_2000_mACCSCV.nc
#     Removing temp_marc_s2_2000_mass_mACCSCV.nc
#     Removing temp_marc_s2_2000_column_mACCSCV.nc
# Fri Aug 17 15:54:37 +08 2018
#   variable = mAITSCV
#     Copying the file for mAITSCV
#     Appending mass_air
#     Calculating the mass rate of mAITSCV in each model level
#     Summing over levels
#     Renaming variable to cmAITSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmAITSCV_ANN.nc
#     Removing temp_marc_s2_2000_mAITSCV.nc
#     Removing temp_marc_s2_2000_mass_mAITSCV.nc
#     Removing temp_marc_s2_2000_column_mAITSCV.nc
# Fri Aug 17 15:55:46 +08 2018
#   variable = mNUCSCV
#     Copying the file for mNUCSCV
#     Appending mass_air
#     Calculating the mass rate of mNUCSCV in each model level
#     Summing over levels
#     Renaming variable to cmNUCSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmNUCSCV_ANN.nc
#     Removing temp_marc_s2_2000_mNUCSCV.nc
#     Removing temp_marc_s2_2000_mass_mNUCSCV.nc
#     Removing temp_marc_s2_2000_column_mNUCSCV.nc
# Fri Aug 17 15:56:50 +08 2018
#   variable = mOCSCV
#     Copying the file for mOCSCV
#     Appending mass_air
#     Calculating the mass rate of mOCSCV in each model level
#     Summing over levels
#     Renaming variable to cmOCSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmOCSCV_ANN.nc
#     Removing temp_marc_s2_2000_mOCSCV.nc
#     Removing temp_marc_s2_2000_mass_mOCSCV.nc
#     Removing temp_marc_s2_2000_column_mOCSCV.nc
# Fri Aug 17 15:58:01 +08 2018
#   variable = mMOSSCV
#     Copying the file for mMOSSCV
#     Appending mass_air
#     Calculating the mass rate of mMOSSCV in each model level
#     Summing over levels
#     Renaming variable to cmMOSSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmMOSSCV_ANN.nc
#     Removing temp_marc_s2_2000_mMOSSCV.nc
#     Removing temp_marc_s2_2000_mass_mMOSSCV.nc
#     Removing temp_marc_s2_2000_column_mMOSSCV.nc
# Fri Aug 17 15:59:05 +08 2018
#   variable = mOIMSCV
#     Copying the file for mOIMSCV
#     Appending mass_air
#     Calculating the mass rate of mOIMSCV in each model level
#     Summing over levels
#     Renaming variable to cmOIMSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmOIMSCV_ANN.nc
#     Removing temp_marc_s2_2000_mOIMSCV.nc
#     Removing temp_marc_s2_2000_mass_mOIMSCV.nc
#     Removing temp_marc_s2_2000_column_mOIMSCV.nc
# Fri Aug 17 16:00:05 +08 2018
#   variable = mBCSCV
#     Copying the file for mBCSCV
#     Appending mass_air
#     Calculating the mass rate of mBCSCV in each model level
#     Summing over levels
#     Renaming variable to cmBCSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmBCSCV_ANN.nc
#     Removing temp_marc_s2_2000_mBCSCV.nc
#     Removing temp_marc_s2_2000_mass_mBCSCV.nc
#     Removing temp_marc_s2_2000_column_mBCSCV.nc
# Fri Aug 17 16:01:04 +08 2018
#   variable = mMBSSCV
#     Copying the file for mMBSSCV
#     Appending mass_air
#     Calculating the mass rate of mMBSSCV in each model level
#     Summing over levels
#     Renaming variable to cmMBSSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmMBSSCV_ANN.nc
#     Removing temp_marc_s2_2000_mMBSSCV.nc
#     Removing temp_marc_s2_2000_mass_mMBSSCV.nc
#     Removing temp_marc_s2_2000_column_mMBSSCV.nc
# Fri Aug 17 16:02:02 +08 2018
#   variable = mBIMSCV
#     Copying the file for mBIMSCV
#     Appending mass_air
#     Calculating the mass rate of mBIMSCV in each model level
#     Summing over levels
#     Renaming variable to cmBIMSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmBIMSCV_ANN.nc
#     Removing temp_marc_s2_2000_mBIMSCV.nc
#     Removing temp_marc_s2_2000_mass_mBIMSCV.nc
#     Removing temp_marc_s2_2000_column_mBIMSCV.nc
# Fri Aug 17 16:02:54 +08 2018
#   variable = mSO4evap
#     Copying the file for mSO4evap
#     Appending mass_air
#     Calculating the mass rate of mSO4evap in each model level
#     Summing over levels
#     Renaming variable to cmSO4evap
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cmSO4evap_ANN.nc
#     Removing temp_marc_s2_2000_mSO4evap.nc
#     Removing temp_marc_s2_2000_mass_mSO4evap.nc
#     Removing temp_marc_s2_2000_column_mSO4evap.nc
# Fri Aug 17 16:03:41 +08 2018
#   variable = BNUCmNUC
#     Copying the file for BNUCmNUC
#     Appending mass_air
#     Calculating the mass rate of BNUCmNUC in each model level
#     Summing over levels
#     Renaming variable to cBNUCmNUC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cBNUCmNUC_ANN.nc
#     Removing temp_marc_s2_2000_BNUCmNUC.nc
#     Removing temp_marc_s2_2000_mass_BNUCmNUC.nc
#     Removing temp_marc_s2_2000_column_BNUCmNUC.nc
# Fri Aug 17 16:04:21 +08 2018
#   variable = CNDmACC
#     Copying the file for CNDmACC
#     Appending mass_air
#     Calculating the mass rate of CNDmACC in each model level
#     Summing over levels
#     Renaming variable to cCNDmACC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cCNDmACC_ANN.nc
#     Removing temp_marc_s2_2000_CNDmACC.nc
#     Removing temp_marc_s2_2000_mass_CNDmACC.nc
#     Removing temp_marc_s2_2000_column_CNDmACC.nc
# Fri Aug 17 16:05:06 +08 2018
#   variable = CNDmAIT
#     Copying the file for CNDmAIT
#     Appending mass_air
#     Calculating the mass rate of CNDmAIT in each model level
#     Summing over levels
#     Renaming variable to cCNDmAIT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cCNDmAIT_ANN.nc
#     Removing temp_marc_s2_2000_CNDmAIT.nc
#     Removing temp_marc_s2_2000_mass_CNDmAIT.nc
#     Removing temp_marc_s2_2000_column_CNDmAIT.nc
# Fri Aug 17 16:05:48 +08 2018
#   variable = CNDmNUC
#     Copying the file for CNDmNUC
#     Appending mass_air
#     Calculating the mass rate of CNDmNUC in each model level
#     Summing over levels
#     Renaming variable to cCNDmNUC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cCNDmNUC_ANN.nc
#     Removing temp_marc_s2_2000_CNDmNUC.nc
#     Removing temp_marc_s2_2000_mass_CNDmNUC.nc
#     Removing temp_marc_s2_2000_column_CNDmNUC.nc
# Fri Aug 17 16:06:32 +08 2018
#   variable = CNDmMOS
#     Copying the file for CNDmMOS
#     Appending mass_air
#     Calculating the mass rate of CNDmMOS in each model level
#     Summing over levels
#     Renaming variable to cCNDmMOS
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cCNDmMOS_ANN.nc
#     Removing temp_marc_s2_2000_CNDmMOS.nc
#     Removing temp_marc_s2_2000_mass_CNDmMOS.nc
#     Removing temp_marc_s2_2000_column_CNDmMOS.nc
# Fri Aug 17 16:07:16 +08 2018
#   variable = CNDmMBS
#     Copying the file for CNDmMBS
#     Appending mass_air
#     Calculating the mass rate of CNDmMBS in each model level
#     Summing over levels
#     Renaming variable to cCNDmMBS
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cCNDmMBS_ANN.nc
#     Removing temp_marc_s2_2000_CNDmMBS.nc
#     Removing temp_marc_s2_2000_mass_CNDmMBS.nc
#     Removing temp_marc_s2_2000_column_CNDmMBS.nc
# Fri Aug 17 16:08:00 +08 2018
#   variable = MVmNUC
#     Copying the file for MVmNUC
#     Appending mass_air
#     Calculating the mass rate of MVmNUC in each model level
#     Summing over levels
#     Renaming variable to cMVmNUC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cMVmNUC_ANN.nc
#     Removing temp_marc_s2_2000_MVmNUC.nc
#     Removing temp_marc_s2_2000_mass_MVmNUC.nc
#     Removing temp_marc_s2_2000_column_MVmNUC.nc
# Fri Aug 17 16:08:38 +08 2018
#   variable = MVmAIT
#     Copying the file for MVmAIT
#     Appending mass_air
#     Calculating the mass rate of MVmAIT in each model level
#     Summing over levels
#     Renaming variable to cMVmAIT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cMVmAIT_ANN.nc
#     Removing temp_marc_s2_2000_MVmAIT.nc
#     Removing temp_marc_s2_2000_mass_MVmAIT.nc
#     Removing temp_marc_s2_2000_column_MVmAIT.nc
# Fri Aug 17 16:09:21 +08 2018
#   variable = CGmNUCAC
#     Copying the file for CGmNUCAC
#     Appending mass_air
#     Calculating the mass rate of CGmNUCAC in each model level
#     Summing over levels
#     Renaming variable to cCGmNUCAC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cCGmNUCAC_ANN.nc
#     Removing temp_marc_s2_2000_CGmNUCAC.nc
#     Removing temp_marc_s2_2000_mass_CGmNUCAC.nc
#     Removing temp_marc_s2_2000_column_CGmNUCAC.nc
# Fri Aug 17 16:10:04 +08 2018
#   variable = CGmNUCAI
#     Copying the file for CGmNUCAI
#     Appending mass_air
#     Calculating the mass rate of CGmNUCAI in each model level
#     Summing over levels
#     Renaming variable to cCGmNUCAI
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cCGmNUCAI_ANN.nc
#     Removing temp_marc_s2_2000_CGmNUCAI.nc
#     Removing temp_marc_s2_2000_mass_CGmNUCAI.nc
#     Removing temp_marc_s2_2000_column_CGmNUCAI.nc
# Fri Aug 17 16:10:39 +08 2018
#   variable = CGmNUCMB
#     Copying the file for CGmNUCMB
#     Appending mass_air
#     Calculating the mass rate of CGmNUCMB in each model level
#     Summing over levels
#     Renaming variable to cCGmNUCMB
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cCGmNUCMB_ANN.nc
#     Removing temp_marc_s2_2000_CGmNUCMB.nc
#     Removing temp_marc_s2_2000_mass_CGmNUCMB.nc
#     Removing temp_marc_s2_2000_column_CGmNUCMB.nc
# Fri Aug 17 16:11:17 +08 2018
#   variable = CGmNUCMO
#     Copying the file for CGmNUCMO
#     Appending mass_air
#     Calculating the mass rate of CGmNUCMO in each model level
#     Summing over levels
#     Renaming variable to cCGmNUCMO
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cCGmNUCMO_ANN.nc
#     Removing temp_marc_s2_2000_CGmNUCMO.nc
#     Removing temp_marc_s2_2000_mass_CGmNUCMO.nc
#     Removing temp_marc_s2_2000_column_CGmNUCMO.nc
# Fri Aug 17 16:11:56 +08 2018
#   variable = CGmAITAC
#     Copying the file for CGmAITAC
#     Appending mass_air
#     Calculating the mass rate of CGmAITAC in each model level
#     Summing over levels
#     Renaming variable to cCGmAITAC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cCGmAITAC_ANN.nc
#     Removing temp_marc_s2_2000_CGmAITAC.nc
#     Removing temp_marc_s2_2000_mass_CGmAITAC.nc
#     Removing temp_marc_s2_2000_column_CGmAITAC.nc
# Fri Aug 17 16:12:38 +08 2018
#   variable = CGmAITMB
#     Copying the file for CGmAITMB
#     Appending mass_air
#     Calculating the mass rate of CGmAITMB in each model level
#     Summing over levels
#     Renaming variable to cCGmAITMB
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cCGmAITMB_ANN.nc
#     Removing temp_marc_s2_2000_CGmAITMB.nc
#     Removing temp_marc_s2_2000_mass_CGmAITMB.nc
#     Removing temp_marc_s2_2000_column_CGmAITMB.nc
# Fri Aug 17 16:13:19 +08 2018
#   variable = CGmAITMO
#     Copying the file for CGmAITMO
#     Appending mass_air
#     Calculating the mass rate of CGmAITMO in each model level
#     Summing over levels
#     Renaming variable to cCGmAITMO
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cCGmAITMO_ANN.nc
#     Removing temp_marc_s2_2000_CGmAITMO.nc
#     Removing temp_marc_s2_2000_mass_CGmAITMO.nc
#     Removing temp_marc_s2_2000_column_CGmAITMO.nc
# Fri Aug 17 16:14:01 +08 2018
#   variable = CGmACCMB
#     Copying the file for CGmACCMB
#     Appending mass_air
#     Calculating the mass rate of CGmACCMB in each model level
#     Summing over levels
#     Renaming variable to cCGmACCMB
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cCGmACCMB_ANN.nc
#     Removing temp_marc_s2_2000_CGmACCMB.nc
#     Removing temp_marc_s2_2000_mass_CGmACCMB.nc
#     Removing temp_marc_s2_2000_column_CGmACCMB.nc
# Fri Aug 17 16:14:49 +08 2018
#   variable = CGmACCMO
#     Copying the file for CGmACCMO
#     Appending mass_air
#     Calculating the mass rate of CGmACCMO in each model level
#     Summing over levels
#     Renaming variable to cCGmACCMO
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cCGmACCMO_ANN.nc
#     Removing temp_marc_s2_2000_CGmACCMO.nc
#     Removing temp_marc_s2_2000_mass_CGmACCMO.nc
#     Removing temp_marc_s2_2000_column_CGmACCMO.nc
# Fri Aug 17 16:15:37 +08 2018
#   variable = CGmOCMOS
#     Copying the file for CGmOCMOS
#     Appending mass_air
#     Calculating the mass rate of CGmOCMOS in each model level
#     Summing over levels
#     Renaming variable to cCGmOCMOS
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_2000_cCGmOCMOS_ANN.nc
#     Removing temp_marc_s2_2000_CGmOCMOS.nc
#     Removing temp_marc_s2_2000_mass_CGmOCMOS.nc
#     Removing temp_marc_s2_2000_column_CGmOCMOS.nc
#   Removing temp_marc_s2_2000_PS.nc
#   Removing temp_marc_s2_2000_mass_air.nc
#   Removing temp_marc_s2_2000.nco
# Fri Aug 17 16:16:24 +08 2018
# year = 1850
#   Copying surface pressure file
#   Calculating mass of air in each model level
# Fri Aug 17 16:17:06 +08 2018
#   variable = mACCWET
#     Copying the file for mACCWET
#     Appending mass_air
#     Calculating the mass rate of mACCWET in each model level
#     Summing over levels
#     Renaming variable to cmACCWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmACCWET_ANN.nc
#     Removing temp_marc_s2_1850_mACCWET.nc
#     Removing temp_marc_s2_1850_mass_mACCWET.nc
#     Removing temp_marc_s2_1850_column_mACCWET.nc
# Fri Aug 17 16:17:49 +08 2018
#   variable = mAITWET
#     Copying the file for mAITWET
#     Appending mass_air
#     Calculating the mass rate of mAITWET in each model level
#     Summing over levels
#     Renaming variable to cmAITWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmAITWET_ANN.nc
#     Removing temp_marc_s2_1850_mAITWET.nc
#     Removing temp_marc_s2_1850_mass_mAITWET.nc
#     Removing temp_marc_s2_1850_column_mAITWET.nc
# Fri Aug 17 16:18:34 +08 2018
#   variable = mNUCWET
#     Copying the file for mNUCWET
#     Appending mass_air
#     Calculating the mass rate of mNUCWET in each model level
#     Summing over levels
#     Renaming variable to cmNUCWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmNUCWET_ANN.nc
#     Removing temp_marc_s2_1850_mNUCWET.nc
#     Removing temp_marc_s2_1850_mass_mNUCWET.nc
#     Removing temp_marc_s2_1850_column_mNUCWET.nc
# Fri Aug 17 16:19:17 +08 2018
#   variable = mOCWET
#     Copying the file for mOCWET
#     Appending mass_air
#     Calculating the mass rate of mOCWET in each model level
#     Summing over levels
#     Renaming variable to cmOCWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmOCWET_ANN.nc
#     Removing temp_marc_s2_1850_mOCWET.nc
#     Removing temp_marc_s2_1850_mass_mOCWET.nc
#     Removing temp_marc_s2_1850_column_mOCWET.nc
# Fri Aug 17 16:20:00 +08 2018
#   variable = mMOSWET
#     Copying the file for mMOSWET
#     Appending mass_air
#     Calculating the mass rate of mMOSWET in each model level
#     Summing over levels
#     Renaming variable to cmMOSWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmMOSWET_ANN.nc
#     Removing temp_marc_s2_1850_mMOSWET.nc
#     Removing temp_marc_s2_1850_mass_mMOSWET.nc
#     Removing temp_marc_s2_1850_column_mMOSWET.nc
# Fri Aug 17 16:20:44 +08 2018
#   variable = mOIMWET
#     Copying the file for mOIMWET
#     Appending mass_air
#     Calculating the mass rate of mOIMWET in each model level
#     Summing over levels
#     Renaming variable to cmOIMWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmOIMWET_ANN.nc
#     Removing temp_marc_s2_1850_mOIMWET.nc
#     Removing temp_marc_s2_1850_mass_mOIMWET.nc
#     Removing temp_marc_s2_1850_column_mOIMWET.nc
# Fri Aug 17 16:21:30 +08 2018
#   variable = mBCWET
#     Copying the file for mBCWET
#     Appending mass_air
#     Calculating the mass rate of mBCWET in each model level
#     Summing over levels
#     Renaming variable to cmBCWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmBCWET_ANN.nc
#     Removing temp_marc_s2_1850_mBCWET.nc
#     Removing temp_marc_s2_1850_mass_mBCWET.nc
#     Removing temp_marc_s2_1850_column_mBCWET.nc
# Fri Aug 17 16:22:19 +08 2018
#   variable = mMBSWET
#     Copying the file for mMBSWET
#     Appending mass_air
#     Calculating the mass rate of mMBSWET in each model level
#     Summing over levels
#     Renaming variable to cmMBSWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmMBSWET_ANN.nc
#     Removing temp_marc_s2_1850_mMBSWET.nc
#     Removing temp_marc_s2_1850_mass_mMBSWET.nc
#     Removing temp_marc_s2_1850_column_mMBSWET.nc
# Fri Aug 17 16:23:04 +08 2018
#   variable = mBIMWET
#     Copying the file for mBIMWET
#     Appending mass_air
#     Calculating the mass rate of mBIMWET in each model level
#     Summing over levels
#     Renaming variable to cmBIMWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmBIMWET_ANN.nc
#     Removing temp_marc_s2_1850_mBIMWET.nc
#     Removing temp_marc_s2_1850_mass_mBIMWET.nc
#     Removing temp_marc_s2_1850_column_mBIMWET.nc
# Fri Aug 17 16:23:49 +08 2018
#   variable = DST01PP
#     Copying the file for DST01PP
#     Appending mass_air
#     Calculating the mass rate of DST01PP in each model level
#     Summing over levels
#     Renaming variable to cDST01PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cDST01PP_ANN.nc
#     Removing temp_marc_s2_1850_DST01PP.nc
#     Removing temp_marc_s2_1850_mass_DST01PP.nc
#     Removing temp_marc_s2_1850_column_DST01PP.nc
# Fri Aug 17 16:24:38 +08 2018
#   variable = DST02PP
#     Copying the file for DST02PP
#     Appending mass_air
#     Calculating the mass rate of DST02PP in each model level
#     Summing over levels
#     Renaming variable to cDST02PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cDST02PP_ANN.nc
#     Removing temp_marc_s2_1850_DST02PP.nc
#     Removing temp_marc_s2_1850_mass_DST02PP.nc
#     Removing temp_marc_s2_1850_column_DST02PP.nc
# Fri Aug 17 16:25:22 +08 2018
#   variable = DST03PP
#     Copying the file for DST03PP
#     Appending mass_air
#     Calculating the mass rate of DST03PP in each model level
#     Summing over levels
#     Renaming variable to cDST03PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cDST03PP_ANN.nc
#     Removing temp_marc_s2_1850_DST03PP.nc
#     Removing temp_marc_s2_1850_mass_DST03PP.nc
#     Removing temp_marc_s2_1850_column_DST03PP.nc
# Fri Aug 17 16:26:11 +08 2018
#   variable = DST04PP
#     Copying the file for DST04PP
#     Appending mass_air
#     Calculating the mass rate of DST04PP in each model level
#     Summing over levels
#     Renaming variable to cDST04PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cDST04PP_ANN.nc
#     Removing temp_marc_s2_1850_DST04PP.nc
#     Removing temp_marc_s2_1850_mass_DST04PP.nc
#     Removing temp_marc_s2_1850_column_DST04PP.nc
# Fri Aug 17 16:26:57 +08 2018
#   variable = SSLT01PP
#     Copying the file for SSLT01PP
#     Appending mass_air
#     Calculating the mass rate of SSLT01PP in each model level
#     Summing over levels
#     Renaming variable to cSSLT01PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cSSLT01PP_ANN.nc
#     Removing temp_marc_s2_1850_SSLT01PP.nc
#     Removing temp_marc_s2_1850_mass_SSLT01PP.nc
#     Removing temp_marc_s2_1850_column_SSLT01PP.nc
# Fri Aug 17 16:27:43 +08 2018
#   variable = SSLT02PP
#     Copying the file for SSLT02PP
#     Appending mass_air
#     Calculating the mass rate of SSLT02PP in each model level
#     Summing over levels
#     Renaming variable to cSSLT02PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cSSLT02PP_ANN.nc
#     Removing temp_marc_s2_1850_SSLT02PP.nc
#     Removing temp_marc_s2_1850_mass_SSLT02PP.nc
#     Removing temp_marc_s2_1850_column_SSLT02PP.nc
# Fri Aug 17 16:28:31 +08 2018
#   variable = SSLT03PP
#     Copying the file for SSLT03PP
#     Appending mass_air
#     Calculating the mass rate of SSLT03PP in each model level
#     Summing over levels
#     Renaming variable to cSSLT03PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cSSLT03PP_ANN.nc
#     Removing temp_marc_s2_1850_SSLT03PP.nc
#     Removing temp_marc_s2_1850_mass_SSLT03PP.nc
#     Removing temp_marc_s2_1850_column_SSLT03PP.nc
# Fri Aug 17 16:29:17 +08 2018
#   variable = SSLT04PP
#     Copying the file for SSLT04PP
#     Appending mass_air
#     Calculating the mass rate of SSLT04PP in each model level
#     Summing over levels
#     Renaming variable to cSSLT04PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cSSLT04PP_ANN.nc
#     Removing temp_marc_s2_1850_SSLT04PP.nc
#     Removing temp_marc_s2_1850_mass_SSLT04PP.nc
#     Removing temp_marc_s2_1850_column_SSLT04PP.nc
# Fri Aug 17 16:30:03 +08 2018
#   variable = AGEmOC
#     Copying the file for AGEmOC
#     Appending mass_air
#     Calculating the mass rate of AGEmOC in each model level
#     Summing over levels
#     Renaming variable to cAGEmOC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cAGEmOC_ANN.nc
#     Removing temp_marc_s2_1850_AGEmOC.nc
#     Removing temp_marc_s2_1850_mass_AGEmOC.nc
#     Removing temp_marc_s2_1850_column_AGEmOC.nc
# Fri Aug 17 16:30:51 +08 2018
#   variable = AGEmMOS
#     Copying the file for AGEmMOS
#     Appending mass_air
#     Calculating the mass rate of AGEmMOS in each model level
#     Summing over levels
#     Renaming variable to cAGEmMOS
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cAGEmMOS_ANN.nc
#     Removing temp_marc_s2_1850_AGEmMOS.nc
#     Removing temp_marc_s2_1850_mass_AGEmMOS.nc
#     Removing temp_marc_s2_1850_column_AGEmMOS.nc
# Fri Aug 17 16:31:39 +08 2018
#   variable = AGEmBC
#     Copying the file for AGEmBC
#     Appending mass_air
#     Calculating the mass rate of AGEmBC in each model level
#     Summing over levels
#     Renaming variable to cAGEmBC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cAGEmBC_ANN.nc
#     Removing temp_marc_s2_1850_AGEmBC.nc
#     Removing temp_marc_s2_1850_mass_AGEmBC.nc
#     Removing temp_marc_s2_1850_column_AGEmBC.nc
# Fri Aug 17 16:32:26 +08 2018
#   variable = AGEmMBS
#     Copying the file for AGEmMBS
#     Appending mass_air
#     Calculating the mass rate of AGEmMBS in each model level
#     Summing over levels
#     Renaming variable to cAGEmMBS
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cAGEmMBS_ANN.nc
#     Removing temp_marc_s2_1850_AGEmMBS.nc
#     Removing temp_marc_s2_1850_mass_AGEmMBS.nc
#     Removing temp_marc_s2_1850_column_AGEmMBS.nc
# Fri Aug 17 16:33:15 +08 2018
#   variable = mACCACT
#     Copying the file for mACCACT
#     Appending mass_air
#     Calculating the mass rate of mACCACT in each model level
#     Summing over levels
#     Renaming variable to cmACCACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmACCACT_ANN.nc
#     Removing temp_marc_s2_1850_mACCACT.nc
#     Removing temp_marc_s2_1850_mass_mACCACT.nc
#     Removing temp_marc_s2_1850_column_mACCACT.nc
# Fri Aug 17 16:34:07 +08 2018
#   variable = mAITACT
#     Copying the file for mAITACT
#     Appending mass_air
#     Calculating the mass rate of mAITACT in each model level
#     Summing over levels
#     Renaming variable to cmAITACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmAITACT_ANN.nc
#     Removing temp_marc_s2_1850_mAITACT.nc
#     Removing temp_marc_s2_1850_mass_mAITACT.nc
#     Removing temp_marc_s2_1850_column_mAITACT.nc
# Fri Aug 17 16:34:55 +08 2018
#   variable = mNUCACT
#     Copying the file for mNUCACT
#     Appending mass_air
#     Calculating the mass rate of mNUCACT in each model level
#     Summing over levels
#     Renaming variable to cmNUCACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmNUCACT_ANN.nc
#     Removing temp_marc_s2_1850_mNUCACT.nc
#     Removing temp_marc_s2_1850_mass_mNUCACT.nc
#     Removing temp_marc_s2_1850_column_mNUCACT.nc
# Fri Aug 17 16:35:42 +08 2018
#   variable = mOCACT
#     Copying the file for mOCACT
#     Appending mass_air
#     Calculating the mass rate of mOCACT in each model level
#     Summing over levels
#     Renaming variable to cmOCACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmOCACT_ANN.nc
#     Removing temp_marc_s2_1850_mOCACT.nc
#     Removing temp_marc_s2_1850_mass_mOCACT.nc
#     Removing temp_marc_s2_1850_column_mOCACT.nc
# Fri Aug 17 16:36:39 +08 2018
#   variable = mMOSACT
#     Copying the file for mMOSACT
#     Appending mass_air
#     Calculating the mass rate of mMOSACT in each model level
#     Summing over levels
#     Renaming variable to cmMOSACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmMOSACT_ANN.nc
#     Removing temp_marc_s2_1850_mMOSACT.nc
#     Removing temp_marc_s2_1850_mass_mMOSACT.nc
#     Removing temp_marc_s2_1850_column_mMOSACT.nc
# Fri Aug 17 16:37:32 +08 2018
#   variable = mOIMACT
#     Copying the file for mOIMACT
#     Appending mass_air
#     Calculating the mass rate of mOIMACT in each model level
#     Summing over levels
#     Renaming variable to cmOIMACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmOIMACT_ANN.nc
#     Removing temp_marc_s2_1850_mOIMACT.nc
#     Removing temp_marc_s2_1850_mass_mOIMACT.nc
#     Removing temp_marc_s2_1850_column_mOIMACT.nc
# Fri Aug 17 16:38:25 +08 2018
#   variable = mBCACT
#     Copying the file for mBCACT
#     Appending mass_air
#     Calculating the mass rate of mBCACT in each model level
#     Summing over levels
#     Renaming variable to cmBCACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmBCACT_ANN.nc
#     Removing temp_marc_s2_1850_mBCACT.nc
#     Removing temp_marc_s2_1850_mass_mBCACT.nc
#     Removing temp_marc_s2_1850_column_mBCACT.nc
# Fri Aug 17 16:39:18 +08 2018
#   variable = mMBSACT
#     Copying the file for mMBSACT
#     Appending mass_air
#     Calculating the mass rate of mMBSACT in each model level
#     Summing over levels
#     Renaming variable to cmMBSACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmMBSACT_ANN.nc
#     Removing temp_marc_s2_1850_mMBSACT.nc
#     Removing temp_marc_s2_1850_mass_mMBSACT.nc
#     Removing temp_marc_s2_1850_column_mMBSACT.nc
# Fri Aug 17 16:40:10 +08 2018
#   variable = mBIMACT
#     Copying the file for mBIMACT
#     Appending mass_air
#     Calculating the mass rate of mBIMACT in each model level
#     Summing over levels
#     Renaming variable to cmBIMACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmBIMACT_ANN.nc
#     Removing temp_marc_s2_1850_mBIMACT.nc
#     Removing temp_marc_s2_1850_mass_mBIMACT.nc
#     Removing temp_marc_s2_1850_column_mBIMACT.nc
# Fri Aug 17 16:41:01 +08 2018
#   variable = mACCSCV
#     Copying the file for mACCSCV
#     Appending mass_air
#     Calculating the mass rate of mACCSCV in each model level
#     Summing over levels
#     Renaming variable to cmACCSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmACCSCV_ANN.nc
#     Removing temp_marc_s2_1850_mACCSCV.nc
#     Removing temp_marc_s2_1850_mass_mACCSCV.nc
#     Removing temp_marc_s2_1850_column_mACCSCV.nc
# Fri Aug 17 16:41:55 +08 2018
#   variable = mAITSCV
#     Copying the file for mAITSCV
#     Appending mass_air
#     Calculating the mass rate of mAITSCV in each model level
#     Summing over levels
#     Renaming variable to cmAITSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmAITSCV_ANN.nc
#     Removing temp_marc_s2_1850_mAITSCV.nc
#     Removing temp_marc_s2_1850_mass_mAITSCV.nc
#     Removing temp_marc_s2_1850_column_mAITSCV.nc
# Fri Aug 17 16:42:43 +08 2018
#   variable = mNUCSCV
#     Copying the file for mNUCSCV
#     Appending mass_air
#     Calculating the mass rate of mNUCSCV in each model level
#     Summing over levels
#     Renaming variable to cmNUCSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmNUCSCV_ANN.nc
#     Removing temp_marc_s2_1850_mNUCSCV.nc
#     Removing temp_marc_s2_1850_mass_mNUCSCV.nc
#     Removing temp_marc_s2_1850_column_mNUCSCV.nc
# Fri Aug 17 16:43:26 +08 2018
#   variable = mOCSCV
#     Copying the file for mOCSCV
#     Appending mass_air
#     Calculating the mass rate of mOCSCV in each model level
#     Summing over levels
#     Renaming variable to cmOCSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmOCSCV_ANN.nc
#     Removing temp_marc_s2_1850_mOCSCV.nc
#     Removing temp_marc_s2_1850_mass_mOCSCV.nc
#     Removing temp_marc_s2_1850_column_mOCSCV.nc
# Fri Aug 17 16:44:25 +08 2018
#   variable = mMOSSCV
#     Copying the file for mMOSSCV
#     Appending mass_air
#     Calculating the mass rate of mMOSSCV in each model level
#     Summing over levels
#     Renaming variable to cmMOSSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmMOSSCV_ANN.nc
#     Removing temp_marc_s2_1850_mMOSSCV.nc
#     Removing temp_marc_s2_1850_mass_mMOSSCV.nc
#     Removing temp_marc_s2_1850_column_mMOSSCV.nc
# Fri Aug 17 16:45:17 +08 2018
#   variable = mOIMSCV
#     Copying the file for mOIMSCV
#     Appending mass_air
#     Calculating the mass rate of mOIMSCV in each model level
#     Summing over levels
#     Renaming variable to cmOIMSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmOIMSCV_ANN.nc
#     Removing temp_marc_s2_1850_mOIMSCV.nc
#     Removing temp_marc_s2_1850_mass_mOIMSCV.nc
#     Removing temp_marc_s2_1850_column_mOIMSCV.nc
# Fri Aug 17 16:46:08 +08 2018
#   variable = mBCSCV
#     Copying the file for mBCSCV
#     Appending mass_air
#     Calculating the mass rate of mBCSCV in each model level
#     Summing over levels
#     Renaming variable to cmBCSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmBCSCV_ANN.nc
#     Removing temp_marc_s2_1850_mBCSCV.nc
#     Removing temp_marc_s2_1850_mass_mBCSCV.nc
#     Removing temp_marc_s2_1850_column_mBCSCV.nc
# Fri Aug 17 16:46:58 +08 2018
#   variable = mMBSSCV
#     Copying the file for mMBSSCV
#     Appending mass_air
#     Calculating the mass rate of mMBSSCV in each model level
#     Summing over levels
#     Renaming variable to cmMBSSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmMBSSCV_ANN.nc
#     Removing temp_marc_s2_1850_mMBSSCV.nc
#     Removing temp_marc_s2_1850_mass_mMBSSCV.nc
#     Removing temp_marc_s2_1850_column_mMBSSCV.nc
# Fri Aug 17 16:47:51 +08 2018
#   variable = mBIMSCV
#     Copying the file for mBIMSCV
#     Appending mass_air
#     Calculating the mass rate of mBIMSCV in each model level
#     Summing over levels
#     Renaming variable to cmBIMSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmBIMSCV_ANN.nc
#     Removing temp_marc_s2_1850_mBIMSCV.nc
#     Removing temp_marc_s2_1850_mass_mBIMSCV.nc
#     Removing temp_marc_s2_1850_column_mBIMSCV.nc
# Fri Aug 17 16:48:42 +08 2018
#   variable = mSO4evap
#     Copying the file for mSO4evap
#     Appending mass_air
#     Calculating the mass rate of mSO4evap in each model level
#     Summing over levels
#     Renaming variable to cmSO4evap
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cmSO4evap_ANN.nc
#     Removing temp_marc_s2_1850_mSO4evap.nc
#     Removing temp_marc_s2_1850_mass_mSO4evap.nc
#     Removing temp_marc_s2_1850_column_mSO4evap.nc
# Fri Aug 17 16:49:33 +08 2018
#   variable = BNUCmNUC
#     Copying the file for BNUCmNUC
#     Appending mass_air
#     Calculating the mass rate of BNUCmNUC in each model level
#     Summing over levels
#     Renaming variable to cBNUCmNUC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cBNUCmNUC_ANN.nc
#     Removing temp_marc_s2_1850_BNUCmNUC.nc
#     Removing temp_marc_s2_1850_mass_BNUCmNUC.nc
#     Removing temp_marc_s2_1850_column_BNUCmNUC.nc
# Fri Aug 17 16:50:18 +08 2018
#   variable = CNDmACC
#     Copying the file for CNDmACC
#     Appending mass_air
#     Calculating the mass rate of CNDmACC in each model level
#     Summing over levels
#     Renaming variable to cCNDmACC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cCNDmACC_ANN.nc
#     Removing temp_marc_s2_1850_CNDmACC.nc
#     Removing temp_marc_s2_1850_mass_CNDmACC.nc
#     Removing temp_marc_s2_1850_column_CNDmACC.nc
# Fri Aug 17 16:51:04 +08 2018
#   variable = CNDmAIT
#     Copying the file for CNDmAIT
#     Appending mass_air
#     Calculating the mass rate of CNDmAIT in each model level
#     Summing over levels
#     Renaming variable to cCNDmAIT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cCNDmAIT_ANN.nc
#     Removing temp_marc_s2_1850_CNDmAIT.nc
#     Removing temp_marc_s2_1850_mass_CNDmAIT.nc
#     Removing temp_marc_s2_1850_column_CNDmAIT.nc
# Fri Aug 17 16:51:50 +08 2018
#   variable = CNDmNUC
#     Copying the file for CNDmNUC
#     Appending mass_air
#     Calculating the mass rate of CNDmNUC in each model level
#     Summing over levels
#     Renaming variable to cCNDmNUC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cCNDmNUC_ANN.nc
#     Removing temp_marc_s2_1850_CNDmNUC.nc
#     Removing temp_marc_s2_1850_mass_CNDmNUC.nc
#     Removing temp_marc_s2_1850_column_CNDmNUC.nc
# Fri Aug 17 16:52:34 +08 2018
#   variable = CNDmMOS
#     Copying the file for CNDmMOS
#     Appending mass_air
#     Calculating the mass rate of CNDmMOS in each model level
#     Summing over levels
#     Renaming variable to cCNDmMOS
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cCNDmMOS_ANN.nc
#     Removing temp_marc_s2_1850_CNDmMOS.nc
#     Removing temp_marc_s2_1850_mass_CNDmMOS.nc
#     Removing temp_marc_s2_1850_column_CNDmMOS.nc
# Fri Aug 17 16:53:26 +08 2018
#   variable = CNDmMBS
#     Copying the file for CNDmMBS
#     Appending mass_air
#     Calculating the mass rate of CNDmMBS in each model level
#     Summing over levels
#     Renaming variable to cCNDmMBS
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cCNDmMBS_ANN.nc
#     Removing temp_marc_s2_1850_CNDmMBS.nc
#     Removing temp_marc_s2_1850_mass_CNDmMBS.nc
#     Removing temp_marc_s2_1850_column_CNDmMBS.nc
# Fri Aug 17 16:54:17 +08 2018
#   variable = MVmNUC
#     Copying the file for MVmNUC
#     Appending mass_air
#     Calculating the mass rate of MVmNUC in each model level
#     Summing over levels
#     Renaming variable to cMVmNUC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cMVmNUC_ANN.nc
#     Removing temp_marc_s2_1850_MVmNUC.nc
#     Removing temp_marc_s2_1850_mass_MVmNUC.nc
#     Removing temp_marc_s2_1850_column_MVmNUC.nc
# Fri Aug 17 16:55:10 +08 2018
#   variable = MVmAIT
#     Copying the file for MVmAIT
#     Appending mass_air
#     Calculating the mass rate of MVmAIT in each model level
#     Summing over levels
#     Renaming variable to cMVmAIT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cMVmAIT_ANN.nc
#     Removing temp_marc_s2_1850_MVmAIT.nc
#     Removing temp_marc_s2_1850_mass_MVmAIT.nc
#     Removing temp_marc_s2_1850_column_MVmAIT.nc
# Fri Aug 17 16:56:08 +08 2018
#   variable = CGmNUCAC
#     Copying the file for CGmNUCAC
#     Appending mass_air
#     Calculating the mass rate of CGmNUCAC in each model level
#     Summing over levels
#     Renaming variable to cCGmNUCAC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cCGmNUCAC_ANN.nc
#     Removing temp_marc_s2_1850_CGmNUCAC.nc
#     Removing temp_marc_s2_1850_mass_CGmNUCAC.nc
#     Removing temp_marc_s2_1850_column_CGmNUCAC.nc
# Fri Aug 17 16:57:00 +08 2018
#   variable = CGmNUCAI
#     Copying the file for CGmNUCAI
#     Appending mass_air
#     Calculating the mass rate of CGmNUCAI in each model level
#     Summing over levels
#     Renaming variable to cCGmNUCAI
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cCGmNUCAI_ANN.nc
#     Removing temp_marc_s2_1850_CGmNUCAI.nc
#     Removing temp_marc_s2_1850_mass_CGmNUCAI.nc
#     Removing temp_marc_s2_1850_column_CGmNUCAI.nc
# Fri Aug 17 16:57:45 +08 2018
#   variable = CGmNUCMB
#     Copying the file for CGmNUCMB
#     Appending mass_air
#     Calculating the mass rate of CGmNUCMB in each model level
#     Summing over levels
#     Renaming variable to cCGmNUCMB
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cCGmNUCMB_ANN.nc
#     Removing temp_marc_s2_1850_CGmNUCMB.nc
#     Removing temp_marc_s2_1850_mass_CGmNUCMB.nc
#     Removing temp_marc_s2_1850_column_CGmNUCMB.nc
# Fri Aug 17 16:58:27 +08 2018
#   variable = CGmNUCMO
#     Copying the file for CGmNUCMO
#     Appending mass_air
#     Calculating the mass rate of CGmNUCMO in each model level
#     Summing over levels
#     Renaming variable to cCGmNUCMO
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cCGmNUCMO_ANN.nc
#     Removing temp_marc_s2_1850_CGmNUCMO.nc
#     Removing temp_marc_s2_1850_mass_CGmNUCMO.nc
#     Removing temp_marc_s2_1850_column_CGmNUCMO.nc
# Fri Aug 17 16:59:07 +08 2018
#   variable = CGmAITAC
#     Copying the file for CGmAITAC
#     Appending mass_air
#     Calculating the mass rate of CGmAITAC in each model level
#     Summing over levels
#     Renaming variable to cCGmAITAC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cCGmAITAC_ANN.nc
#     Removing temp_marc_s2_1850_CGmAITAC.nc
#     Removing temp_marc_s2_1850_mass_CGmAITAC.nc
#     Removing temp_marc_s2_1850_column_CGmAITAC.nc
# Fri Aug 17 16:59:55 +08 2018
#   variable = CGmAITMB
#     Copying the file for CGmAITMB
#     Appending mass_air
#     Calculating the mass rate of CGmAITMB in each model level
#     Summing over levels
#     Renaming variable to cCGmAITMB
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cCGmAITMB_ANN.nc
#     Removing temp_marc_s2_1850_CGmAITMB.nc
#     Removing temp_marc_s2_1850_mass_CGmAITMB.nc
#     Removing temp_marc_s2_1850_column_CGmAITMB.nc
# Fri Aug 17 17:00:34 +08 2018
#   variable = CGmAITMO
#     Copying the file for CGmAITMO
#     Appending mass_air
#     Calculating the mass rate of CGmAITMO in each model level
#     Summing over levels
#     Renaming variable to cCGmAITMO
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cCGmAITMO_ANN.nc
#     Removing temp_marc_s2_1850_CGmAITMO.nc
#     Removing temp_marc_s2_1850_mass_CGmAITMO.nc
#     Removing temp_marc_s2_1850_column_CGmAITMO.nc
# Fri Aug 17 17:01:17 +08 2018
#   variable = CGmACCMB
#     Copying the file for CGmACCMB
#     Appending mass_air
#     Calculating the mass rate of CGmACCMB in each model level
#     Summing over levels
#     Renaming variable to cCGmACCMB
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cCGmACCMB_ANN.nc
#     Removing temp_marc_s2_1850_CGmACCMB.nc
#     Removing temp_marc_s2_1850_mass_CGmACCMB.nc
#     Removing temp_marc_s2_1850_column_CGmACCMB.nc
# Fri Aug 17 17:02:09 +08 2018
#   variable = CGmACCMO
#     Copying the file for CGmACCMO
#     Appending mass_air
#     Calculating the mass rate of CGmACCMO in each model level
#     Summing over levels
#     Renaming variable to cCGmACCMO
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cCGmACCMO_ANN.nc
#     Removing temp_marc_s2_1850_CGmACCMO.nc
#     Removing temp_marc_s2_1850_mass_CGmACCMO.nc
#     Removing temp_marc_s2_1850_column_CGmACCMO.nc
# Fri Aug 17 17:02:57 +08 2018
#   variable = CGmOCMOS
#     Copying the file for CGmOCMOS
#     Appending mass_air
#     Calculating the mass rate of CGmOCMOS in each model level
#     Summing over levels
#     Renaming variable to cCGmOCMOS
#     Setting units and long_name
#     Calculating annual means
#     Written marc_s2_1850_cCGmOCMOS_ANN.nc
#     Removing temp_marc_s2_1850_CGmOCMOS.nc
#     Removing temp_marc_s2_1850_mass_CGmOCMOS.nc
#     Removing temp_marc_s2_1850_column_CGmOCMOS.nc
#   Removing temp_marc_s2_1850_PS.nc
#   Removing temp_marc_s2_1850_mass_air.nc
#   Removing temp_marc_s2_1850.nco
# Fri Aug 17 17:03:47 +08 2018

# %% [markdown]
# ## Derive additional variables of interest
# - Total sulfate, total OC, total BC, total dust, total sea-salt.
# - Other "derived" variables (including renamed variables for ease of reading into budget_tables_draft2017.ipynb).
# - Sum of sources and sinks for each species.

# %%
derived_variable_list = [
    # Total sulfate. Note: mode mass adjustment and coagulation balance to zero.
    'ctSUL_DRY=-mNUCDRY-mAITDRY-mACCDRY-mMOSDRY-mMBSDRY+mOIMDRY+mBIMDRY',  # dry deposition
    'ctSUL_IMP=cmNUCWET+cmAITWET+cmACCWET+cmMOSWET+cmMBSWET-cmOIMWET-cmBIMWET',  # impaction scavenging
    'ctSUL_ACT=cmNUCACT+cmAITACT+cmACCACT+cmMOSACT+cmMBSACT-cmOIMACT-cmBIMACT',  # strat. nuc. scav.
    'ctSUL_SCV=cmNUCSCV+cmAITSCV+cmACCSCV+cmMOSSCV+cmMBSSCV-cmOIMSCV-cmBIMSCV',  # conv. nuc. scav.
    'ctSUL_CND=cCNDmNUC+cCNDmAIT+cCNDmACC+cCNDmMOS+cCNDmMBS',  # H2SO4 condensation
    'ctSUL_BNUC=cBNUCmNUC',  # binary nucleation
    'ctSUL_EVAP=cmSO4evap',  # SO4 cloud evaporation
    'ctSUL_AGEsrc=cAGEmMOS+cAGEmMBS',  # aging source
    'ctSUL_SOURCE=ctSUL_CND+ctSUL_BNUC+ctSUL_EVAP+ctSUL_AGEsrc',  # sum of sources
    'ctSUL_SINK=ctSUL_DRY+ctSUL_IMP+ctSUL_ACT+ctSUL_SCV',  # sum of sinks
    # Total OC. Note: aging and coagulation balance to zero.
    'ctOC_SF=mOCSF',  # emissions (including SOA)
    'ctOC_DRY=-mOCDRY-mOIMDRY',  # dry deposition
    'ctOC_IMP=cmOCWET+cmOIMWET',  # impaction scavenging
    'ctOC_ACT=cmOCACT+cmOIMACT',  # strat. nuc. scav.
    'ctOC_SCV=cmOCSCV+cmOIMSCV',  # conv. nuc. svav.
    'ctOC_SOURCE=ctOC_SF',  # sum of sources
    'ctOC_SINK=ctOC_DRY+ctOC_IMP+ctOC_ACT+ctOC_SCV',  # sum of sinks
    # Total BC. Note: aging balances to zero.
    'ctBC_SF=mBCSF',  # emissions
    'ctBC_DRY=-mBCDRY-mBIMDRY',  # dry deposition
    'ctBC_IMP=cmBCWET+cmBIMWET',  # impaction scavenging
    'ctBC_ACT=cmBCACT+cmBIMACT',  # strat. nuc. scav.
    'ctBC_SCV=cmBCSCV+cmBIMSCV',  # conv. nuc. svav.
    'ctBC_SOURCE=ctBC_SF',  # sum of sources
    'ctBC_SINK=ctBC_DRY+ctBC_IMP+ctBC_ACT+ctBC_SCV',  # sum of sinks
    # Total dust
    'ctDST_SF=DST01SF+DST02SF+DST03SF+DST04SF',  # emissions
    'ctDST_DRY=-DST01DD-DST02DD-DST03DD-DST04DD',  # dry deposition
    'ctDST_IMP=cDST01PP+cDST02PP+cDST03PP+cDST04PP',  # impaction scavenging
    'ctDST_SOURCE=ctDST_SF',  # sum of sources
    'ctDST_SINK=ctDST_DRY+ctDST_IMP',  # sum of sinks
    # Total sea-salt
    'ctSSLT_SF=SSLT01SF+SSLT02SF+SSLT03SF+SSLT04SF',  # emissions
    'ctSSLT_DRY=-SSLT01DD-SSLT02DD-SSLT03DD-SSLT04DD',  # dry deposition
    'ctSSLT_IMP=cSSLT01PP+cSSLT02PP+cSSLT03PP+cSSLT04PP',  # impaction scavenging
    'ctSSLT_SOURCE=ctSSLT_SF',  # sum of sources
    'ctSSLT_SINK=ctSSLT_DRY+ctSSLT_IMP',  # sum of sinks
    # ACC
    'cACC_DRY=-mACCDRY',  # dry deposition -> sink
    'cACC_IMP=cmACCWET',  # impaction scavenging -> sink
    'cACC_ACT=cmACCACT',  # strat. nuc. scav. -> sink
    'cACC_SCV=cmACCSCV',  # conv. nuc. scav. -> sink
    'cACC_CND=cCNDmACC',  # H2SO4 condensation -> source
    'cACC_EVAP=cmSO4evap',  # SO4 cloud evaporation -> source
    'cACC_ADJsrc=-cMVmAIT',  # mode mass adjustment source
    'cACC_CGsrc=-cCGmNUCAI-cCGmAITAC',  # coagulation source
    'cACC_CGsnk=cCGmACCMB+cCGmACCMO',  # coagulation sink
    'cACC_SOURCE=cACC_CND+cACC_EVAP+cACC_ADJsrc+cACC_CGsrc',  # sum of sources
    'cACC_SINK=cACC_DRY+cACC_IMP+cACC_ACT+cACC_SCV+cACC_CGsnk',  # sum of sinks
    # AIT
    'cAIT_DRY=-mAITDRY',  # dry deposition -> sink
    'cAIT_IMP=cmAITWET',  # impaction scavenging -> sink
    'cAIT_ACT=cmAITACT',  # strat. nuc. scav. -> sink
    'cAIT_SCV=cmAITSCV',  # conv. nuc. scav. -> sink
    'cAIT_CND=cCNDmAIT',  # H2SO4 condensation -> source
    'cAIT_ADJsrc=-cMVmNUC',  # mode mass adjustment source
    'cAIT_ADJsnk=cMVmAIT',  # mode mass adjustment sink
    'cAIT_CGsrc=-cCGmNUCAI',  # coagulation source
    'cAIT_CGsnk=cCGmAITAC+cCGmAITMB+cCGmAITMO',  # coagulation sink
    'cAIT_SOURCE=cAIT_CND+cAIT_ADJsrc+cAIT_CGsrc',  # sum of sources
    'cAIT_SINK=cAIT_DRY+cAIT_IMP+cAIT_ACT+cAIT_SCV+cAIT_ADJsnk+cAIT_CGsnk',  # sum of sinks
    # NUC
    'cNUC_DRY=-mNUCDRY',  # dry deposition -> sink
    'cNUC_IMP=cmNUCWET',  # impaction scavenging -> sink
    'cNUC_ACT=cmNUCACT',  # strat. nuc. scav. -> sink
    'cNUC_SCV=cmNUCSCV',  # conv. nuc. scav. -> sink
    'cNUC_CND=cCNDmNUC',  # H2SO4 condensation -> source
    'cNUC_BNUC=cBNUCmNUC',  # binary nucleation -> source
    'cNUC_ADJsnk=cMVmNUC',  # mode mass adjustment sink
    'cNUC_CGsnk=cCGmNUCAI+cCGmNUCAC+cCGmNUCMB+cCGmNUCMO',  # coagulation sink
    'cNUC_SOURCE=cNUC_CND+cNUC_BNUC',  # sum of sources
    'cNUC_SINK=cNUC_DRY+cNUC_IMP+cNUC_ACT+cNUC_SCV+cNUC_ADJsnk+cNUC_CGsnk',  # sum of sinks
    # OC
    'cOC_SF=mOCSF',  # emissions (including SOA)
    'cOC_DRY=-mOCDRY',  # dry deposition -> sink
    'cOC_IMP=cmOCWET',  # impaction scavenging -> sink
    'cOC_ACT=cmOCACT',  # strat. nuc. scav. -> sink
    'cOC_SCV=cmOCSCV',  # conv. nuc. scav. -> sink
    'cOC_AGEsnk=cAGEmOC',  # aging sink
    'cOC_CGsnk=cCGmOCMOS',  # coagulation sink
    'cOC_SOURCE=cOC_SF',  # sum of sources
    'cOC_SINK=cOC_DRY+cOC_IMP+cOC_ACT+cOC_SCV+cOC_AGEsnk+cOC_CGsnk',  # sum of sinks
    # MOS
    'cMOS_DRY=-mMOSDRY',  # dry deposition -> sink
    'cMOS_IMP=cmMOSWET',  # impaction scavenging -> sink
    'cMOS_ACT=cmMOSACT',  # strat. nuc. scav. -> sink
    'cMOS_SCV=cmMOSSCV',  # conv. nuc. scav. -> sink
    'cMOS_CND=cCNDmMOS',  # H2SO4 condensation -> source
    'cMOS_AGEsrc=cAGEmMOS-cAGEmOC',  # aging source
    'cMOS_CGsrc=-cCGmNUCMO-cCGmAITMO-cCGmACCMO-cCGmOCMOS',  # coagulation source
    'cMOS_SOURCE=cMOS_CND+cMOS_AGEsrc+cMOS_CGsrc',  # sum of sources
    'cMOS_SINK=cMOS_DRY+cMOS_IMP+cMOS_ACT+cMOS_SCV',  # sum of sinks
    # OIM
    'cOIM_DRY=-mOIMDRY',  # dry deposition -> sink
    'cOIM_IMP=cmOIMWET',  # impaction scavenging -> sink
    'cOIM_ACT=cmOIMACT',  # strat. nuc. scav. -> sink
    'cOIM_SCV=cmOIMSCV',  # conv. nuc. scav. -> sink
    'cOIM_AGEsrc=-cAGEmOC',  # aging source
    'cOIM_CGsrc=-cCGmOCMOS',  # coagulation source
    'cOIM_SOURCE=cOIM_AGEsrc+cOIM_CGsrc',  # sum of sources
    'cOIM_SINK=cOIM_DRY+cOIM_IMP+cOIM_ACT+cOIM_SCV',  # sum of sinks
    # SIMOS: sulfate in MOS
    'cSIMOS_DRY=cMOS_DRY-cOIM_DRY',  # dry deposition -> sink
    'cSIMOS_IMP=cMOS_IMP-cOIM_IMP',  # impaction scavenging -> sink
    'cSIMOS_ACT=cMOS_ACT-cOIM_ACT',  # strat. nuc. scav. -> sink
    'cSIMOS_SCV=cMOS_SCV-cOIM_SCV',  # conv. nuc. scav. -> sink
    'cSIMOS_CND=cMOS_CND',  # H2SO4 condensation -> source
    'cSIMOS_AGEsrc=cAGEmMOS',  # aging source
    'cSIMOS_CGsrc=-cCGmNUCMO-cCGmAITMO-cCGmACCMO',  # coagulation source
    'cSIMOS_SOURCE=cSIMOS_CND+cSIMOS_AGEsrc+cSIMOS_CGsrc',  # sum of sources
    'cSIMOS_SINK=cSIMOS_DRY+cSIMOS_IMP+cSIMOS_ACT+cSIMOS_SCV',  # sum of sinks
    # BC
    'cBC_SF=mBCSF',  # emissions (including SOA)
    'cBC_DRY=-mBCDRY',  # dry deposition -> sink
    'cBC_IMP=cmBCWET',  # impaction scavenging -> sink
    'cBC_ACT=cmBCACT',  # strat. nuc. scav. -> sink
    'cBC_SCV=cmBCSCV',  # conv. nuc. scav. -> sink
    'cBC_AGEsnk=cAGEmBC',  # aging sink
    'cBC_SOURCE=cBC_SF',  # sum of sources
    'cBC_SINK=cBC_DRY+cBC_IMP+cBC_ACT+cBC_SCV+cBC_AGEsnk',  # sum of sinks
    # MBS
    'cMBS_DRY=-mMBSDRY',  # dry deposition -> sink
    'cMBS_IMP=cmMBSWET',  # impaction scavenging -> sink
    'cMBS_ACT=cmMBSACT',  # strat. nuc. scav. -> sink
    'cMBS_SCV=cmMBSSCV',  # conv. nuc. scav. -> sink
    'cMBS_CND=cCNDmMBS',  # H2SO4 condensation -> source
    'cMBS_AGEsrc=cAGEmMBS-cAGEmBC',  # aging source
    'cMBS_CGsrc=-cCGmNUCMB-cCGmAITMB-cCGmACCMB',  # coagulation source
    'cMBS_SOURCE=cMBS_CND+cMBS_AGEsrc+cMBS_CGsrc',  # sum of sources
    'cMBS_SINK=cMBS_DRY+cMBS_IMP+cMBS_ACT+cMBS_SCV',  # sum of sinks
    # BIM
    'cBIM_DRY=-mBIMDRY',  # dry deposition -> sink
    'cBIM_IMP=cmBIMWET',  # impaction scavenging -> sink
    'cBIM_ACT=cmBIMACT',  # strat. nuc. scav. -> sink
    'cBIM_SCV=cmBIMSCV',  # conv. nuc. scav. -> sink
    'cBIM_AGEsrc=-cAGEmBC',  # aging source
    'cBIM_SOURCE=cBIM_AGEsrc',  # sum of sources
    'cBIM_SINK=cBIM_DRY+cBIM_IMP+cBIM_ACT+cBIM_SCV',  # sum of sinks
    # SIMBS: sulfate in MBS
    'cSIMBS_DRY=cMBS_DRY-cBIM_DRY',  # dry deposition -> sink
    'cSIMBS_IMP=cMBS_IMP-cBIM_IMP',  # impaction scavenging -> sink
    'cSIMBS_ACT=cMBS_ACT-cBIM_ACT',  # strat. nuc. scav. -> sink
    'cSIMBS_SCV=cMBS_SCV-cBIM_SCV',  # conv. nuc. scav. -> sink
    'cSIMBS_CND=cMBS_CND',  # H2SO4 condensation -> source
    'cSIMBS_AGEsrc=cAGEmMBS',  # aging source
    'cSIMBS_CGsrc=cMBS_CGsrc',  # coagulation source
    'cSIMBS_SOURCE=cSIMBS_CND+cSIMBS_AGEsrc+cSIMBS_CGsrc',  # sum of sources
    'cSIMBS_SINK=cSIMBS_DRY+cSIMBS_IMP+cSIMBS_ACT+cSIMBS_SCV',  # sum of sinks
    ]

# %%
for year in ['2000', '1850']:  # loop over year-2000 and year-1850
    for derived_variable in derived_variable_list:  # loop over variables to derive
        print('{}, {}'.format(derived_variable, year))
        variable_list = re.split('\=\-|\=|\+|\-', derived_variable)  # list of variables in derived variable
        # Merge input files
        in_filename_list = []
        for variable in variable_list[1:]:
            in_filename_list.append('{}/marc_s2_{}_{}_ANN.nc'.format(out_dir, year, variable))
        merge_filename = '{}/temp_{}_merge_ANN.nc'.format(out_dir, year)
        if len(in_filename_list) == 1:  # merge case 1: 1 input file
            ! cp {in_filename_list[0]} {merge_filename}
        elif len(in_filename_list) == 2:  # merge case 2: 2 input files
            ! cdo -s merge {in_filename_list[0]} {in_filename_list[1]} \
                {merge_filename} >/dev/null 2>/dev/null
        elif len(in_filename_list) == 3:  # merge case 3: 3 input files
            ! cdo -s merge {in_filename_list[0]} {in_filename_list[1]} {in_filename_list[2]} \
                {merge_filename} >/dev/null 2>/dev/null
        elif len(in_filename_list) == 4:  # merge case 4: 4 input files
            ! cdo -s merge {in_filename_list[0]} {in_filename_list[1]} {in_filename_list[2]} \
                {in_filename_list[3]} \
                {merge_filename} >/dev/null 2>/dev/null
        elif len(in_filename_list) == 5:  # merge case 5: 5 input files
            ! cdo -s merge {in_filename_list[0]} {in_filename_list[1]} {in_filename_list[2]} \
                {in_filename_list[3]} {in_filename_list[4]} \
                {merge_filename} >/dev/null 2>/dev/null
        elif len(in_filename_list) == 6:  # merge case 6: 6 input files
            ! cdo -s merge {in_filename_list[0]} {in_filename_list[1]} {in_filename_list[2]} \
                {in_filename_list[3]} {in_filename_list[4]} {in_filename_list[5]} \
                {merge_filename} >/dev/null 2>/dev/null
        elif len(in_filename_list) == 7:  # merge case 7: 7 input files
            ! cdo -s merge {in_filename_list[0]} {in_filename_list[1]} {in_filename_list[2]} \
                {in_filename_list[3]} {in_filename_list[4]} {in_filename_list[5]} \
                {in_filename_list[6]} {merge_filename} >/dev/null 2>/dev/null
        # Calculate derived variable
        out_filename = '{}/marc_s2_{}_{}_ANN.nc'.format(out_dir, year, variable_list[0])
        try:
            os.remove(out_filename)
        except FileNotFoundError:
            pass
        ! cdo -s expr,'{derived_variable}' {merge_filename} {out_filename}
        if os.path.isfile(out_filename):
            print('  Written {}'.format(out_filename.split('/')[-1]))
        # Remove temporary file
        for filename in [merge_filename, ]:
            print('  Removing {}'.format(filename.split('/')[-1]))
            os.remove(filename)
! date
# Out:
# ctSUL_DRY=-mNUCDRY-mAITDRY-mACCDRY-mMOSDRY-mMBSDRY+mOIMDRY+mBIMDRY, 2000
#   Written marc_s2_2000_ctSUL_DRY_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSUL_IMP=cmNUCWET+cmAITWET+cmACCWET+cmMOSWET+cmMBSWET-cmOIMWET-cmBIMWET, 2000
#   Written marc_s2_2000_ctSUL_IMP_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSUL_ACT=cmNUCACT+cmAITACT+cmACCACT+cmMOSACT+cmMBSACT-cmOIMACT-cmBIMACT, 2000
#   Written marc_s2_2000_ctSUL_ACT_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSUL_SCV=cmNUCSCV+cmAITSCV+cmACCSCV+cmMOSSCV+cmMBSSCV-cmOIMSCV-cmBIMSCV, 2000
#   Written marc_s2_2000_ctSUL_SCV_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSUL_CND=cCNDmNUC+cCNDmAIT+cCNDmACC+cCNDmMOS+cCNDmMBS, 2000
#   Written marc_s2_2000_ctSUL_CND_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSUL_BNUC=cBNUCmNUC, 2000
#   Written marc_s2_2000_ctSUL_BNUC_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSUL_EVAP=cmSO4evap, 2000
#   Written marc_s2_2000_ctSUL_EVAP_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSUL_AGEsrc=cAGEmMOS+cAGEmMBS, 2000
#   Written marc_s2_2000_ctSUL_AGEsrc_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSUL_SOURCE=ctSUL_CND+ctSUL_BNUC+ctSUL_EVAP+ctSUL_AGEsrc, 2000
#   Written marc_s2_2000_ctSUL_SOURCE_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSUL_SINK=ctSUL_DRY+ctSUL_IMP+ctSUL_ACT+ctSUL_SCV, 2000
#   Written marc_s2_2000_ctSUL_SINK_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctOC_SF=mOCSF, 2000
#   Written marc_s2_2000_ctOC_SF_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctOC_DRY=-mOCDRY-mOIMDRY, 2000
#   Written marc_s2_2000_ctOC_DRY_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctOC_IMP=cmOCWET+cmOIMWET, 2000
#   Written marc_s2_2000_ctOC_IMP_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctOC_ACT=cmOCACT+cmOIMACT, 2000
#   Written marc_s2_2000_ctOC_ACT_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctOC_SCV=cmOCSCV+cmOIMSCV, 2000
#   Written marc_s2_2000_ctOC_SCV_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctOC_SOURCE=ctOC_SF, 2000
#   Written marc_s2_2000_ctOC_SOURCE_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctOC_SINK=ctOC_DRY+ctOC_IMP+ctOC_ACT+ctOC_SCV, 2000
#   Written marc_s2_2000_ctOC_SINK_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctBC_SF=mBCSF, 2000
#   Written marc_s2_2000_ctBC_SF_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctBC_DRY=-mBCDRY-mBIMDRY, 2000
#   Written marc_s2_2000_ctBC_DRY_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctBC_IMP=cmBCWET+cmBIMWET, 2000
#   Written marc_s2_2000_ctBC_IMP_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctBC_ACT=cmBCACT+cmBIMACT, 2000
#   Written marc_s2_2000_ctBC_ACT_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctBC_SCV=cmBCSCV+cmBIMSCV, 2000
#   Written marc_s2_2000_ctBC_SCV_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctBC_SOURCE=ctBC_SF, 2000
#   Written marc_s2_2000_ctBC_SOURCE_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctBC_SINK=ctBC_DRY+ctBC_IMP+ctBC_ACT+ctBC_SCV, 2000
#   Written marc_s2_2000_ctBC_SINK_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctDST_SF=DST01SF+DST02SF+DST03SF+DST04SF, 2000
#   Written marc_s2_2000_ctDST_SF_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctDST_DRY=-DST01DD-DST02DD-DST03DD-DST04DD, 2000
#   Written marc_s2_2000_ctDST_DRY_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctDST_IMP=cDST01PP+cDST02PP+cDST03PP+cDST04PP, 2000
#   Written marc_s2_2000_ctDST_IMP_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctDST_SOURCE=ctDST_SF, 2000
#   Written marc_s2_2000_ctDST_SOURCE_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctDST_SINK=ctDST_DRY+ctDST_IMP, 2000
#   Written marc_s2_2000_ctDST_SINK_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSSLT_SF=SSLT01SF+SSLT02SF+SSLT03SF+SSLT04SF, 2000
#   Written marc_s2_2000_ctSSLT_SF_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSSLT_DRY=-SSLT01DD-SSLT02DD-SSLT03DD-SSLT04DD, 2000
#   Written marc_s2_2000_ctSSLT_DRY_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSSLT_IMP=cSSLT01PP+cSSLT02PP+cSSLT03PP+cSSLT04PP, 2000
#   Written marc_s2_2000_ctSSLT_IMP_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSSLT_SOURCE=ctSSLT_SF, 2000
#   Written marc_s2_2000_ctSSLT_SOURCE_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSSLT_SINK=ctSSLT_DRY+ctSSLT_IMP, 2000
#   Written marc_s2_2000_ctSSLT_SINK_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cACC_DRY=-mACCDRY, 2000
#   Written marc_s2_2000_cACC_DRY_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cACC_IMP=cmACCWET, 2000
#   Written marc_s2_2000_cACC_IMP_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cACC_ACT=cmACCACT, 2000
#   Written marc_s2_2000_cACC_ACT_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cACC_SCV=cmACCSCV, 2000
#   Written marc_s2_2000_cACC_SCV_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cACC_CND=cCNDmACC, 2000
#   Written marc_s2_2000_cACC_CND_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cACC_EVAP=cmSO4evap, 2000
#   Written marc_s2_2000_cACC_EVAP_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cACC_ADJsrc=-cMVmAIT, 2000
#   Written marc_s2_2000_cACC_ADJsrc_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cACC_CGsrc=-cCGmNUCAI-cCGmAITAC, 2000
#   Written marc_s2_2000_cACC_CGsrc_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cACC_CGsnk=cCGmACCMB+cCGmACCMO, 2000
#   Written marc_s2_2000_cACC_CGsnk_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cACC_SOURCE=cACC_CND+cACC_EVAP+cACC_ADJsrc+cACC_CGsrc, 2000
#   Written marc_s2_2000_cACC_SOURCE_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cACC_SINK=cACC_DRY+cACC_IMP+cACC_ACT+cACC_SCV+cACC_CGsnk, 2000
#   Written marc_s2_2000_cACC_SINK_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cAIT_DRY=-mAITDRY, 2000
#   Written marc_s2_2000_cAIT_DRY_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cAIT_IMP=cmAITWET, 2000
#   Written marc_s2_2000_cAIT_IMP_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cAIT_ACT=cmAITACT, 2000
#   Written marc_s2_2000_cAIT_ACT_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cAIT_SCV=cmAITSCV, 2000
#   Written marc_s2_2000_cAIT_SCV_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cAIT_CND=cCNDmAIT, 2000
#   Written marc_s2_2000_cAIT_CND_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cAIT_ADJsrc=-cMVmNUC, 2000
#   Written marc_s2_2000_cAIT_ADJsrc_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cAIT_ADJsnk=cMVmAIT, 2000
#   Written marc_s2_2000_cAIT_ADJsnk_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cAIT_CGsrc=-cCGmNUCAI, 2000
#   Written marc_s2_2000_cAIT_CGsrc_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cAIT_CGsnk=cCGmAITAC+cCGmAITMB+cCGmAITMO, 2000
#   Written marc_s2_2000_cAIT_CGsnk_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cAIT_SOURCE=cAIT_CND+cAIT_ADJsrc+cAIT_CGsrc, 2000
#   Written marc_s2_2000_cAIT_SOURCE_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cAIT_SINK=cAIT_DRY+cAIT_IMP+cAIT_ACT+cAIT_SCV+cAIT_ADJsnk+cAIT_CGsnk, 2000
#   Written marc_s2_2000_cAIT_SINK_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cNUC_DRY=-mNUCDRY, 2000
#   Written marc_s2_2000_cNUC_DRY_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cNUC_IMP=cmNUCWET, 2000
#   Written marc_s2_2000_cNUC_IMP_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cNUC_ACT=cmNUCACT, 2000
#   Written marc_s2_2000_cNUC_ACT_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cNUC_SCV=cmNUCSCV, 2000
#   Written marc_s2_2000_cNUC_SCV_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cNUC_CND=cCNDmNUC, 2000
#   Written marc_s2_2000_cNUC_CND_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cNUC_BNUC=cBNUCmNUC, 2000
#   Written marc_s2_2000_cNUC_BNUC_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cNUC_ADJsnk=cMVmNUC, 2000
#   Written marc_s2_2000_cNUC_ADJsnk_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cNUC_CGsnk=cCGmNUCAI+cCGmNUCAC+cCGmNUCMB+cCGmNUCMO, 2000
#   Written marc_s2_2000_cNUC_CGsnk_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cNUC_SOURCE=cNUC_CND+cNUC_BNUC, 2000
#   Written marc_s2_2000_cNUC_SOURCE_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cNUC_SINK=cNUC_DRY+cNUC_IMP+cNUC_ACT+cNUC_SCV+cNUC_ADJsnk+cNUC_CGsnk, 2000
#   Written marc_s2_2000_cNUC_SINK_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cOC_SF=mOCSF, 2000
#   Written marc_s2_2000_cOC_SF_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cOC_DRY=-mOCDRY, 2000
#   Written marc_s2_2000_cOC_DRY_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cOC_IMP=cmOCWET, 2000
#   Written marc_s2_2000_cOC_IMP_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cOC_ACT=cmOCACT, 2000
#   Written marc_s2_2000_cOC_ACT_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cOC_SCV=cmOCSCV, 2000
#   Written marc_s2_2000_cOC_SCV_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cOC_AGEsnk=cAGEmOC, 2000
#   Written marc_s2_2000_cOC_AGEsnk_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cOC_CGsnk=cCGmOCMOS, 2000
#   Written marc_s2_2000_cOC_CGsnk_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cOC_SOURCE=cOC_SF, 2000
#   Written marc_s2_2000_cOC_SOURCE_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cOC_SINK=cOC_DRY+cOC_IMP+cOC_ACT+cOC_SCV+cOC_AGEsnk+cOC_CGsnk, 2000
#   Written marc_s2_2000_cOC_SINK_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cMOS_DRY=-mMOSDRY, 2000
#   Written marc_s2_2000_cMOS_DRY_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cMOS_IMP=cmMOSWET, 2000
#   Written marc_s2_2000_cMOS_IMP_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cMOS_ACT=cmMOSACT, 2000
#   Written marc_s2_2000_cMOS_ACT_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cMOS_SCV=cmMOSSCV, 2000
#   Written marc_s2_2000_cMOS_SCV_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cMOS_CND=cCNDmMOS, 2000
#   Written marc_s2_2000_cMOS_CND_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cMOS_AGEsrc=cAGEmMOS-cAGEmOC, 2000
#   Written marc_s2_2000_cMOS_AGEsrc_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cMOS_CGsrc=-cCGmNUCMO-cCGmAITMO-cCGmACCMO-cCGmOCMOS, 2000
#   Written marc_s2_2000_cMOS_CGsrc_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cMOS_SOURCE=cMOS_CND+cMOS_AGEsrc+cMOS_CGsrc, 2000
#   Written marc_s2_2000_cMOS_SOURCE_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cMOS_SINK=cMOS_DRY+cMOS_IMP+cMOS_ACT+cMOS_SCV, 2000
#   Written marc_s2_2000_cMOS_SINK_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cOIM_DRY=-mOIMDRY, 2000
#   Written marc_s2_2000_cOIM_DRY_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cOIM_IMP=cmOIMWET, 2000
#   Written marc_s2_2000_cOIM_IMP_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cOIM_ACT=cmOIMACT, 2000
#   Written marc_s2_2000_cOIM_ACT_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cOIM_SCV=cmOIMSCV, 2000
#   Written marc_s2_2000_cOIM_SCV_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cOIM_AGEsrc=-cAGEmOC, 2000
#   Written marc_s2_2000_cOIM_AGEsrc_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cOIM_CGsrc=-cCGmOCMOS, 2000
#   Written marc_s2_2000_cOIM_CGsrc_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cOIM_SOURCE=cOIM_AGEsrc+cOIM_CGsrc, 2000
#   Written marc_s2_2000_cOIM_SOURCE_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cOIM_SINK=cOIM_DRY+cOIM_IMP+cOIM_ACT+cOIM_SCV, 2000
#   Written marc_s2_2000_cOIM_SINK_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cSIMOS_DRY=cMOS_DRY-cOIM_DRY, 2000
#   Written marc_s2_2000_cSIMOS_DRY_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cSIMOS_IMP=cMOS_IMP-cOIM_IMP, 2000
#   Written marc_s2_2000_cSIMOS_IMP_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cSIMOS_ACT=cMOS_ACT-cOIM_ACT, 2000
#   Written marc_s2_2000_cSIMOS_ACT_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cSIMOS_SCV=cMOS_SCV-cOIM_SCV, 2000
#   Written marc_s2_2000_cSIMOS_SCV_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cSIMOS_CND=cMOS_CND, 2000
#   Written marc_s2_2000_cSIMOS_CND_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cSIMOS_AGEsrc=cAGEmMOS, 2000
#   Written marc_s2_2000_cSIMOS_AGEsrc_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cSIMOS_CGsrc=-cCGmNUCMO-cCGmAITMO-cCGmACCMO, 2000
#   Written marc_s2_2000_cSIMOS_CGsrc_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cSIMOS_SOURCE=cSIMOS_CND+cSIMOS_AGEsrc+cSIMOS_CGsrc, 2000
#   Written marc_s2_2000_cSIMOS_SOURCE_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cSIMOS_SINK=cSIMOS_DRY+cSIMOS_IMP+cSIMOS_ACT+cSIMOS_SCV, 2000
#   Written marc_s2_2000_cSIMOS_SINK_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cBC_SF=mBCSF, 2000
#   Written marc_s2_2000_cBC_SF_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cBC_DRY=-mBCDRY, 2000
#   Written marc_s2_2000_cBC_DRY_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cBC_IMP=cmBCWET, 2000
#   Written marc_s2_2000_cBC_IMP_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cBC_ACT=cmBCACT, 2000
#   Written marc_s2_2000_cBC_ACT_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cBC_SCV=cmBCSCV, 2000
#   Written marc_s2_2000_cBC_SCV_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cBC_AGEsnk=cAGEmBC, 2000
#   Written marc_s2_2000_cBC_AGEsnk_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cBC_SOURCE=cBC_SF, 2000
#   Written marc_s2_2000_cBC_SOURCE_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cBC_SINK=cBC_DRY+cBC_IMP+cBC_ACT+cBC_SCV+cBC_AGEsnk, 2000
#   Written marc_s2_2000_cBC_SINK_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cMBS_DRY=-mMBSDRY, 2000
#   Written marc_s2_2000_cMBS_DRY_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cMBS_IMP=cmMBSWET, 2000
#   Written marc_s2_2000_cMBS_IMP_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cMBS_ACT=cmMBSACT, 2000
#   Written marc_s2_2000_cMBS_ACT_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cMBS_SCV=cmMBSSCV, 2000
#   Written marc_s2_2000_cMBS_SCV_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cMBS_CND=cCNDmMBS, 2000
#   Written marc_s2_2000_cMBS_CND_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cMBS_AGEsrc=cAGEmMBS-cAGEmBC, 2000
#   Written marc_s2_2000_cMBS_AGEsrc_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cMBS_CGsrc=-cCGmNUCMB-cCGmAITMB-cCGmACCMB, 2000
#   Written marc_s2_2000_cMBS_CGsrc_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cMBS_SOURCE=cMBS_CND+cMBS_AGEsrc+cMBS_CGsrc, 2000
#   Written marc_s2_2000_cMBS_SOURCE_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cMBS_SINK=cMBS_DRY+cMBS_IMP+cMBS_ACT+cMBS_SCV, 2000
#   Written marc_s2_2000_cMBS_SINK_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cBIM_DRY=-mBIMDRY, 2000
#   Written marc_s2_2000_cBIM_DRY_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cBIM_IMP=cmBIMWET, 2000
#   Written marc_s2_2000_cBIM_IMP_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cBIM_ACT=cmBIMACT, 2000
#   Written marc_s2_2000_cBIM_ACT_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cBIM_SCV=cmBIMSCV, 2000
#   Written marc_s2_2000_cBIM_SCV_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cBIM_AGEsrc=-cAGEmBC, 2000
#   Written marc_s2_2000_cBIM_AGEsrc_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cBIM_SOURCE=cBIM_AGEsrc, 2000
#   Written marc_s2_2000_cBIM_SOURCE_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cBIM_SINK=cBIM_DRY+cBIM_IMP+cBIM_ACT+cBIM_SCV, 2000
#   Written marc_s2_2000_cBIM_SINK_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cSIMBS_DRY=cMBS_DRY-cBIM_DRY, 2000
#   Written marc_s2_2000_cSIMBS_DRY_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cSIMBS_IMP=cMBS_IMP-cBIM_IMP, 2000
#   Written marc_s2_2000_cSIMBS_IMP_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cSIMBS_ACT=cMBS_ACT-cBIM_ACT, 2000
#   Written marc_s2_2000_cSIMBS_ACT_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cSIMBS_SCV=cMBS_SCV-cBIM_SCV, 2000
#   Written marc_s2_2000_cSIMBS_SCV_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cSIMBS_CND=cMBS_CND, 2000
#   Written marc_s2_2000_cSIMBS_CND_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cSIMBS_AGEsrc=cAGEmMBS, 2000
#   Written marc_s2_2000_cSIMBS_AGEsrc_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cSIMBS_CGsrc=cMBS_CGsrc, 2000
#   Written marc_s2_2000_cSIMBS_CGsrc_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cSIMBS_SOURCE=cSIMBS_CND+cSIMBS_AGEsrc+cSIMBS_CGsrc, 2000
#   Written marc_s2_2000_cSIMBS_SOURCE_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# cSIMBS_SINK=cSIMBS_DRY+cSIMBS_IMP+cSIMBS_ACT+cSIMBS_SCV, 2000
#   Written marc_s2_2000_cSIMBS_SINK_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSUL_DRY=-mNUCDRY-mAITDRY-mACCDRY-mMOSDRY-mMBSDRY+mOIMDRY+mBIMDRY, 1850
#   Written marc_s2_1850_ctSUL_DRY_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSUL_IMP=cmNUCWET+cmAITWET+cmACCWET+cmMOSWET+cmMBSWET-cmOIMWET-cmBIMWET, 1850
#   Written marc_s2_1850_ctSUL_IMP_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSUL_ACT=cmNUCACT+cmAITACT+cmACCACT+cmMOSACT+cmMBSACT-cmOIMACT-cmBIMACT, 1850
#   Written marc_s2_1850_ctSUL_ACT_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSUL_SCV=cmNUCSCV+cmAITSCV+cmACCSCV+cmMOSSCV+cmMBSSCV-cmOIMSCV-cmBIMSCV, 1850
#   Written marc_s2_1850_ctSUL_SCV_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSUL_CND=cCNDmNUC+cCNDmAIT+cCNDmACC+cCNDmMOS+cCNDmMBS, 1850
#   Written marc_s2_1850_ctSUL_CND_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSUL_BNUC=cBNUCmNUC, 1850
#   Written marc_s2_1850_ctSUL_BNUC_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSUL_EVAP=cmSO4evap, 1850
#   Written marc_s2_1850_ctSUL_EVAP_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSUL_AGEsrc=cAGEmMOS+cAGEmMBS, 1850
#   Written marc_s2_1850_ctSUL_AGEsrc_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSUL_SOURCE=ctSUL_CND+ctSUL_BNUC+ctSUL_EVAP+ctSUL_AGEsrc, 1850
#   Written marc_s2_1850_ctSUL_SOURCE_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSUL_SINK=ctSUL_DRY+ctSUL_IMP+ctSUL_ACT+ctSUL_SCV, 1850
#   Written marc_s2_1850_ctSUL_SINK_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctOC_SF=mOCSF, 1850
#   Written marc_s2_1850_ctOC_SF_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctOC_DRY=-mOCDRY-mOIMDRY, 1850
#   Written marc_s2_1850_ctOC_DRY_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctOC_IMP=cmOCWET+cmOIMWET, 1850
#   Written marc_s2_1850_ctOC_IMP_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctOC_ACT=cmOCACT+cmOIMACT, 1850
#   Written marc_s2_1850_ctOC_ACT_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctOC_SCV=cmOCSCV+cmOIMSCV, 1850
#   Written marc_s2_1850_ctOC_SCV_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctOC_SOURCE=ctOC_SF, 1850
#   Written marc_s2_1850_ctOC_SOURCE_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctOC_SINK=ctOC_DRY+ctOC_IMP+ctOC_ACT+ctOC_SCV, 1850
#   Written marc_s2_1850_ctOC_SINK_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctBC_SF=mBCSF, 1850
#   Written marc_s2_1850_ctBC_SF_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctBC_DRY=-mBCDRY-mBIMDRY, 1850
#   Written marc_s2_1850_ctBC_DRY_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctBC_IMP=cmBCWET+cmBIMWET, 1850
#   Written marc_s2_1850_ctBC_IMP_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctBC_ACT=cmBCACT+cmBIMACT, 1850
#   Written marc_s2_1850_ctBC_ACT_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctBC_SCV=cmBCSCV+cmBIMSCV, 1850
#   Written marc_s2_1850_ctBC_SCV_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctBC_SOURCE=ctBC_SF, 1850
#   Written marc_s2_1850_ctBC_SOURCE_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctBC_SINK=ctBC_DRY+ctBC_IMP+ctBC_ACT+ctBC_SCV, 1850
#   Written marc_s2_1850_ctBC_SINK_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctDST_SF=DST01SF+DST02SF+DST03SF+DST04SF, 1850
#   Written marc_s2_1850_ctDST_SF_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctDST_DRY=-DST01DD-DST02DD-DST03DD-DST04DD, 1850
#   Written marc_s2_1850_ctDST_DRY_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctDST_IMP=cDST01PP+cDST02PP+cDST03PP+cDST04PP, 1850
#   Written marc_s2_1850_ctDST_IMP_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctDST_SOURCE=ctDST_SF, 1850
#   Written marc_s2_1850_ctDST_SOURCE_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctDST_SINK=ctDST_DRY+ctDST_IMP, 1850
#   Written marc_s2_1850_ctDST_SINK_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSSLT_SF=SSLT01SF+SSLT02SF+SSLT03SF+SSLT04SF, 1850
#   Written marc_s2_1850_ctSSLT_SF_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSSLT_DRY=-SSLT01DD-SSLT02DD-SSLT03DD-SSLT04DD, 1850
#   Written marc_s2_1850_ctSSLT_DRY_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSSLT_IMP=cSSLT01PP+cSSLT02PP+cSSLT03PP+cSSLT04PP, 1850
#   Written marc_s2_1850_ctSSLT_IMP_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSSLT_SOURCE=ctSSLT_SF, 1850
#   Written marc_s2_1850_ctSSLT_SOURCE_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSSLT_SINK=ctSSLT_DRY+ctSSLT_IMP, 1850
#   Written marc_s2_1850_ctSSLT_SINK_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cACC_DRY=-mACCDRY, 1850
#   Written marc_s2_1850_cACC_DRY_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cACC_IMP=cmACCWET, 1850
#   Written marc_s2_1850_cACC_IMP_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cACC_ACT=cmACCACT, 1850
#   Written marc_s2_1850_cACC_ACT_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cACC_SCV=cmACCSCV, 1850
#   Written marc_s2_1850_cACC_SCV_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cACC_CND=cCNDmACC, 1850
#   Written marc_s2_1850_cACC_CND_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cACC_EVAP=cmSO4evap, 1850
#   Written marc_s2_1850_cACC_EVAP_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cACC_ADJsrc=-cMVmAIT, 1850
#   Written marc_s2_1850_cACC_ADJsrc_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cACC_CGsrc=-cCGmNUCAI-cCGmAITAC, 1850
#   Written marc_s2_1850_cACC_CGsrc_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cACC_CGsnk=cCGmACCMB+cCGmACCMO, 1850
#   Written marc_s2_1850_cACC_CGsnk_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cACC_SOURCE=cACC_CND+cACC_EVAP+cACC_ADJsrc+cACC_CGsrc, 1850
#   Written marc_s2_1850_cACC_SOURCE_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cACC_SINK=cACC_DRY+cACC_IMP+cACC_ACT+cACC_SCV+cACC_CGsnk, 1850
#   Written marc_s2_1850_cACC_SINK_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cAIT_DRY=-mAITDRY, 1850
#   Written marc_s2_1850_cAIT_DRY_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cAIT_IMP=cmAITWET, 1850
#   Written marc_s2_1850_cAIT_IMP_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cAIT_ACT=cmAITACT, 1850
#   Written marc_s2_1850_cAIT_ACT_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cAIT_SCV=cmAITSCV, 1850
#   Written marc_s2_1850_cAIT_SCV_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cAIT_CND=cCNDmAIT, 1850
#   Written marc_s2_1850_cAIT_CND_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cAIT_ADJsrc=-cMVmNUC, 1850
#   Written marc_s2_1850_cAIT_ADJsrc_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cAIT_ADJsnk=cMVmAIT, 1850
#   Written marc_s2_1850_cAIT_ADJsnk_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cAIT_CGsrc=-cCGmNUCAI, 1850
#   Written marc_s2_1850_cAIT_CGsrc_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cAIT_CGsnk=cCGmAITAC+cCGmAITMB+cCGmAITMO, 1850
#   Written marc_s2_1850_cAIT_CGsnk_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cAIT_SOURCE=cAIT_CND+cAIT_ADJsrc+cAIT_CGsrc, 1850
#   Written marc_s2_1850_cAIT_SOURCE_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cAIT_SINK=cAIT_DRY+cAIT_IMP+cAIT_ACT+cAIT_SCV+cAIT_ADJsnk+cAIT_CGsnk, 1850
#   Written marc_s2_1850_cAIT_SINK_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cNUC_DRY=-mNUCDRY, 1850
#   Written marc_s2_1850_cNUC_DRY_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cNUC_IMP=cmNUCWET, 1850
#   Written marc_s2_1850_cNUC_IMP_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cNUC_ACT=cmNUCACT, 1850
#   Written marc_s2_1850_cNUC_ACT_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cNUC_SCV=cmNUCSCV, 1850
#   Written marc_s2_1850_cNUC_SCV_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cNUC_CND=cCNDmNUC, 1850
#   Written marc_s2_1850_cNUC_CND_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cNUC_BNUC=cBNUCmNUC, 1850
#   Written marc_s2_1850_cNUC_BNUC_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cNUC_ADJsnk=cMVmNUC, 1850
#   Written marc_s2_1850_cNUC_ADJsnk_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cNUC_CGsnk=cCGmNUCAI+cCGmNUCAC+cCGmNUCMB+cCGmNUCMO, 1850
#   Written marc_s2_1850_cNUC_CGsnk_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cNUC_SOURCE=cNUC_CND+cNUC_BNUC, 1850
#   Written marc_s2_1850_cNUC_SOURCE_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cNUC_SINK=cNUC_DRY+cNUC_IMP+cNUC_ACT+cNUC_SCV+cNUC_ADJsnk+cNUC_CGsnk, 1850
#   Written marc_s2_1850_cNUC_SINK_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cOC_SF=mOCSF, 1850
#   Written marc_s2_1850_cOC_SF_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cOC_DRY=-mOCDRY, 1850
#   Written marc_s2_1850_cOC_DRY_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cOC_IMP=cmOCWET, 1850
#   Written marc_s2_1850_cOC_IMP_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cOC_ACT=cmOCACT, 1850
#   Written marc_s2_1850_cOC_ACT_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cOC_SCV=cmOCSCV, 1850
#   Written marc_s2_1850_cOC_SCV_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cOC_AGEsnk=cAGEmOC, 1850
#   Written marc_s2_1850_cOC_AGEsnk_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cOC_CGsnk=cCGmOCMOS, 1850
#   Written marc_s2_1850_cOC_CGsnk_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cOC_SOURCE=cOC_SF, 1850
#   Written marc_s2_1850_cOC_SOURCE_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cOC_SINK=cOC_DRY+cOC_IMP+cOC_ACT+cOC_SCV+cOC_AGEsnk+cOC_CGsnk, 1850
#   Written marc_s2_1850_cOC_SINK_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cMOS_DRY=-mMOSDRY, 1850
#   Written marc_s2_1850_cMOS_DRY_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cMOS_IMP=cmMOSWET, 1850
#   Written marc_s2_1850_cMOS_IMP_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cMOS_ACT=cmMOSACT, 1850
#   Written marc_s2_1850_cMOS_ACT_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cMOS_SCV=cmMOSSCV, 1850
#   Written marc_s2_1850_cMOS_SCV_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cMOS_CND=cCNDmMOS, 1850
#   Written marc_s2_1850_cMOS_CND_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cMOS_AGEsrc=cAGEmMOS-cAGEmOC, 1850
#   Written marc_s2_1850_cMOS_AGEsrc_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cMOS_CGsrc=-cCGmNUCMO-cCGmAITMO-cCGmACCMO-cCGmOCMOS, 1850
#   Written marc_s2_1850_cMOS_CGsrc_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cMOS_SOURCE=cMOS_CND+cMOS_AGEsrc+cMOS_CGsrc, 1850
#   Written marc_s2_1850_cMOS_SOURCE_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cMOS_SINK=cMOS_DRY+cMOS_IMP+cMOS_ACT+cMOS_SCV, 1850
#   Written marc_s2_1850_cMOS_SINK_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cOIM_DRY=-mOIMDRY, 1850
#   Written marc_s2_1850_cOIM_DRY_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cOIM_IMP=cmOIMWET, 1850
#   Written marc_s2_1850_cOIM_IMP_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cOIM_ACT=cmOIMACT, 1850
#   Written marc_s2_1850_cOIM_ACT_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cOIM_SCV=cmOIMSCV, 1850
#   Written marc_s2_1850_cOIM_SCV_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cOIM_AGEsrc=-cAGEmOC, 1850
#   Written marc_s2_1850_cOIM_AGEsrc_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cOIM_CGsrc=-cCGmOCMOS, 1850
#   Written marc_s2_1850_cOIM_CGsrc_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cOIM_SOURCE=cOIM_AGEsrc+cOIM_CGsrc, 1850
#   Written marc_s2_1850_cOIM_SOURCE_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cOIM_SINK=cOIM_DRY+cOIM_IMP+cOIM_ACT+cOIM_SCV, 1850
#   Written marc_s2_1850_cOIM_SINK_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cSIMOS_DRY=cMOS_DRY-cOIM_DRY, 1850
#   Written marc_s2_1850_cSIMOS_DRY_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cSIMOS_IMP=cMOS_IMP-cOIM_IMP, 1850
#   Written marc_s2_1850_cSIMOS_IMP_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cSIMOS_ACT=cMOS_ACT-cOIM_ACT, 1850
#   Written marc_s2_1850_cSIMOS_ACT_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cSIMOS_SCV=cMOS_SCV-cOIM_SCV, 1850
#   Written marc_s2_1850_cSIMOS_SCV_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cSIMOS_CND=cMOS_CND, 1850
#   Written marc_s2_1850_cSIMOS_CND_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cSIMOS_AGEsrc=cAGEmMOS, 1850
#   Written marc_s2_1850_cSIMOS_AGEsrc_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cSIMOS_CGsrc=-cCGmNUCMO-cCGmAITMO-cCGmACCMO, 1850
#   Written marc_s2_1850_cSIMOS_CGsrc_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cSIMOS_SOURCE=cSIMOS_CND+cSIMOS_AGEsrc+cSIMOS_CGsrc, 1850
#   Written marc_s2_1850_cSIMOS_SOURCE_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cSIMOS_SINK=cSIMOS_DRY+cSIMOS_IMP+cSIMOS_ACT+cSIMOS_SCV, 1850
#   Written marc_s2_1850_cSIMOS_SINK_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cBC_SF=mBCSF, 1850
#   Written marc_s2_1850_cBC_SF_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cBC_DRY=-mBCDRY, 1850
#   Written marc_s2_1850_cBC_DRY_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cBC_IMP=cmBCWET, 1850
#   Written marc_s2_1850_cBC_IMP_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cBC_ACT=cmBCACT, 1850
#   Written marc_s2_1850_cBC_ACT_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cBC_SCV=cmBCSCV, 1850
#   Written marc_s2_1850_cBC_SCV_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cBC_AGEsnk=cAGEmBC, 1850
#   Written marc_s2_1850_cBC_AGEsnk_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cBC_SOURCE=cBC_SF, 1850
#   Written marc_s2_1850_cBC_SOURCE_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cBC_SINK=cBC_DRY+cBC_IMP+cBC_ACT+cBC_SCV+cBC_AGEsnk, 1850
#   Written marc_s2_1850_cBC_SINK_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cMBS_DRY=-mMBSDRY, 1850
#   Written marc_s2_1850_cMBS_DRY_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cMBS_IMP=cmMBSWET, 1850
#   Written marc_s2_1850_cMBS_IMP_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cMBS_ACT=cmMBSACT, 1850
#   Written marc_s2_1850_cMBS_ACT_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cMBS_SCV=cmMBSSCV, 1850
#   Written marc_s2_1850_cMBS_SCV_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cMBS_CND=cCNDmMBS, 1850
#   Written marc_s2_1850_cMBS_CND_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cMBS_AGEsrc=cAGEmMBS-cAGEmBC, 1850
#   Written marc_s2_1850_cMBS_AGEsrc_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cMBS_CGsrc=-cCGmNUCMB-cCGmAITMB-cCGmACCMB, 1850
#   Written marc_s2_1850_cMBS_CGsrc_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cMBS_SOURCE=cMBS_CND+cMBS_AGEsrc+cMBS_CGsrc, 1850
#   Written marc_s2_1850_cMBS_SOURCE_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cMBS_SINK=cMBS_DRY+cMBS_IMP+cMBS_ACT+cMBS_SCV, 1850
#   Written marc_s2_1850_cMBS_SINK_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cBIM_DRY=-mBIMDRY, 1850
#   Written marc_s2_1850_cBIM_DRY_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cBIM_IMP=cmBIMWET, 1850
#   Written marc_s2_1850_cBIM_IMP_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cBIM_ACT=cmBIMACT, 1850
#   Written marc_s2_1850_cBIM_ACT_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cBIM_SCV=cmBIMSCV, 1850
#   Written marc_s2_1850_cBIM_SCV_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cBIM_AGEsrc=-cAGEmBC, 1850
#   Written marc_s2_1850_cBIM_AGEsrc_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cBIM_SOURCE=cBIM_AGEsrc, 1850
#   Written marc_s2_1850_cBIM_SOURCE_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cBIM_SINK=cBIM_DRY+cBIM_IMP+cBIM_ACT+cBIM_SCV, 1850
#   Written marc_s2_1850_cBIM_SINK_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cSIMBS_DRY=cMBS_DRY-cBIM_DRY, 1850
#   Written marc_s2_1850_cSIMBS_DRY_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cSIMBS_IMP=cMBS_IMP-cBIM_IMP, 1850
#   Written marc_s2_1850_cSIMBS_IMP_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cSIMBS_ACT=cMBS_ACT-cBIM_ACT, 1850
#   Written marc_s2_1850_cSIMBS_ACT_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cSIMBS_SCV=cMBS_SCV-cBIM_SCV, 1850
#   Written marc_s2_1850_cSIMBS_SCV_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cSIMBS_CND=cMBS_CND, 1850
#   Written marc_s2_1850_cSIMBS_CND_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cSIMBS_AGEsrc=cAGEmMBS, 1850
#   Written marc_s2_1850_cSIMBS_AGEsrc_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cSIMBS_CGsrc=cMBS_CGsrc, 1850
#   Written marc_s2_1850_cSIMBS_CGsrc_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cSIMBS_SOURCE=cSIMBS_CND+cSIMBS_AGEsrc+cSIMBS_CGsrc, 1850
#   Written marc_s2_1850_cSIMBS_SOURCE_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# cSIMBS_SINK=cSIMBS_DRY+cSIMBS_IMP+cSIMBS_ACT+cSIMBS_SCV, 1850
#   Written marc_s2_1850_cSIMBS_SINK_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# Fri Aug 17 17:05:24 +08 2018
