# %% [markdown]
# # budget_cdo_nco_draft2017b.ipynb
#
# ## Purpose
# Use CDO and NCO to post-process MARC aerosol budget data from project [p17c-marc-comparison](https://github.com/grandey/p17c-marc-comparison).
#
# ## Requirements
# - Climate Data Operators (CDO)
# - NetCDF Operators (NCO)
# - CESM output data, post-processed to time-series format, as described in [data_management.org](https://github.com/grandey/p17c-marc-comparison/blob/master/manage_data/data_management.org#syncing-to-local-machine-for-analysis). These data will be made available via https://doi.org/10.6084/m9.figshare.5687812.
#
# ## Author
# Benjamin S. Grandey, 2018
#
# ## Acknowledgments
# Thanks are due to **Alex Avramov**.  The interpretation of the diagnostics are informed by *print_MARC_budget_Benjamin.pro*, an IDL script written by Alex Avramov.

# %%
! date
# Out:
# Thu Jun 14 12:26:36 +08 2018

# %%
from glob import glob
import os
import re
import shutil

# %% [markdown]
# ## CDO and NCO version information

# %%
! cdo --version
! ncks --version
# Out:
# Climate Data Operators version 1.9.1 (http://mpimet.mpg.de/cdo)
# Compiled: by root on squall2.local (x86_64-apple-darwin17.2.0) Nov  2 2017 18:28:19
# CXX Compiler: /usr/bin/clang++ -std=gnu++11 -pipe -Os -stdlib=libc++ -arch x86_64  -D_THREAD_SAFE -pthread
# CXX version : unknown
# C Compiler: /usr/bin/clang -pipe -Os -arch x86_64  -D_THREAD_SAFE -pthread
# C version : unknown
# Features: DATA PTHREADS HDF5 NC4/HDF5 OPeNDAP SZ UDUNITS2 PROJ.4 CURL FFTW3 SSE4_1
# Libraries: HDF5/1.10.1 proj/4.93 curl/7.56.1
# Filetypes: srv ext ieg grb1 nc1 nc2 nc4 nc4c nc5
#      CDI library version : 1.9.1 of Nov  2 2017 18:27:49
#  CGRIBEX library version : 1.9.0 of Sep 29 2017 10:16:02
#   NetCDF library version : 4.4.1.1 of Oct  6 2017 14:14:42 $
#     HDF5 library version : 1.10.1
#  SERVICE library version : 1.4.0 of Nov  2 2017 18:27:47
#    EXTRA library version : 1.4.0 of Nov  2 2017 18:27:46
#      IEG library version : 1.4.0 of Nov  2 2017 18:27:46
#     FILE library version : 1.8.3 of Nov  2 2017 18:27:46
#
# NCO netCDF Operators version 4.6.6 built by root on squall2.local at Nov  3 2017 12:13:40
# ncks version 4.6.6

# %% [markdown]
# ## Directory locations for input and output NetCDF files
# The data in the input directory (*in_dir*) will be made available via Figshare: https://doi.org/10.6084/m9.figshare.5687812.

# %%
# Input data directory
#in_dir = os.path.expandvars('$HOME/data/figshare/figshare5687812/')
in_dir = os.path.expandvars('$HOME/data/projects/p17c_marc_comparison/output_timeseries/')

# Output data directory
out_dir = os.path.expandvars('$HOME/data/projects/p17c_marc_comparison/budget_cdo_nco_draft2017b/')

# %% [markdown]
# ## Clean output data directory

# %%
for filename in glob('{}/*.nc'.format(out_dir)):
    print('Deleting {}'.format(filename.split('/')[-1]))
    os.remove(filename)
for filename in glob('{}/*.nco'.format(out_dir)):
    print('Deleting {}'.format(filename.split('/')[-1]))
    os.remove(filename)
for filename in glob('{}/*.tmp'.format(out_dir)):
    print('Deleting {}'.format(filename.split('/')[-1]))
    os.remove(filename)
! date
# Out:
# Thu Jun 14 12:26:37 +08 2018

# %% [markdown]
# ## Calculate annual means of standard MARC 2D diagnostic variables

# %%
variable_list = ['mOCSF', 'mBCSF',  # surface emissions
                 'DST01SF', 'DST02SF', 'DST03SF', 'DST04SF',
                 'SSLT01SF', 'SSLT02SF', 'SSLT03SF', 'SSLT04SF',
                 'mACCDRY', 'mAITDRY', 'mNUCDRY',  # dry deposition
                 'mOCDRY', 'mMOSDRY', 'mOIMDRY', 'mBCDRY', 'mMBSDRY', 'mBIMDRY',
                 'DST01DD', 'DST02DD', 'DST03DD', 'DST04DD',
                 'SSLT01DD', 'SSLT02DD', 'SSLT03DD', 'SSLT04DD'
                ]
for variable in variable_list:
    for year in ['2000', '1850']:
        # Check if input file exists
        in_filename = '{}/p17c_marc_{}.cam.h0.{}.nc'.format(in_dir, year, variable)
        if os.path.isfile(in_filename):
            print('{}, marc, {}'.format(variable, year))
            # Calculate annual means using NCO (with years starting in January)
            annual_filename = '{}/marc_{}_{}_ANN.nc'.format(out_dir, year, variable)
            ! ncra -O --mro -d time,,,12,12 {in_filename} {annual_filename}
            print('  Written {}'.format(annual_filename.split('/')[-1]))
! date
# Out:
# mOCSF, marc, 2000
#   Written marc_2000_mOCSF_ANN.nc
# mOCSF, marc, 1850
#   Written marc_1850_mOCSF_ANN.nc
# mBCSF, marc, 2000
#   Written marc_2000_mBCSF_ANN.nc
# mBCSF, marc, 1850
#   Written marc_1850_mBCSF_ANN.nc
# DST01SF, marc, 2000
#   Written marc_2000_DST01SF_ANN.nc
# DST01SF, marc, 1850
#   Written marc_1850_DST01SF_ANN.nc
# DST02SF, marc, 2000
#   Written marc_2000_DST02SF_ANN.nc
# DST02SF, marc, 1850
#   Written marc_1850_DST02SF_ANN.nc
# DST03SF, marc, 2000
#   Written marc_2000_DST03SF_ANN.nc
# DST03SF, marc, 1850
#   Written marc_1850_DST03SF_ANN.nc
# DST04SF, marc, 2000
#   Written marc_2000_DST04SF_ANN.nc
# DST04SF, marc, 1850
#   Written marc_1850_DST04SF_ANN.nc
# SSLT01SF, marc, 2000
#   Written marc_2000_SSLT01SF_ANN.nc
# SSLT01SF, marc, 1850
#   Written marc_1850_SSLT01SF_ANN.nc
# SSLT02SF, marc, 2000
#   Written marc_2000_SSLT02SF_ANN.nc
# SSLT02SF, marc, 1850
#   Written marc_1850_SSLT02SF_ANN.nc
# SSLT03SF, marc, 2000
#   Written marc_2000_SSLT03SF_ANN.nc
# SSLT03SF, marc, 1850
#   Written marc_1850_SSLT03SF_ANN.nc
# SSLT04SF, marc, 2000
#   Written marc_2000_SSLT04SF_ANN.nc
# SSLT04SF, marc, 1850
#   Written marc_1850_SSLT04SF_ANN.nc
# mACCDRY, marc, 2000
#   Written marc_2000_mACCDRY_ANN.nc
# mACCDRY, marc, 1850
#   Written marc_1850_mACCDRY_ANN.nc
# mAITDRY, marc, 2000
#   Written marc_2000_mAITDRY_ANN.nc
# mAITDRY, marc, 1850
#   Written marc_1850_mAITDRY_ANN.nc
# mNUCDRY, marc, 2000
#   Written marc_2000_mNUCDRY_ANN.nc
# mNUCDRY, marc, 1850
#   Written marc_1850_mNUCDRY_ANN.nc
# mOCDRY, marc, 2000
#   Written marc_2000_mOCDRY_ANN.nc
# mOCDRY, marc, 1850
#   Written marc_1850_mOCDRY_ANN.nc
# mMOSDRY, marc, 2000
#   Written marc_2000_mMOSDRY_ANN.nc
# mMOSDRY, marc, 1850
#   Written marc_1850_mMOSDRY_ANN.nc
# mOIMDRY, marc, 2000
#   Written marc_2000_mOIMDRY_ANN.nc
# mOIMDRY, marc, 1850
#   Written marc_1850_mOIMDRY_ANN.nc
# mBCDRY, marc, 2000
#   Written marc_2000_mBCDRY_ANN.nc
# mBCDRY, marc, 1850
#   Written marc_1850_mBCDRY_ANN.nc
# mMBSDRY, marc, 2000
#   Written marc_2000_mMBSDRY_ANN.nc
# mMBSDRY, marc, 1850
#   Written marc_1850_mMBSDRY_ANN.nc
# mBIMDRY, marc, 2000
#   Written marc_2000_mBIMDRY_ANN.nc
# mBIMDRY, marc, 1850
#   Written marc_1850_mBIMDRY_ANN.nc
# DST01DD, marc, 2000
#   Written marc_2000_DST01DD_ANN.nc
# DST01DD, marc, 1850
#   Written marc_1850_DST01DD_ANN.nc
# DST02DD, marc, 2000
#   Written marc_2000_DST02DD_ANN.nc
# DST02DD, marc, 1850
#   Written marc_1850_DST02DD_ANN.nc
# DST03DD, marc, 2000
#   Written marc_2000_DST03DD_ANN.nc
# DST03DD, marc, 1850
#   Written marc_1850_DST03DD_ANN.nc
# DST04DD, marc, 2000
#   Written marc_2000_DST04DD_ANN.nc
# DST04DD, marc, 1850
#   Written marc_1850_DST04DD_ANN.nc
# SSLT01DD, marc, 2000
#   Written marc_2000_SSLT01DD_ANN.nc
# SSLT01DD, marc, 1850
#   Written marc_1850_SSLT01DD_ANN.nc
# SSLT02DD, marc, 2000
#   Written marc_2000_SSLT02DD_ANN.nc
# SSLT02DD, marc, 1850
#   Written marc_1850_SSLT02DD_ANN.nc
# SSLT03DD, marc, 2000
#   Written marc_2000_SSLT03DD_ANN.nc
# SSLT03DD, marc, 1850
#   Written marc_1850_SSLT03DD_ANN.nc
# SSLT04DD, marc, 2000
#   Written marc_2000_SSLT04DD_ANN.nc
# SSLT04DD, marc, 1850
#   Written marc_1850_SSLT04DD_ANN.nc
# Thu Jun 14 12:27:16 +08 2018

# %% [markdown]
# ## Calculate column integrals from 3D rate data
# kg/kg/s -> kg/m2/s

# %%
# List of 3D rate variables of interest
variable_list = [
    'mACCWET', 'mAITWET', 'mNUCWET',  # wet deposition
    'mOCWET', 'mMOSWET', 'mOIMWET', 'mBCWET', 'mMBSWET', 'mBIMWET',
    'DST01PP', 'DST02PP', 'DST03PP', 'DST04PP', 'SSLT01PP', 'SSLT02PP', 'SSLT03PP', 'SSLT04PP',
    'AGEmOC', 'AGEmMOS', 'AGEmBC', 'AGEmMBS', # aging
    'mACCACT', 'mAITACT', 'mNUCACT',  # nucleation scavenging
    'mOCACT', 'mMOSACT', 'mOIMACT', 'mBCACT', 'mMBSACT', 'mBIMACT',
    'mACCSCV', 'mAITSCV', 'mNUCSCV',  # nucleation scavenging by convection
    'mOCSCV', 'mMOSSCV', 'mOIMSCV', 'mBCSCV', 'mMBSSCV', 'mBIMSCV',
    'mSO4evap',  # SO4 cloud evaporation -> ACC
    'BNUCmNUC',  # binary nucleation -> NUC
    'CNDmACC', 'CNDmAIT', 'CNDmNUC', 'CNDmMOS', 'CNDmMBS',  # H2SO4 condensation
    'MVmNUC', 'MVmAIT',  # mass mode adjustment, NUC->AIT, AIT->ACC
    'CGmNUCAC', 'CGmNUCAI', 'CGmNUCMB', 'CGmNUCMO',  # coagulation
    'CGmAITAC', 'CGmAITMB', 'CGmAITMO', 'CGmACCMB', 'CGmACCMO', 'CGmOCMOS']

# %%
# Calculate column integrals
for year in ['2000', '1850']:  # loop over emission years
    ! date
    print('year = {}'.format(year))
    # Copy the surface pressure file - necessary for decoding of the hybrid coordinates
    print('  Copying surface pressure file')
    in_filename = '{}/p17c_marc_{}.cam.h0.PS.nc'.format(in_dir, year)
    ps_filename = '{}/temp_marc_{}_PS.nc'.format(out_dir, year)
    shutil.copy2(in_filename, ps_filename)
    # Create file containing NCO commands for calculation of air mass in each model level
    nco_filename = '{}/temp_marc_{}.nco'.format(out_dir, year)
    nco_file = open(nco_filename, 'w')
    nco_file.writelines(['*P_bnds[time,ilev,lat,lon]=hyai*P0+hybi*PS;\n',  # pressures at bounds
                         '*P_delta[time,lev,lat,lon]=P_bnds(:,1:30,:,:)-P_bnds(:,0:29,:,:);\n',  # deltas
                         'mass_air=P_delta/9.807;'])  # mass of air
    nco_file.close()
    # Calculate mass of air in each model level
    print('  Calculating mass of air in each model level')
    mass_air_filename = '{}/temp_marc_{}_mass_air.nc'.format(out_dir, year)
    ! ncap2 -O -v -S {nco_filename} {ps_filename} {mass_air_filename}
    # Loop over rate data variables
    for variable in variable_list:  # dust
        ! date
        print('  variable = {}'.format(variable))
        # Copy the rate file
        print('    Copying the file for {}'.format(variable))
        in_filename = '{}/p17c_marc_{}.cam.h0.{}.nc'.format(in_dir, year, variable)
        rate_filename = '{}/temp_marc_{}_{}.nc'.format(out_dir, year, variable)
        shutil.copy2(in_filename, rate_filename)
        # Append the mass of air in each model level
        print('    Appending mass_air')
        ! ncks -A {mass_air_filename} {rate_filename}
        # Calculate the mass rate of the variable
        print('    Calculating the mass rate of {} in each model level'.format(variable))
        mass_variable_filename = '{}/temp_marc_{}_mass_{}.nc'.format(out_dir, year, variable)
        ! ncap2 -O -s 'mass_{variable}=mass_air*{variable}' {rate_filename} {mass_variable_filename}
        # Sum over levels to calculate column integral (and exclude unwanted variables)
        print('    Summing over levels')
        column_filename = '{}/temp_marc_{}_column_{}.nc'.format(out_dir, year, variable)
        ! ncwa -O -x -v mass_air,{variable} -a lev -y sum {mass_variable_filename} {column_filename}
        # Rename variable
        print('    Renaming variable to c{}'.format(variable))
        ! ncrename -v mass_{variable},c{variable} {column_filename} >/dev/null 2>/dev/null
        # Set units and long_name
        print('    Setting units and long_name')
        ! ncatted -a 'units',c{variable},o,c,'kg/m2/s' {column_filename}
        ! ncatted -a 'long_name',c{variable},o,c,'{variable} column integral' {column_filename}
        # Calculate annual means (with years starting in January)
        print('    Calculating annual means')
        annual_filename = '{}/marc_{}_c{}_ANN.nc'.format(out_dir, year, variable)
        ! ncra -O --mro -d time,,,12,12 {column_filename} {annual_filename}
        print('    Written {}'.format(annual_filename.split('/')[-1]))
        # Remove three temporary files
        for filename in [rate_filename, mass_variable_filename, column_filename]:
            print('    Removing {}'.format(filename.split('/')[-1]))
            os.remove(filename)
    # Remove another two temporary files
    for filename in [ps_filename, mass_air_filename, nco_filename]:
            print('  Removing {}'.format(filename.split('/')[-1]))
            os.remove(filename)
! date
# Out:
# Thu Jun 14 12:27:16 +08 2018
# year = 2000
#   Copying surface pressure file
#   Calculating mass of air in each model level
# Thu Jun 14 12:28:04 +08 2018
#   variable = mACCWET
#     Copying the file for mACCWET
#     Appending mass_air
#     Calculating the mass rate of mACCWET in each model level
#     Summing over levels
#     Renaming variable to cmACCWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmACCWET_ANN.nc
#     Removing temp_marc_2000_mACCWET.nc
#     Removing temp_marc_2000_mass_mACCWET.nc
#     Removing temp_marc_2000_column_mACCWET.nc
# Thu Jun 14 12:28:54 +08 2018
#   variable = mAITWET
#     Copying the file for mAITWET
#     Appending mass_air
#     Calculating the mass rate of mAITWET in each model level
#     Summing over levels
#     Renaming variable to cmAITWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmAITWET_ANN.nc
#     Removing temp_marc_2000_mAITWET.nc
#     Removing temp_marc_2000_mass_mAITWET.nc
#     Removing temp_marc_2000_column_mAITWET.nc
# Thu Jun 14 12:29:39 +08 2018
#   variable = mNUCWET
#     Copying the file for mNUCWET
#     Appending mass_air
#     Calculating the mass rate of mNUCWET in each model level
#     Summing over levels
#     Renaming variable to cmNUCWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmNUCWET_ANN.nc
#     Removing temp_marc_2000_mNUCWET.nc
#     Removing temp_marc_2000_mass_mNUCWET.nc
#     Removing temp_marc_2000_column_mNUCWET.nc
# Thu Jun 14 12:30:26 +08 2018
#   variable = mOCWET
#     Copying the file for mOCWET
#     Appending mass_air
#     Calculating the mass rate of mOCWET in each model level
#     Summing over levels
#     Renaming variable to cmOCWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmOCWET_ANN.nc
#     Removing temp_marc_2000_mOCWET.nc
#     Removing temp_marc_2000_mass_mOCWET.nc
#     Removing temp_marc_2000_column_mOCWET.nc
# Thu Jun 14 12:31:16 +08 2018
#   variable = mMOSWET
#     Copying the file for mMOSWET
#     Appending mass_air
#     Calculating the mass rate of mMOSWET in each model level
#     Summing over levels
#     Renaming variable to cmMOSWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmMOSWET_ANN.nc
#     Removing temp_marc_2000_mMOSWET.nc
#     Removing temp_marc_2000_mass_mMOSWET.nc
#     Removing temp_marc_2000_column_mMOSWET.nc
# Thu Jun 14 12:32:05 +08 2018
#   variable = mOIMWET
#     Copying the file for mOIMWET
#     Appending mass_air
#     Calculating the mass rate of mOIMWET in each model level
#     Summing over levels
#     Renaming variable to cmOIMWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmOIMWET_ANN.nc
#     Removing temp_marc_2000_mOIMWET.nc
#     Removing temp_marc_2000_mass_mOIMWET.nc
#     Removing temp_marc_2000_column_mOIMWET.nc
# Thu Jun 14 12:32:56 +08 2018
#   variable = mBCWET
#     Copying the file for mBCWET
#     Appending mass_air
#     Calculating the mass rate of mBCWET in each model level
#     Summing over levels
#     Renaming variable to cmBCWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmBCWET_ANN.nc
#     Removing temp_marc_2000_mBCWET.nc
#     Removing temp_marc_2000_mass_mBCWET.nc
#     Removing temp_marc_2000_column_mBCWET.nc
# Thu Jun 14 12:33:46 +08 2018
#   variable = mMBSWET
#     Copying the file for mMBSWET
#     Appending mass_air
#     Calculating the mass rate of mMBSWET in each model level
#     Summing over levels
#     Renaming variable to cmMBSWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmMBSWET_ANN.nc
#     Removing temp_marc_2000_mMBSWET.nc
#     Removing temp_marc_2000_mass_mMBSWET.nc
#     Removing temp_marc_2000_column_mMBSWET.nc
# Thu Jun 14 12:34:35 +08 2018
#   variable = mBIMWET
#     Copying the file for mBIMWET
#     Appending mass_air
#     Calculating the mass rate of mBIMWET in each model level
#     Summing over levels
#     Renaming variable to cmBIMWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmBIMWET_ANN.nc
#     Removing temp_marc_2000_mBIMWET.nc
#     Removing temp_marc_2000_mass_mBIMWET.nc
#     Removing temp_marc_2000_column_mBIMWET.nc
# Thu Jun 14 12:35:22 +08 2018
#   variable = DST01PP
#     Copying the file for DST01PP
#     Appending mass_air
#     Calculating the mass rate of DST01PP in each model level
#     Summing over levels
#     Renaming variable to cDST01PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cDST01PP_ANN.nc
#     Removing temp_marc_2000_DST01PP.nc
#     Removing temp_marc_2000_mass_DST01PP.nc
#     Removing temp_marc_2000_column_DST01PP.nc
# Thu Jun 14 12:36:05 +08 2018
#   variable = DST02PP
#     Copying the file for DST02PP
#     Appending mass_air
#     Calculating the mass rate of DST02PP in each model level
#     Summing over levels
#     Renaming variable to cDST02PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cDST02PP_ANN.nc
#     Removing temp_marc_2000_DST02PP.nc
#     Removing temp_marc_2000_mass_DST02PP.nc
#     Removing temp_marc_2000_column_DST02PP.nc
# Thu Jun 14 12:36:52 +08 2018
#   variable = DST03PP
#     Copying the file for DST03PP
#     Appending mass_air
#     Calculating the mass rate of DST03PP in each model level
#     Summing over levels
#     Renaming variable to cDST03PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cDST03PP_ANN.nc
#     Removing temp_marc_2000_DST03PP.nc
#     Removing temp_marc_2000_mass_DST03PP.nc
#     Removing temp_marc_2000_column_DST03PP.nc
# Thu Jun 14 12:37:39 +08 2018
#   variable = DST04PP
#     Copying the file for DST04PP
#     Appending mass_air
#     Calculating the mass rate of DST04PP in each model level
#     Summing over levels
#     Renaming variable to cDST04PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cDST04PP_ANN.nc
#     Removing temp_marc_2000_DST04PP.nc
#     Removing temp_marc_2000_mass_DST04PP.nc
#     Removing temp_marc_2000_column_DST04PP.nc
# Thu Jun 14 12:38:29 +08 2018
#   variable = SSLT01PP
#     Copying the file for SSLT01PP
#     Appending mass_air
#     Calculating the mass rate of SSLT01PP in each model level
#     Summing over levels
#     Renaming variable to cSSLT01PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cSSLT01PP_ANN.nc
#     Removing temp_marc_2000_SSLT01PP.nc
#     Removing temp_marc_2000_mass_SSLT01PP.nc
#     Removing temp_marc_2000_column_SSLT01PP.nc
# Thu Jun 14 12:39:12 +08 2018
#   variable = SSLT02PP
#     Copying the file for SSLT02PP
#     Appending mass_air
#     Calculating the mass rate of SSLT02PP in each model level
#     Summing over levels
#     Renaming variable to cSSLT02PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cSSLT02PP_ANN.nc
#     Removing temp_marc_2000_SSLT02PP.nc
#     Removing temp_marc_2000_mass_SSLT02PP.nc
#     Removing temp_marc_2000_column_SSLT02PP.nc
# Thu Jun 14 12:39:56 +08 2018
#   variable = SSLT03PP
#     Copying the file for SSLT03PP
#     Appending mass_air
#     Calculating the mass rate of SSLT03PP in each model level
#     Summing over levels
#     Renaming variable to cSSLT03PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cSSLT03PP_ANN.nc
#     Removing temp_marc_2000_SSLT03PP.nc
#     Removing temp_marc_2000_mass_SSLT03PP.nc
#     Removing temp_marc_2000_column_SSLT03PP.nc
# Thu Jun 14 12:40:39 +08 2018
#   variable = SSLT04PP
#     Copying the file for SSLT04PP
#     Appending mass_air
#     Calculating the mass rate of SSLT04PP in each model level
#     Summing over levels
#     Renaming variable to cSSLT04PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cSSLT04PP_ANN.nc
#     Removing temp_marc_2000_SSLT04PP.nc
#     Removing temp_marc_2000_mass_SSLT04PP.nc
#     Removing temp_marc_2000_column_SSLT04PP.nc
# Thu Jun 14 12:41:27 +08 2018
#   variable = AGEmOC
#     Copying the file for AGEmOC
#     Appending mass_air
#     Calculating the mass rate of AGEmOC in each model level
#     Summing over levels
#     Renaming variable to cAGEmOC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cAGEmOC_ANN.nc
#     Removing temp_marc_2000_AGEmOC.nc
#     Removing temp_marc_2000_mass_AGEmOC.nc
#     Removing temp_marc_2000_column_AGEmOC.nc
# Thu Jun 14 12:42:14 +08 2018
#   variable = AGEmMOS
#     Copying the file for AGEmMOS
#     Appending mass_air
#     Calculating the mass rate of AGEmMOS in each model level
#     Summing over levels
#     Renaming variable to cAGEmMOS
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cAGEmMOS_ANN.nc
#     Removing temp_marc_2000_AGEmMOS.nc
#     Removing temp_marc_2000_mass_AGEmMOS.nc
#     Removing temp_marc_2000_column_AGEmMOS.nc
# Thu Jun 14 12:43:03 +08 2018
#   variable = AGEmBC
#     Copying the file for AGEmBC
#     Appending mass_air
#     Calculating the mass rate of AGEmBC in each model level
#     Summing over levels
#     Renaming variable to cAGEmBC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cAGEmBC_ANN.nc
#     Removing temp_marc_2000_AGEmBC.nc
#     Removing temp_marc_2000_mass_AGEmBC.nc
#     Removing temp_marc_2000_column_AGEmBC.nc
# Thu Jun 14 12:43:49 +08 2018
#   variable = AGEmMBS
#     Copying the file for AGEmMBS
#     Appending mass_air
#     Calculating the mass rate of AGEmMBS in each model level
#     Summing over levels
#     Renaming variable to cAGEmMBS
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cAGEmMBS_ANN.nc
#     Removing temp_marc_2000_AGEmMBS.nc
#     Removing temp_marc_2000_mass_AGEmMBS.nc
#     Removing temp_marc_2000_column_AGEmMBS.nc
# Thu Jun 14 12:44:39 +08 2018
#   variable = mACCACT
#     Copying the file for mACCACT
#     Appending mass_air
#     Calculating the mass rate of mACCACT in each model level
#     Summing over levels
#     Renaming variable to cmACCACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmACCACT_ANN.nc
#     Removing temp_marc_2000_mACCACT.nc
#     Removing temp_marc_2000_mass_mACCACT.nc
#     Removing temp_marc_2000_column_mACCACT.nc
# Thu Jun 14 12:45:25 +08 2018
#   variable = mAITACT
#     Copying the file for mAITACT
#     Appending mass_air
#     Calculating the mass rate of mAITACT in each model level
#     Summing over levels
#     Renaming variable to cmAITACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmAITACT_ANN.nc
#     Removing temp_marc_2000_mAITACT.nc
#     Removing temp_marc_2000_mass_mAITACT.nc
#     Removing temp_marc_2000_column_mAITACT.nc
# Thu Jun 14 12:46:10 +08 2018
#   variable = mNUCACT
#     Copying the file for mNUCACT
#     Appending mass_air
#     Calculating the mass rate of mNUCACT in each model level
#     Summing over levels
#     Renaming variable to cmNUCACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmNUCACT_ANN.nc
#     Removing temp_marc_2000_mNUCACT.nc
#     Removing temp_marc_2000_mass_mNUCACT.nc
#     Removing temp_marc_2000_column_mNUCACT.nc
# Thu Jun 14 12:46:54 +08 2018
#   variable = mOCACT
#     Copying the file for mOCACT
#     Appending mass_air
#     Calculating the mass rate of mOCACT in each model level
#     Summing over levels
#     Renaming variable to cmOCACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmOCACT_ANN.nc
#     Removing temp_marc_2000_mOCACT.nc
#     Removing temp_marc_2000_mass_mOCACT.nc
#     Removing temp_marc_2000_column_mOCACT.nc
# Thu Jun 14 12:47:49 +08 2018
#   variable = mMOSACT
#     Copying the file for mMOSACT
#     Appending mass_air
#     Calculating the mass rate of mMOSACT in each model level
#     Summing over levels
#     Renaming variable to cmMOSACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmMOSACT_ANN.nc
#     Removing temp_marc_2000_mMOSACT.nc
#     Removing temp_marc_2000_mass_mMOSACT.nc
#     Removing temp_marc_2000_column_mMOSACT.nc
# Thu Jun 14 12:48:41 +08 2018
#   variable = mOIMACT
#     Copying the file for mOIMACT
#     Appending mass_air
#     Calculating the mass rate of mOIMACT in each model level
#     Summing over levels
#     Renaming variable to cmOIMACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmOIMACT_ANN.nc
#     Removing temp_marc_2000_mOIMACT.nc
#     Removing temp_marc_2000_mass_mOIMACT.nc
#     Removing temp_marc_2000_column_mOIMACT.nc
# Thu Jun 14 12:49:32 +08 2018
#   variable = mBCACT
#     Copying the file for mBCACT
#     Appending mass_air
#     Calculating the mass rate of mBCACT in each model level
#     Summing over levels
#     Renaming variable to cmBCACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmBCACT_ANN.nc
#     Removing temp_marc_2000_mBCACT.nc
#     Removing temp_marc_2000_mass_mBCACT.nc
#     Removing temp_marc_2000_column_mBCACT.nc
# Thu Jun 14 12:50:22 +08 2018
#   variable = mMBSACT
#     Copying the file for mMBSACT
#     Appending mass_air
#     Calculating the mass rate of mMBSACT in each model level
#     Summing over levels
#     Renaming variable to cmMBSACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmMBSACT_ANN.nc
#     Removing temp_marc_2000_mMBSACT.nc
#     Removing temp_marc_2000_mass_mMBSACT.nc
#     Removing temp_marc_2000_column_mMBSACT.nc
# Thu Jun 14 12:51:12 +08 2018
#   variable = mBIMACT
#     Copying the file for mBIMACT
#     Appending mass_air
#     Calculating the mass rate of mBIMACT in each model level
#     Summing over levels
#     Renaming variable to cmBIMACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmBIMACT_ANN.nc
#     Removing temp_marc_2000_mBIMACT.nc
#     Removing temp_marc_2000_mass_mBIMACT.nc
#     Removing temp_marc_2000_column_mBIMACT.nc
# Thu Jun 14 12:52:00 +08 2018
#   variable = mACCSCV
#     Copying the file for mACCSCV
#     Appending mass_air
#     Calculating the mass rate of mACCSCV in each model level
#     Summing over levels
#     Renaming variable to cmACCSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmACCSCV_ANN.nc
#     Removing temp_marc_2000_mACCSCV.nc
#     Removing temp_marc_2000_mass_mACCSCV.nc
#     Removing temp_marc_2000_column_mACCSCV.nc
# Thu Jun 14 12:52:49 +08 2018
#   variable = mAITSCV
#     Copying the file for mAITSCV
#     Appending mass_air
#     Calculating the mass rate of mAITSCV in each model level
#     Summing over levels
#     Renaming variable to cmAITSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmAITSCV_ANN.nc
#     Removing temp_marc_2000_mAITSCV.nc
#     Removing temp_marc_2000_mass_mAITSCV.nc
#     Removing temp_marc_2000_column_mAITSCV.nc
# Thu Jun 14 12:53:35 +08 2018
#   variable = mNUCSCV
#     Copying the file for mNUCSCV
#     Appending mass_air
#     Calculating the mass rate of mNUCSCV in each model level
#     Summing over levels
#     Renaming variable to cmNUCSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmNUCSCV_ANN.nc
#     Removing temp_marc_2000_mNUCSCV.nc
#     Removing temp_marc_2000_mass_mNUCSCV.nc
#     Removing temp_marc_2000_column_mNUCSCV.nc
# Thu Jun 14 12:54:18 +08 2018
#   variable = mOCSCV
#     Copying the file for mOCSCV
#     Appending mass_air
#     Calculating the mass rate of mOCSCV in each model level
#     Summing over levels
#     Renaming variable to cmOCSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmOCSCV_ANN.nc
#     Removing temp_marc_2000_mOCSCV.nc
#     Removing temp_marc_2000_mass_mOCSCV.nc
#     Removing temp_marc_2000_column_mOCSCV.nc
# Thu Jun 14 12:55:12 +08 2018
#   variable = mMOSSCV
#     Copying the file for mMOSSCV
#     Appending mass_air
#     Calculating the mass rate of mMOSSCV in each model level
#     Summing over levels
#     Renaming variable to cmMOSSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmMOSSCV_ANN.nc
#     Removing temp_marc_2000_mMOSSCV.nc
#     Removing temp_marc_2000_mass_mMOSSCV.nc
#     Removing temp_marc_2000_column_mMOSSCV.nc
# Thu Jun 14 12:56:03 +08 2018
#   variable = mOIMSCV
#     Copying the file for mOIMSCV
#     Appending mass_air
#     Calculating the mass rate of mOIMSCV in each model level
#     Summing over levels
#     Renaming variable to cmOIMSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmOIMSCV_ANN.nc
#     Removing temp_marc_2000_mOIMSCV.nc
#     Removing temp_marc_2000_mass_mOIMSCV.nc
#     Removing temp_marc_2000_column_mOIMSCV.nc
# Thu Jun 14 12:56:50 +08 2018
#   variable = mBCSCV
#     Copying the file for mBCSCV
#     Appending mass_air
#     Calculating the mass rate of mBCSCV in each model level
#     Summing over levels
#     Renaming variable to cmBCSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmBCSCV_ANN.nc
#     Removing temp_marc_2000_mBCSCV.nc
#     Removing temp_marc_2000_mass_mBCSCV.nc
#     Removing temp_marc_2000_column_mBCSCV.nc
# Thu Jun 14 12:57:40 +08 2018
#   variable = mMBSSCV
#     Copying the file for mMBSSCV
#     Appending mass_air
#     Calculating the mass rate of mMBSSCV in each model level
#     Summing over levels
#     Renaming variable to cmMBSSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmMBSSCV_ANN.nc
#     Removing temp_marc_2000_mMBSSCV.nc
#     Removing temp_marc_2000_mass_mMBSSCV.nc
#     Removing temp_marc_2000_column_mMBSSCV.nc
# Thu Jun 14 12:58:29 +08 2018
#   variable = mBIMSCV
#     Copying the file for mBIMSCV
#     Appending mass_air
#     Calculating the mass rate of mBIMSCV in each model level
#     Summing over levels
#     Renaming variable to cmBIMSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmBIMSCV_ANN.nc
#     Removing temp_marc_2000_mBIMSCV.nc
#     Removing temp_marc_2000_mass_mBIMSCV.nc
#     Removing temp_marc_2000_column_mBIMSCV.nc
# Thu Jun 14 12:59:16 +08 2018
#   variable = mSO4evap
#     Copying the file for mSO4evap
#     Appending mass_air
#     Calculating the mass rate of mSO4evap in each model level
#     Summing over levels
#     Renaming variable to cmSO4evap
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cmSO4evap_ANN.nc
#     Removing temp_marc_2000_mSO4evap.nc
#     Removing temp_marc_2000_mass_mSO4evap.nc
#     Removing temp_marc_2000_column_mSO4evap.nc
# Thu Jun 14 13:00:03 +08 2018
#   variable = BNUCmNUC
#     Copying the file for BNUCmNUC
#     Appending mass_air
#     Calculating the mass rate of BNUCmNUC in each model level
#     Summing over levels
#     Renaming variable to cBNUCmNUC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cBNUCmNUC_ANN.nc
#     Removing temp_marc_2000_BNUCmNUC.nc
#     Removing temp_marc_2000_mass_BNUCmNUC.nc
#     Removing temp_marc_2000_column_BNUCmNUC.nc
# Thu Jun 14 13:00:43 +08 2018
#   variable = CNDmACC
#     Copying the file for CNDmACC
#     Appending mass_air
#     Calculating the mass rate of CNDmACC in each model level
#     Summing over levels
#     Renaming variable to cCNDmACC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cCNDmACC_ANN.nc
#     Removing temp_marc_2000_CNDmACC.nc
#     Removing temp_marc_2000_mass_CNDmACC.nc
#     Removing temp_marc_2000_column_CNDmACC.nc
# Thu Jun 14 13:01:28 +08 2018
#   variable = CNDmAIT
#     Copying the file for CNDmAIT
#     Appending mass_air
#     Calculating the mass rate of CNDmAIT in each model level
#     Summing over levels
#     Renaming variable to cCNDmAIT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cCNDmAIT_ANN.nc
#     Removing temp_marc_2000_CNDmAIT.nc
#     Removing temp_marc_2000_mass_CNDmAIT.nc
#     Removing temp_marc_2000_column_CNDmAIT.nc
# Thu Jun 14 13:02:09 +08 2018
#   variable = CNDmNUC
#     Copying the file for CNDmNUC
#     Appending mass_air
#     Calculating the mass rate of CNDmNUC in each model level
#     Summing over levels
#     Renaming variable to cCNDmNUC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cCNDmNUC_ANN.nc
#     Removing temp_marc_2000_CNDmNUC.nc
#     Removing temp_marc_2000_mass_CNDmNUC.nc
#     Removing temp_marc_2000_column_CNDmNUC.nc
# Thu Jun 14 13:02:51 +08 2018
#   variable = CNDmMOS
#     Copying the file for CNDmMOS
#     Appending mass_air
#     Calculating the mass rate of CNDmMOS in each model level
#     Summing over levels
#     Renaming variable to cCNDmMOS
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cCNDmMOS_ANN.nc
#     Removing temp_marc_2000_CNDmMOS.nc
#     Removing temp_marc_2000_mass_CNDmMOS.nc
#     Removing temp_marc_2000_column_CNDmMOS.nc
# Thu Jun 14 13:03:36 +08 2018
#   variable = CNDmMBS
#     Copying the file for CNDmMBS
#     Appending mass_air
#     Calculating the mass rate of CNDmMBS in each model level
#     Summing over levels
#     Renaming variable to cCNDmMBS
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cCNDmMBS_ANN.nc
#     Removing temp_marc_2000_CNDmMBS.nc
#     Removing temp_marc_2000_mass_CNDmMBS.nc
#     Removing temp_marc_2000_column_CNDmMBS.nc
# Thu Jun 14 13:04:24 +08 2018
#   variable = MVmNUC
#     Copying the file for MVmNUC
#     Appending mass_air
#     Calculating the mass rate of MVmNUC in each model level
#     Summing over levels
#     Renaming variable to cMVmNUC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cMVmNUC_ANN.nc
#     Removing temp_marc_2000_MVmNUC.nc
#     Removing temp_marc_2000_mass_MVmNUC.nc
#     Removing temp_marc_2000_column_MVmNUC.nc
# Thu Jun 14 13:05:08 +08 2018
#   variable = MVmAIT
#     Copying the file for MVmAIT
#     Appending mass_air
#     Calculating the mass rate of MVmAIT in each model level
#     Summing over levels
#     Renaming variable to cMVmAIT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cMVmAIT_ANN.nc
#     Removing temp_marc_2000_MVmAIT.nc
#     Removing temp_marc_2000_mass_MVmAIT.nc
#     Removing temp_marc_2000_column_MVmAIT.nc
# Thu Jun 14 13:05:56 +08 2018
#   variable = CGmNUCAC
#     Copying the file for CGmNUCAC
#     Appending mass_air
#     Calculating the mass rate of CGmNUCAC in each model level
#     Summing over levels
#     Renaming variable to cCGmNUCAC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cCGmNUCAC_ANN.nc
#     Removing temp_marc_2000_CGmNUCAC.nc
#     Removing temp_marc_2000_mass_CGmNUCAC.nc
#     Removing temp_marc_2000_column_CGmNUCAC.nc
# Thu Jun 14 13:06:39 +08 2018
#   variable = CGmNUCAI
#     Copying the file for CGmNUCAI
#     Appending mass_air
#     Calculating the mass rate of CGmNUCAI in each model level
#     Summing over levels
#     Renaming variable to cCGmNUCAI
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cCGmNUCAI_ANN.nc
#     Removing temp_marc_2000_CGmNUCAI.nc
#     Removing temp_marc_2000_mass_CGmNUCAI.nc
#     Removing temp_marc_2000_column_CGmNUCAI.nc
# Thu Jun 14 13:07:14 +08 2018
#   variable = CGmNUCMB
#     Copying the file for CGmNUCMB
#     Appending mass_air
#     Calculating the mass rate of CGmNUCMB in each model level
#     Summing over levels
#     Renaming variable to cCGmNUCMB
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cCGmNUCMB_ANN.nc
#     Removing temp_marc_2000_CGmNUCMB.nc
#     Removing temp_marc_2000_mass_CGmNUCMB.nc
#     Removing temp_marc_2000_column_CGmNUCMB.nc
# Thu Jun 14 13:07:52 +08 2018
#   variable = CGmNUCMO
#     Copying the file for CGmNUCMO
#     Appending mass_air
#     Calculating the mass rate of CGmNUCMO in each model level
#     Summing over levels
#     Renaming variable to cCGmNUCMO
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cCGmNUCMO_ANN.nc
#     Removing temp_marc_2000_CGmNUCMO.nc
#     Removing temp_marc_2000_mass_CGmNUCMO.nc
#     Removing temp_marc_2000_column_CGmNUCMO.nc
# Thu Jun 14 13:08:32 +08 2018
#   variable = CGmAITAC
#     Copying the file for CGmAITAC
#     Appending mass_air
#     Calculating the mass rate of CGmAITAC in each model level
#     Summing over levels
#     Renaming variable to cCGmAITAC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cCGmAITAC_ANN.nc
#     Removing temp_marc_2000_CGmAITAC.nc
#     Removing temp_marc_2000_mass_CGmAITAC.nc
#     Removing temp_marc_2000_column_CGmAITAC.nc
# Thu Jun 14 13:09:14 +08 2018
#   variable = CGmAITMB
#     Copying the file for CGmAITMB
#     Appending mass_air
#     Calculating the mass rate of CGmAITMB in each model level
#     Summing over levels
#     Renaming variable to cCGmAITMB
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cCGmAITMB_ANN.nc
#     Removing temp_marc_2000_CGmAITMB.nc
#     Removing temp_marc_2000_mass_CGmAITMB.nc
#     Removing temp_marc_2000_column_CGmAITMB.nc
# Thu Jun 14 13:09:55 +08 2018
#   variable = CGmAITMO
#     Copying the file for CGmAITMO
#     Appending mass_air
#     Calculating the mass rate of CGmAITMO in each model level
#     Summing over levels
#     Renaming variable to cCGmAITMO
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cCGmAITMO_ANN.nc
#     Removing temp_marc_2000_CGmAITMO.nc
#     Removing temp_marc_2000_mass_CGmAITMO.nc
#     Removing temp_marc_2000_column_CGmAITMO.nc
# Thu Jun 14 13:10:38 +08 2018
#   variable = CGmACCMB
#     Copying the file for CGmACCMB
#     Appending mass_air
#     Calculating the mass rate of CGmACCMB in each model level
#     Summing over levels
#     Renaming variable to cCGmACCMB
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cCGmACCMB_ANN.nc
#     Removing temp_marc_2000_CGmACCMB.nc
#     Removing temp_marc_2000_mass_CGmACCMB.nc
#     Removing temp_marc_2000_column_CGmACCMB.nc
# Thu Jun 14 13:11:31 +08 2018
#   variable = CGmACCMO
#     Copying the file for CGmACCMO
#     Appending mass_air
#     Calculating the mass rate of CGmACCMO in each model level
#     Summing over levels
#     Renaming variable to cCGmACCMO
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cCGmACCMO_ANN.nc
#     Removing temp_marc_2000_CGmACCMO.nc
#     Removing temp_marc_2000_mass_CGmACCMO.nc
#     Removing temp_marc_2000_column_CGmACCMO.nc
# Thu Jun 14 13:12:19 +08 2018
#   variable = CGmOCMOS
#     Copying the file for CGmOCMOS
#     Appending mass_air
#     Calculating the mass rate of CGmOCMOS in each model level
#     Summing over levels
#     Renaming variable to cCGmOCMOS
#     Setting units and long_name
#     Calculating annual means
#     Written marc_2000_cCGmOCMOS_ANN.nc
#     Removing temp_marc_2000_CGmOCMOS.nc
#     Removing temp_marc_2000_mass_CGmOCMOS.nc
#     Removing temp_marc_2000_column_CGmOCMOS.nc
#   Removing temp_marc_2000_PS.nc
#   Removing temp_marc_2000_mass_air.nc
#   Removing temp_marc_2000.nco
# Thu Jun 14 13:13:05 +08 2018
# year = 1850
#   Copying surface pressure file
#   Calculating mass of air in each model level
# Thu Jun 14 13:13:46 +08 2018
#   variable = mACCWET
#     Copying the file for mACCWET
#     Appending mass_air
#     Calculating the mass rate of mACCWET in each model level
#     Summing over levels
#     Renaming variable to cmACCWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmACCWET_ANN.nc
#     Removing temp_marc_1850_mACCWET.nc
#     Removing temp_marc_1850_mass_mACCWET.nc
#     Removing temp_marc_1850_column_mACCWET.nc
# Thu Jun 14 13:14:33 +08 2018
#   variable = mAITWET
#     Copying the file for mAITWET
#     Appending mass_air
#     Calculating the mass rate of mAITWET in each model level
#     Summing over levels
#     Renaming variable to cmAITWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmAITWET_ANN.nc
#     Removing temp_marc_1850_mAITWET.nc
#     Removing temp_marc_1850_mass_mAITWET.nc
#     Removing temp_marc_1850_column_mAITWET.nc
# Thu Jun 14 13:15:18 +08 2018
#   variable = mNUCWET
#     Copying the file for mNUCWET
#     Appending mass_air
#     Calculating the mass rate of mNUCWET in each model level
#     Summing over levels
#     Renaming variable to cmNUCWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmNUCWET_ANN.nc
#     Removing temp_marc_1850_mNUCWET.nc
#     Removing temp_marc_1850_mass_mNUCWET.nc
#     Removing temp_marc_1850_column_mNUCWET.nc
# Thu Jun 14 13:16:03 +08 2018
#   variable = mOCWET
#     Copying the file for mOCWET
#     Appending mass_air
#     Calculating the mass rate of mOCWET in each model level
#     Summing over levels
#     Renaming variable to cmOCWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmOCWET_ANN.nc
#     Removing temp_marc_1850_mOCWET.nc
#     Removing temp_marc_1850_mass_mOCWET.nc
#     Removing temp_marc_1850_column_mOCWET.nc
# Thu Jun 14 13:16:47 +08 2018
#   variable = mMOSWET
#     Copying the file for mMOSWET
#     Appending mass_air
#     Calculating the mass rate of mMOSWET in each model level
#     Summing over levels
#     Renaming variable to cmMOSWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmMOSWET_ANN.nc
#     Removing temp_marc_1850_mMOSWET.nc
#     Removing temp_marc_1850_mass_mMOSWET.nc
#     Removing temp_marc_1850_column_mMOSWET.nc
# Thu Jun 14 13:17:34 +08 2018
#   variable = mOIMWET
#     Copying the file for mOIMWET
#     Appending mass_air
#     Calculating the mass rate of mOIMWET in each model level
#     Summing over levels
#     Renaming variable to cmOIMWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmOIMWET_ANN.nc
#     Removing temp_marc_1850_mOIMWET.nc
#     Removing temp_marc_1850_mass_mOIMWET.nc
#     Removing temp_marc_1850_column_mOIMWET.nc
# Thu Jun 14 13:18:20 +08 2018
#   variable = mBCWET
#     Copying the file for mBCWET
#     Appending mass_air
#     Calculating the mass rate of mBCWET in each model level
#     Summing over levels
#     Renaming variable to cmBCWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmBCWET_ANN.nc
#     Removing temp_marc_1850_mBCWET.nc
#     Removing temp_marc_1850_mass_mBCWET.nc
#     Removing temp_marc_1850_column_mBCWET.nc
# Thu Jun 14 13:19:07 +08 2018
#   variable = mMBSWET
#     Copying the file for mMBSWET
#     Appending mass_air
#     Calculating the mass rate of mMBSWET in each model level
#     Summing over levels
#     Renaming variable to cmMBSWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmMBSWET_ANN.nc
#     Removing temp_marc_1850_mMBSWET.nc
#     Removing temp_marc_1850_mass_mMBSWET.nc
#     Removing temp_marc_1850_column_mMBSWET.nc
# Thu Jun 14 13:19:54 +08 2018
#   variable = mBIMWET
#     Copying the file for mBIMWET
#     Appending mass_air
#     Calculating the mass rate of mBIMWET in each model level
#     Summing over levels
#     Renaming variable to cmBIMWET
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmBIMWET_ANN.nc
#     Removing temp_marc_1850_mBIMWET.nc
#     Removing temp_marc_1850_mass_mBIMWET.nc
#     Removing temp_marc_1850_column_mBIMWET.nc
# Thu Jun 14 13:20:40 +08 2018
#   variable = DST01PP
#     Copying the file for DST01PP
#     Appending mass_air
#     Calculating the mass rate of DST01PP in each model level
#     Summing over levels
#     Renaming variable to cDST01PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cDST01PP_ANN.nc
#     Removing temp_marc_1850_DST01PP.nc
#     Removing temp_marc_1850_mass_DST01PP.nc
#     Removing temp_marc_1850_column_DST01PP.nc
# Thu Jun 14 13:21:29 +08 2018
#   variable = DST02PP
#     Copying the file for DST02PP
#     Appending mass_air
#     Calculating the mass rate of DST02PP in each model level
#     Summing over levels
#     Renaming variable to cDST02PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cDST02PP_ANN.nc
#     Removing temp_marc_1850_DST02PP.nc
#     Removing temp_marc_1850_mass_DST02PP.nc
#     Removing temp_marc_1850_column_DST02PP.nc
# Thu Jun 14 13:22:15 +08 2018
#   variable = DST03PP
#     Copying the file for DST03PP
#     Appending mass_air
#     Calculating the mass rate of DST03PP in each model level
#     Summing over levels
#     Renaming variable to cDST03PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cDST03PP_ANN.nc
#     Removing temp_marc_1850_DST03PP.nc
#     Removing temp_marc_1850_mass_DST03PP.nc
#     Removing temp_marc_1850_column_DST03PP.nc
# Thu Jun 14 13:23:03 +08 2018
#   variable = DST04PP
#     Copying the file for DST04PP
#     Appending mass_air
#     Calculating the mass rate of DST04PP in each model level
#     Summing over levels
#     Renaming variable to cDST04PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cDST04PP_ANN.nc
#     Removing temp_marc_1850_DST04PP.nc
#     Removing temp_marc_1850_mass_DST04PP.nc
#     Removing temp_marc_1850_column_DST04PP.nc
# Thu Jun 14 13:23:48 +08 2018
#   variable = SSLT01PP
#     Copying the file for SSLT01PP
#     Appending mass_air
#     Calculating the mass rate of SSLT01PP in each model level
#     Summing over levels
#     Renaming variable to cSSLT01PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cSSLT01PP_ANN.nc
#     Removing temp_marc_1850_SSLT01PP.nc
#     Removing temp_marc_1850_mass_SSLT01PP.nc
#     Removing temp_marc_1850_column_SSLT01PP.nc
# Thu Jun 14 13:24:34 +08 2018
#   variable = SSLT02PP
#     Copying the file for SSLT02PP
#     Appending mass_air
#     Calculating the mass rate of SSLT02PP in each model level
#     Summing over levels
#     Renaming variable to cSSLT02PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cSSLT02PP_ANN.nc
#     Removing temp_marc_1850_SSLT02PP.nc
#     Removing temp_marc_1850_mass_SSLT02PP.nc
#     Removing temp_marc_1850_column_SSLT02PP.nc
# Thu Jun 14 13:25:20 +08 2018
#   variable = SSLT03PP
#     Copying the file for SSLT03PP
#     Appending mass_air
#     Calculating the mass rate of SSLT03PP in each model level
#     Summing over levels
#     Renaming variable to cSSLT03PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cSSLT03PP_ANN.nc
#     Removing temp_marc_1850_SSLT03PP.nc
#     Removing temp_marc_1850_mass_SSLT03PP.nc
#     Removing temp_marc_1850_column_SSLT03PP.nc
# Thu Jun 14 13:26:05 +08 2018
#   variable = SSLT04PP
#     Copying the file for SSLT04PP
#     Appending mass_air
#     Calculating the mass rate of SSLT04PP in each model level
#     Summing over levels
#     Renaming variable to cSSLT04PP
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cSSLT04PP_ANN.nc
#     Removing temp_marc_1850_SSLT04PP.nc
#     Removing temp_marc_1850_mass_SSLT04PP.nc
#     Removing temp_marc_1850_column_SSLT04PP.nc
# Thu Jun 14 13:26:51 +08 2018
#   variable = AGEmOC
#     Copying the file for AGEmOC
#     Appending mass_air
#     Calculating the mass rate of AGEmOC in each model level
#     Summing over levels
#     Renaming variable to cAGEmOC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cAGEmOC_ANN.nc
#     Removing temp_marc_1850_AGEmOC.nc
#     Removing temp_marc_1850_mass_AGEmOC.nc
#     Removing temp_marc_1850_column_AGEmOC.nc
# Thu Jun 14 13:27:41 +08 2018
#   variable = AGEmMOS
#     Copying the file for AGEmMOS
#     Appending mass_air
#     Calculating the mass rate of AGEmMOS in each model level
#     Summing over levels
#     Renaming variable to cAGEmMOS
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cAGEmMOS_ANN.nc
#     Removing temp_marc_1850_AGEmMOS.nc
#     Removing temp_marc_1850_mass_AGEmMOS.nc
#     Removing temp_marc_1850_column_AGEmMOS.nc
# Thu Jun 14 13:28:31 +08 2018
#   variable = AGEmBC
#     Copying the file for AGEmBC
#     Appending mass_air
#     Calculating the mass rate of AGEmBC in each model level
#     Summing over levels
#     Renaming variable to cAGEmBC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cAGEmBC_ANN.nc
#     Removing temp_marc_1850_AGEmBC.nc
#     Removing temp_marc_1850_mass_AGEmBC.nc
#     Removing temp_marc_1850_column_AGEmBC.nc
# Thu Jun 14 13:29:16 +08 2018
#   variable = AGEmMBS
#     Copying the file for AGEmMBS
#     Appending mass_air
#     Calculating the mass rate of AGEmMBS in each model level
#     Summing over levels
#     Renaming variable to cAGEmMBS
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cAGEmMBS_ANN.nc
#     Removing temp_marc_1850_AGEmMBS.nc
#     Removing temp_marc_1850_mass_AGEmMBS.nc
#     Removing temp_marc_1850_column_AGEmMBS.nc
# Thu Jun 14 13:30:02 +08 2018
#   variable = mACCACT
#     Copying the file for mACCACT
#     Appending mass_air
#     Calculating the mass rate of mACCACT in each model level
#     Summing over levels
#     Renaming variable to cmACCACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmACCACT_ANN.nc
#     Removing temp_marc_1850_mACCACT.nc
#     Removing temp_marc_1850_mass_mACCACT.nc
#     Removing temp_marc_1850_column_mACCACT.nc
# Thu Jun 14 13:30:50 +08 2018
#   variable = mAITACT
#     Copying the file for mAITACT
#     Appending mass_air
#     Calculating the mass rate of mAITACT in each model level
#     Summing over levels
#     Renaming variable to cmAITACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmAITACT_ANN.nc
#     Removing temp_marc_1850_mAITACT.nc
#     Removing temp_marc_1850_mass_mAITACT.nc
#     Removing temp_marc_1850_column_mAITACT.nc
# Thu Jun 14 13:31:37 +08 2018
#   variable = mNUCACT
#     Copying the file for mNUCACT
#     Appending mass_air
#     Calculating the mass rate of mNUCACT in each model level
#     Summing over levels
#     Renaming variable to cmNUCACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmNUCACT_ANN.nc
#     Removing temp_marc_1850_mNUCACT.nc
#     Removing temp_marc_1850_mass_mNUCACT.nc
#     Removing temp_marc_1850_column_mNUCACT.nc
# Thu Jun 14 13:32:25 +08 2018
#   variable = mOCACT
#     Copying the file for mOCACT
#     Appending mass_air
#     Calculating the mass rate of mOCACT in each model level
#     Summing over levels
#     Renaming variable to cmOCACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmOCACT_ANN.nc
#     Removing temp_marc_1850_mOCACT.nc
#     Removing temp_marc_1850_mass_mOCACT.nc
#     Removing temp_marc_1850_column_mOCACT.nc
# Thu Jun 14 13:33:20 +08 2018
#   variable = mMOSACT
#     Copying the file for mMOSACT
#     Appending mass_air
#     Calculating the mass rate of mMOSACT in each model level
#     Summing over levels
#     Renaming variable to cmMOSACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmMOSACT_ANN.nc
#     Removing temp_marc_1850_mMOSACT.nc
#     Removing temp_marc_1850_mass_mMOSACT.nc
#     Removing temp_marc_1850_column_mMOSACT.nc
# Thu Jun 14 13:34:15 +08 2018
#   variable = mOIMACT
#     Copying the file for mOIMACT
#     Appending mass_air
#     Calculating the mass rate of mOIMACT in each model level
#     Summing over levels
#     Renaming variable to cmOIMACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmOIMACT_ANN.nc
#     Removing temp_marc_1850_mOIMACT.nc
#     Removing temp_marc_1850_mass_mOIMACT.nc
#     Removing temp_marc_1850_column_mOIMACT.nc
# Thu Jun 14 13:35:04 +08 2018
#   variable = mBCACT
#     Copying the file for mBCACT
#     Appending mass_air
#     Calculating the mass rate of mBCACT in each model level
#     Summing over levels
#     Renaming variable to cmBCACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmBCACT_ANN.nc
#     Removing temp_marc_1850_mBCACT.nc
#     Removing temp_marc_1850_mass_mBCACT.nc
#     Removing temp_marc_1850_column_mBCACT.nc
# Thu Jun 14 13:35:52 +08 2018
#   variable = mMBSACT
#     Copying the file for mMBSACT
#     Appending mass_air
#     Calculating the mass rate of mMBSACT in each model level
#     Summing over levels
#     Renaming variable to cmMBSACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmMBSACT_ANN.nc
#     Removing temp_marc_1850_mMBSACT.nc
#     Removing temp_marc_1850_mass_mMBSACT.nc
#     Removing temp_marc_1850_column_mMBSACT.nc
# Thu Jun 14 13:36:40 +08 2018
#   variable = mBIMACT
#     Copying the file for mBIMACT
#     Appending mass_air
#     Calculating the mass rate of mBIMACT in each model level
#     Summing over levels
#     Renaming variable to cmBIMACT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmBIMACT_ANN.nc
#     Removing temp_marc_1850_mBIMACT.nc
#     Removing temp_marc_1850_mass_mBIMACT.nc
#     Removing temp_marc_1850_column_mBIMACT.nc
# Thu Jun 14 13:37:29 +08 2018
#   variable = mACCSCV
#     Copying the file for mACCSCV
#     Appending mass_air
#     Calculating the mass rate of mACCSCV in each model level
#     Summing over levels
#     Renaming variable to cmACCSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmACCSCV_ANN.nc
#     Removing temp_marc_1850_mACCSCV.nc
#     Removing temp_marc_1850_mass_mACCSCV.nc
#     Removing temp_marc_1850_column_mACCSCV.nc
# Thu Jun 14 13:38:20 +08 2018
#   variable = mAITSCV
#     Copying the file for mAITSCV
#     Appending mass_air
#     Calculating the mass rate of mAITSCV in each model level
#     Summing over levels
#     Renaming variable to cmAITSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmAITSCV_ANN.nc
#     Removing temp_marc_1850_mAITSCV.nc
#     Removing temp_marc_1850_mass_mAITSCV.nc
#     Removing temp_marc_1850_column_mAITSCV.nc
# Thu Jun 14 13:39:04 +08 2018
#   variable = mNUCSCV
#     Copying the file for mNUCSCV
#     Appending mass_air
#     Calculating the mass rate of mNUCSCV in each model level
#     Summing over levels
#     Renaming variable to cmNUCSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmNUCSCV_ANN.nc
#     Removing temp_marc_1850_mNUCSCV.nc
#     Removing temp_marc_1850_mass_mNUCSCV.nc
#     Removing temp_marc_1850_column_mNUCSCV.nc
# Thu Jun 14 13:39:49 +08 2018
#   variable = mOCSCV
#     Copying the file for mOCSCV
#     Appending mass_air
#     Calculating the mass rate of mOCSCV in each model level
#     Summing over levels
#     Renaming variable to cmOCSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmOCSCV_ANN.nc
#     Removing temp_marc_1850_mOCSCV.nc
#     Removing temp_marc_1850_mass_mOCSCV.nc
#     Removing temp_marc_1850_column_mOCSCV.nc
# Thu Jun 14 13:40:47 +08 2018
#   variable = mMOSSCV
#     Copying the file for mMOSSCV
#     Appending mass_air
#     Calculating the mass rate of mMOSSCV in each model level
#     Summing over levels
#     Renaming variable to cmMOSSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmMOSSCV_ANN.nc
#     Removing temp_marc_1850_mMOSSCV.nc
#     Removing temp_marc_1850_mass_mMOSSCV.nc
#     Removing temp_marc_1850_column_mMOSSCV.nc
# Thu Jun 14 13:41:45 +08 2018
#   variable = mOIMSCV
#     Copying the file for mOIMSCV
#     Appending mass_air
#     Calculating the mass rate of mOIMSCV in each model level
#     Summing over levels
#     Renaming variable to cmOIMSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmOIMSCV_ANN.nc
#     Removing temp_marc_1850_mOIMSCV.nc
#     Removing temp_marc_1850_mass_mOIMSCV.nc
#     Removing temp_marc_1850_column_mOIMSCV.nc
# Thu Jun 14 13:42:37 +08 2018
#   variable = mBCSCV
#     Copying the file for mBCSCV
#     Appending mass_air
#     Calculating the mass rate of mBCSCV in each model level
#     Summing over levels
#     Renaming variable to cmBCSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmBCSCV_ANN.nc
#     Removing temp_marc_1850_mBCSCV.nc
#     Removing temp_marc_1850_mass_mBCSCV.nc
#     Removing temp_marc_1850_column_mBCSCV.nc
# Thu Jun 14 13:43:30 +08 2018
#   variable = mMBSSCV
#     Copying the file for mMBSSCV
#     Appending mass_air
#     Calculating the mass rate of mMBSSCV in each model level
#     Summing over levels
#     Renaming variable to cmMBSSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmMBSSCV_ANN.nc
#     Removing temp_marc_1850_mMBSSCV.nc
#     Removing temp_marc_1850_mass_mMBSSCV.nc
#     Removing temp_marc_1850_column_mMBSSCV.nc
# Thu Jun 14 13:44:21 +08 2018
#   variable = mBIMSCV
#     Copying the file for mBIMSCV
#     Appending mass_air
#     Calculating the mass rate of mBIMSCV in each model level
#     Summing over levels
#     Renaming variable to cmBIMSCV
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmBIMSCV_ANN.nc
#     Removing temp_marc_1850_mBIMSCV.nc
#     Removing temp_marc_1850_mass_mBIMSCV.nc
#     Removing temp_marc_1850_column_mBIMSCV.nc
# Thu Jun 14 13:45:12 +08 2018
#   variable = mSO4evap
#     Copying the file for mSO4evap
#     Appending mass_air
#     Calculating the mass rate of mSO4evap in each model level
#     Summing over levels
#     Renaming variable to cmSO4evap
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cmSO4evap_ANN.nc
#     Removing temp_marc_1850_mSO4evap.nc
#     Removing temp_marc_1850_mass_mSO4evap.nc
#     Removing temp_marc_1850_column_mSO4evap.nc
# Thu Jun 14 13:46:02 +08 2018
#   variable = BNUCmNUC
#     Copying the file for BNUCmNUC
#     Appending mass_air
#     Calculating the mass rate of BNUCmNUC in each model level
#     Summing over levels
#     Renaming variable to cBNUCmNUC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cBNUCmNUC_ANN.nc
#     Removing temp_marc_1850_BNUCmNUC.nc
#     Removing temp_marc_1850_mass_BNUCmNUC.nc
#     Removing temp_marc_1850_column_BNUCmNUC.nc
# Thu Jun 14 13:46:42 +08 2018
#   variable = CNDmACC
#     Copying the file for CNDmACC
#     Appending mass_air
#     Calculating the mass rate of CNDmACC in each model level
#     Summing over levels
#     Renaming variable to cCNDmACC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cCNDmACC_ANN.nc
#     Removing temp_marc_1850_CNDmACC.nc
#     Removing temp_marc_1850_mass_CNDmACC.nc
#     Removing temp_marc_1850_column_CNDmACC.nc
# Thu Jun 14 13:47:28 +08 2018
#   variable = CNDmAIT
#     Copying the file for CNDmAIT
#     Appending mass_air
#     Calculating the mass rate of CNDmAIT in each model level
#     Summing over levels
#     Renaming variable to cCNDmAIT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cCNDmAIT_ANN.nc
#     Removing temp_marc_1850_CNDmAIT.nc
#     Removing temp_marc_1850_mass_CNDmAIT.nc
#     Removing temp_marc_1850_column_CNDmAIT.nc
# Thu Jun 14 13:48:09 +08 2018
#   variable = CNDmNUC
#     Copying the file for CNDmNUC
#     Appending mass_air
#     Calculating the mass rate of CNDmNUC in each model level
#     Summing over levels
#     Renaming variable to cCNDmNUC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cCNDmNUC_ANN.nc
#     Removing temp_marc_1850_CNDmNUC.nc
#     Removing temp_marc_1850_mass_CNDmNUC.nc
#     Removing temp_marc_1850_column_CNDmNUC.nc
# Thu Jun 14 13:48:51 +08 2018
#   variable = CNDmMOS
#     Copying the file for CNDmMOS
#     Appending mass_air
#     Calculating the mass rate of CNDmMOS in each model level
#     Summing over levels
#     Renaming variable to cCNDmMOS
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cCNDmMOS_ANN.nc
#     Removing temp_marc_1850_CNDmMOS.nc
#     Removing temp_marc_1850_mass_CNDmMOS.nc
#     Removing temp_marc_1850_column_CNDmMOS.nc
# Thu Jun 14 13:49:36 +08 2018
#   variable = CNDmMBS
#     Copying the file for CNDmMBS
#     Appending mass_air
#     Calculating the mass rate of CNDmMBS in each model level
#     Summing over levels
#     Renaming variable to cCNDmMBS
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cCNDmMBS_ANN.nc
#     Removing temp_marc_1850_CNDmMBS.nc
#     Removing temp_marc_1850_mass_CNDmMBS.nc
#     Removing temp_marc_1850_column_CNDmMBS.nc
# Thu Jun 14 13:50:19 +08 2018
#   variable = MVmNUC
#     Copying the file for MVmNUC
#     Appending mass_air
#     Calculating the mass rate of MVmNUC in each model level
#     Summing over levels
#     Renaming variable to cMVmNUC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cMVmNUC_ANN.nc
#     Removing temp_marc_1850_MVmNUC.nc
#     Removing temp_marc_1850_mass_MVmNUC.nc
#     Removing temp_marc_1850_column_MVmNUC.nc
# Thu Jun 14 13:50:57 +08 2018
#   variable = MVmAIT
#     Copying the file for MVmAIT
#     Appending mass_air
#     Calculating the mass rate of MVmAIT in each model level
#     Summing over levels
#     Renaming variable to cMVmAIT
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cMVmAIT_ANN.nc
#     Removing temp_marc_1850_MVmAIT.nc
#     Removing temp_marc_1850_mass_MVmAIT.nc
#     Removing temp_marc_1850_column_MVmAIT.nc
# Thu Jun 14 13:51:38 +08 2018
#   variable = CGmNUCAC
#     Copying the file for CGmNUCAC
#     Appending mass_air
#     Calculating the mass rate of CGmNUCAC in each model level
#     Summing over levels
#     Renaming variable to cCGmNUCAC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cCGmNUCAC_ANN.nc
#     Removing temp_marc_1850_CGmNUCAC.nc
#     Removing temp_marc_1850_mass_CGmNUCAC.nc
#     Removing temp_marc_1850_column_CGmNUCAC.nc
# Thu Jun 14 13:52:18 +08 2018
#   variable = CGmNUCAI
#     Copying the file for CGmNUCAI
#     Appending mass_air
#     Calculating the mass rate of CGmNUCAI in each model level
#     Summing over levels
#     Renaming variable to cCGmNUCAI
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cCGmNUCAI_ANN.nc
#     Removing temp_marc_1850_CGmNUCAI.nc
#     Removing temp_marc_1850_mass_CGmNUCAI.nc
#     Removing temp_marc_1850_column_CGmNUCAI.nc
# Thu Jun 14 13:52:56 +08 2018
#   variable = CGmNUCMB
#     Copying the file for CGmNUCMB
#     Appending mass_air
#     Calculating the mass rate of CGmNUCMB in each model level
#     Summing over levels
#     Renaming variable to cCGmNUCMB
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cCGmNUCMB_ANN.nc
#     Removing temp_marc_1850_CGmNUCMB.nc
#     Removing temp_marc_1850_mass_CGmNUCMB.nc
#     Removing temp_marc_1850_column_CGmNUCMB.nc
# Thu Jun 14 13:53:33 +08 2018
#   variable = CGmNUCMO
#     Copying the file for CGmNUCMO
#     Appending mass_air
#     Calculating the mass rate of CGmNUCMO in each model level
#     Summing over levels
#     Renaming variable to cCGmNUCMO
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cCGmNUCMO_ANN.nc
#     Removing temp_marc_1850_CGmNUCMO.nc
#     Removing temp_marc_1850_mass_CGmNUCMO.nc
#     Removing temp_marc_1850_column_CGmNUCMO.nc
# Thu Jun 14 13:54:11 +08 2018
#   variable = CGmAITAC
#     Copying the file for CGmAITAC
#     Appending mass_air
#     Calculating the mass rate of CGmAITAC in each model level
#     Summing over levels
#     Renaming variable to cCGmAITAC
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cCGmAITAC_ANN.nc
#     Removing temp_marc_1850_CGmAITAC.nc
#     Removing temp_marc_1850_mass_CGmAITAC.nc
#     Removing temp_marc_1850_column_CGmAITAC.nc
# Thu Jun 14 13:55:00 +08 2018
#   variable = CGmAITMB
#     Copying the file for CGmAITMB
#     Appending mass_air
#     Calculating the mass rate of CGmAITMB in each model level
#     Summing over levels
#     Renaming variable to cCGmAITMB
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cCGmAITMB_ANN.nc
#     Removing temp_marc_1850_CGmAITMB.nc
#     Removing temp_marc_1850_mass_CGmAITMB.nc
#     Removing temp_marc_1850_column_CGmAITMB.nc
# Thu Jun 14 13:55:39 +08 2018
#   variable = CGmAITMO
#     Copying the file for CGmAITMO
#     Appending mass_air
#     Calculating the mass rate of CGmAITMO in each model level
#     Summing over levels
#     Renaming variable to cCGmAITMO
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cCGmAITMO_ANN.nc
#     Removing temp_marc_1850_CGmAITMO.nc
#     Removing temp_marc_1850_mass_CGmAITMO.nc
#     Removing temp_marc_1850_column_CGmAITMO.nc
# Thu Jun 14 13:56:22 +08 2018
#   variable = CGmACCMB
#     Copying the file for CGmACCMB
#     Appending mass_air
#     Calculating the mass rate of CGmACCMB in each model level
#     Summing over levels
#     Renaming variable to cCGmACCMB
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cCGmACCMB_ANN.nc
#     Removing temp_marc_1850_CGmACCMB.nc
#     Removing temp_marc_1850_mass_CGmACCMB.nc
#     Removing temp_marc_1850_column_CGmACCMB.nc
# Thu Jun 14 13:57:14 +08 2018
#   variable = CGmACCMO
#     Copying the file for CGmACCMO
#     Appending mass_air
#     Calculating the mass rate of CGmACCMO in each model level
#     Summing over levels
#     Renaming variable to cCGmACCMO
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cCGmACCMO_ANN.nc
#     Removing temp_marc_1850_CGmACCMO.nc
#     Removing temp_marc_1850_mass_CGmACCMO.nc
#     Removing temp_marc_1850_column_CGmACCMO.nc
# Thu Jun 14 13:58:07 +08 2018
#   variable = CGmOCMOS
#     Copying the file for CGmOCMOS
#     Appending mass_air
#     Calculating the mass rate of CGmOCMOS in each model level
#     Summing over levels
#     Renaming variable to cCGmOCMOS
#     Setting units and long_name
#     Calculating annual means
#     Written marc_1850_cCGmOCMOS_ANN.nc
#     Removing temp_marc_1850_CGmOCMOS.nc
#     Removing temp_marc_1850_mass_CGmOCMOS.nc
#     Removing temp_marc_1850_column_CGmOCMOS.nc
#   Removing temp_marc_1850_PS.nc
#   Removing temp_marc_1850_mass_air.nc
#   Removing temp_marc_1850.nco
# Thu Jun 14 13:58:54 +08 2018

# %% [markdown]
# ## Derive additional variables of interest
# - Total sulfate, total OC, total BC, total dust, total sea-salt.
# - Sum of sources and sinks for each of these.

# %%
derived_variable_list = [
    # Total sulfate. Note: mode mass adjustment and coagulation balance to zero.
    'ctSUL_DRY=mNUCDRY+mAITDRY+mACCDRY+mMOSDRY+mMBSDRY-mOIMDRY-mBIMDRY',  # dry deposition
    'ctSUL_WET=cmNUCWET+cmAITWET+cmACCWET+cmMOSWET+cmMBSWET-cmOIMWET-cmBIMWET',  # wet deposition
    'ctSUL_ACT=cmNUCACT+cmAITACT+cmACCACT+cmMOSACT+cmMBSACT-cmOIMACT-cmBIMACT',  # strat. nuc. scav.
    'ctSUL_SCV=cmNUCSCV+cmAITSCV+cmACCSCV+cmMOSSCV+cmMBSSCV-cmOIMSCV-cmBIMSCV',  # conv. nuc. scav.
    'ctSUL_CND=cCNDmNUC+cCNDmAIT+cCNDmACC+cCNDmMOS+cCNDmMBS',  # H2SO4 condensation
    'ctSUL_NUC=cBNUCmNUC',  # binary nucleation
    'ctSUL_EVAP=cmSO4evap',  # SO4 cloud evaporation
    'ctSUL_AGE=cAGEmMOS+cAGEmMBS',  # aging
    'ctSUL_SOURCE=ctSUL_CND+ctSUL_NUC+ctSUL_EVAP+ctSUL_AGE',  # sum of sources
    'ctSUL_SINK=ctSUL_DRY-ctSUL_WET-ctSUL_ACT-ctSUL_SCV',  # sum of sinks; dry dep has diff sign
    # Total OC. Note: aging and coagulation balance to zero.
    'ctOC_SF=mOCSF',  # emissions (including SOA)
    'ctOC_DRY=mOCDRY+mOIMDRY',  # dry deposition
    'ctOC_WET=cmOCWET+cmOIMWET',  # wet deposition
    'ctOC_ACT=cmOCACT+cmOIMACT',  # strat. nuc. scav.
    'ctOC_SCV=cmOCSCV+cmOIMSCV',  # conv. nuc. svav.
    'ctOC_SOURCE=ctOC_SF',  # sum of sources
    'ctOC_SINK=ctOC_DRY-ctOC_WET-ctOC_ACT-ctOC_SCV',  # sum of sinks
    # Total BC. Note: aging balances to zero.
    'ctBC_SF=mBCSF',  # emissions
    'ctBC_DRY=mBCDRY+mBIMDRY',  # dry deposition
    'ctBC_WET=cmBCWET+cmBIMWET',  # wet deposition
    'ctBC_ACT=cmBCACT+cmBIMACT',  # strat. nuc. scav.
    'ctBC_SCV=cmBCSCV+cmBIMSCV',  # conv. nuc. svav.
    'ctBC_SOURCE=ctBC_SF',  # sum of sources
    'ctBC_SINK=ctBC_DRY-ctBC_WET-ctBC_ACT-ctBC_SCV',  # sum of sinks
    # Total dust
    'ctDST_SF=DST01SF+DST02SF+DST03SF+DST04SF',  # emissions
    'ctDST_DRY=DST01DD+DST02DD+DST03DD+DST04DD',  # dry deposition
    'ctDST_WET=cDST01PP+cDST02PP+cDST03PP+cDST04PP',  # wet deposition
    'ctDST_SOURCE=ctDST_SF',  # sum of sources
    'ctDST_SINK=ctDST_DRY-ctDST_WET',  # sum of sinks
    # Total sea-salt
    'ctSSLT_SF=SSLT01SF+SSLT02SF+SSLT03SF+SSLT04SF',  # emissions
    'ctSSLT_DRY=SSLT01DD+SSLT02DD+SSLT03DD+SSLT04DD',  # dry deposition
    'ctSSLT_WET=cSSLT01PP+cSSLT02PP+cSSLT03PP+cSSLT04PP',  # wet deposition
    'ctSSLT_SOURCE=ctSSLT_SF',  # sum of sources
    'ctSSLT_SINK=ctSSLT_DRY-ctSSLT_WET',  # sum of sinks
    ]

# %%
for year in ['2000', '1850']:  # loop over year-2000 and year-1850
    for derived_variable in derived_variable_list:  # loop over variables to derive
        print('{}, {}'.format(derived_variable, year))
        variable_list = re.split('\=|\+|\-', derived_variable)  # list of variables in derived variable
        # Merge input files
        in_filename_list = []
        for variable in variable_list[1:]:
            in_filename_list.append('{}/marc_{}_{}_ANN.nc'.format(out_dir, year, variable))
        merge_filename = '{}/temp_{}_merge_ANN.nc'.format(out_dir, year)
        if len(in_filename_list) == 1:  # merge case 1: 1 input file
            ! cp {in_filename_list[0]} {merge_filename}
        elif len(in_filename_list) == 2:  # merge case 2: 2 input files
            ! cdo -s merge {in_filename_list[0]} {in_filename_list[1]} \
                {merge_filename} >/dev/null 2>/dev/null
        elif len(in_filename_list) == 4:  # merge case 3: 4 input files
            ! cdo -s merge {in_filename_list[0]} {in_filename_list[1]} {in_filename_list[2]} \
                {in_filename_list[3]} \
                {merge_filename} >/dev/null 2>/dev/null
        elif len(in_filename_list) == 5:  # merge case 4: 5 input files
            ! cdo -s merge {in_filename_list[0]} {in_filename_list[1]} {in_filename_list[2]} \
                {in_filename_list[3]} {in_filename_list[4]} \
                {merge_filename} >/dev/null 2>/dev/null
        elif len(in_filename_list) == 7:  # merge case 5: 7 input files
            ! cdo -s merge {in_filename_list[0]} {in_filename_list[1]} {in_filename_list[2]} \
                {in_filename_list[3]} {in_filename_list[4]} {in_filename_list[5]} \
                {in_filename_list[6]} {merge_filename} >/dev/null 2>/dev/null
        # Calculate derived variable
        out_filename = '{}/marc_{}_{}_ANN.nc'.format(out_dir, year, variable_list[0])
        ! cdo -s expr,'{derived_variable}' {merge_filename} {out_filename}
        if os.path.isfile(out_filename):
            print('  Written {}'.format(out_filename.split('/')[-1]))
        # Remove temporary file
        for filename in [merge_filename, ]:
            print('  Removing {}'.format(filename.split('/')[-1]))
            os.remove(filename)
! date
# Out:
# ctSUL_DRY=mNUCDRY+mAITDRY+mACCDRY+mMOSDRY+mMBSDRY-mOIMDRY-mBIMDRY, 2000
#   Written marc_2000_ctSUL_DRY_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSUL_WET=cmNUCWET+cmAITWET+cmACCWET+cmMOSWET+cmMBSWET-cmOIMWET-cmBIMWET, 2000
#   Written marc_2000_ctSUL_WET_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSUL_ACT=cmNUCACT+cmAITACT+cmACCACT+cmMOSACT+cmMBSACT-cmOIMACT-cmBIMACT, 2000
#   Written marc_2000_ctSUL_ACT_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSUL_SCV=cmNUCSCV+cmAITSCV+cmACCSCV+cmMOSSCV+cmMBSSCV-cmOIMSCV-cmBIMSCV, 2000
#   Written marc_2000_ctSUL_SCV_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSUL_CND=cCNDmNUC+cCNDmAIT+cCNDmACC+cCNDmMOS+cCNDmMBS, 2000
#   Written marc_2000_ctSUL_CND_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSUL_NUC=cBNUCmNUC, 2000
#   Written marc_2000_ctSUL_NUC_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSUL_EVAP=cmSO4evap, 2000
#   Written marc_2000_ctSUL_EVAP_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSUL_AGE=cAGEmMOS+cAGEmMBS, 2000
#   Written marc_2000_ctSUL_AGE_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSUL_SOURCE=ctSUL_CND+ctSUL_NUC+ctSUL_EVAP+ctSUL_AGE, 2000
#   Written marc_2000_ctSUL_SOURCE_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSUL_SINK=ctSUL_DRY-ctSUL_WET-ctSUL_ACT-ctSUL_SCV, 2000
#   Written marc_2000_ctSUL_SINK_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctOC_SF=mOCSF, 2000
#   Written marc_2000_ctOC_SF_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctOC_DRY=mOCDRY+mOIMDRY, 2000
#   Written marc_2000_ctOC_DRY_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctOC_WET=cmOCWET+cmOIMWET, 2000
#   Written marc_2000_ctOC_WET_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctOC_ACT=cmOCACT+cmOIMACT, 2000
#   Written marc_2000_ctOC_ACT_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctOC_SCV=cmOCSCV+cmOIMSCV, 2000
#   Written marc_2000_ctOC_SCV_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctOC_SOURCE=ctOC_SF, 2000
#   Written marc_2000_ctOC_SOURCE_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctOC_SINK=ctOC_DRY-ctOC_WET-ctOC_ACT-ctOC_SCV, 2000
#   Written marc_2000_ctOC_SINK_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctBC_SF=mBCSF, 2000
#   Written marc_2000_ctBC_SF_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctBC_DRY=mBCDRY+mBIMDRY, 2000
#   Written marc_2000_ctBC_DRY_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctBC_WET=cmBCWET+cmBIMWET, 2000
#   Written marc_2000_ctBC_WET_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctBC_ACT=cmBCACT+cmBIMACT, 2000
#   Written marc_2000_ctBC_ACT_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctBC_SCV=cmBCSCV+cmBIMSCV, 2000
#   Written marc_2000_ctBC_SCV_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctBC_SOURCE=ctBC_SF, 2000
#   Written marc_2000_ctBC_SOURCE_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctBC_SINK=ctBC_DRY-ctBC_WET-ctBC_ACT-ctBC_SCV, 2000
#   Written marc_2000_ctBC_SINK_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctDST_SF=DST01SF+DST02SF+DST03SF+DST04SF, 2000
#   Written marc_2000_ctDST_SF_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctDST_DRY=DST01DD+DST02DD+DST03DD+DST04DD, 2000
#   Written marc_2000_ctDST_DRY_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctDST_WET=cDST01PP+cDST02PP+cDST03PP+cDST04PP, 2000
#   Written marc_2000_ctDST_WET_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctDST_SOURCE=ctDST_SF, 2000
#   Written marc_2000_ctDST_SOURCE_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctDST_SINK=ctDST_DRY-ctDST_WET, 2000
#   Written marc_2000_ctDST_SINK_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSSLT_SF=SSLT01SF+SSLT02SF+SSLT03SF+SSLT04SF, 2000
#   Written marc_2000_ctSSLT_SF_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSSLT_DRY=SSLT01DD+SSLT02DD+SSLT03DD+SSLT04DD, 2000
#   Written marc_2000_ctSSLT_DRY_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSSLT_WET=cSSLT01PP+cSSLT02PP+cSSLT03PP+cSSLT04PP, 2000
#   Written marc_2000_ctSSLT_WET_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSSLT_SOURCE=ctSSLT_SF, 2000
#   Written marc_2000_ctSSLT_SOURCE_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSSLT_SINK=ctSSLT_DRY-ctSSLT_WET, 2000
#   Written marc_2000_ctSSLT_SINK_ANN.nc
#   Removing temp_2000_merge_ANN.nc
# ctSUL_DRY=mNUCDRY+mAITDRY+mACCDRY+mMOSDRY+mMBSDRY-mOIMDRY-mBIMDRY, 1850
#   Written marc_1850_ctSUL_DRY_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSUL_WET=cmNUCWET+cmAITWET+cmACCWET+cmMOSWET+cmMBSWET-cmOIMWET-cmBIMWET, 1850
#   Written marc_1850_ctSUL_WET_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSUL_ACT=cmNUCACT+cmAITACT+cmACCACT+cmMOSACT+cmMBSACT-cmOIMACT-cmBIMACT, 1850
#   Written marc_1850_ctSUL_ACT_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSUL_SCV=cmNUCSCV+cmAITSCV+cmACCSCV+cmMOSSCV+cmMBSSCV-cmOIMSCV-cmBIMSCV, 1850
#   Written marc_1850_ctSUL_SCV_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSUL_CND=cCNDmNUC+cCNDmAIT+cCNDmACC+cCNDmMOS+cCNDmMBS, 1850
#   Written marc_1850_ctSUL_CND_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSUL_NUC=cBNUCmNUC, 1850
#   Written marc_1850_ctSUL_NUC_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSUL_EVAP=cmSO4evap, 1850
#   Written marc_1850_ctSUL_EVAP_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSUL_AGE=cAGEmMOS+cAGEmMBS, 1850
#   Written marc_1850_ctSUL_AGE_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSUL_SOURCE=ctSUL_CND+ctSUL_NUC+ctSUL_EVAP+ctSUL_AGE, 1850
#   Written marc_1850_ctSUL_SOURCE_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSUL_SINK=ctSUL_DRY-ctSUL_WET-ctSUL_ACT-ctSUL_SCV, 1850
#   Written marc_1850_ctSUL_SINK_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctOC_SF=mOCSF, 1850
#   Written marc_1850_ctOC_SF_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctOC_DRY=mOCDRY+mOIMDRY, 1850
#   Written marc_1850_ctOC_DRY_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctOC_WET=cmOCWET+cmOIMWET, 1850
#   Written marc_1850_ctOC_WET_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctOC_ACT=cmOCACT+cmOIMACT, 1850
#   Written marc_1850_ctOC_ACT_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctOC_SCV=cmOCSCV+cmOIMSCV, 1850
#   Written marc_1850_ctOC_SCV_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctOC_SOURCE=ctOC_SF, 1850
#   Written marc_1850_ctOC_SOURCE_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctOC_SINK=ctOC_DRY-ctOC_WET-ctOC_ACT-ctOC_SCV, 1850
#   Written marc_1850_ctOC_SINK_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctBC_SF=mBCSF, 1850
#   Written marc_1850_ctBC_SF_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctBC_DRY=mBCDRY+mBIMDRY, 1850
#   Written marc_1850_ctBC_DRY_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctBC_WET=cmBCWET+cmBIMWET, 1850
#   Written marc_1850_ctBC_WET_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctBC_ACT=cmBCACT+cmBIMACT, 1850
#   Written marc_1850_ctBC_ACT_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctBC_SCV=cmBCSCV+cmBIMSCV, 1850
#   Written marc_1850_ctBC_SCV_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctBC_SOURCE=ctBC_SF, 1850
#   Written marc_1850_ctBC_SOURCE_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctBC_SINK=ctBC_DRY-ctBC_WET-ctBC_ACT-ctBC_SCV, 1850
#   Written marc_1850_ctBC_SINK_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctDST_SF=DST01SF+DST02SF+DST03SF+DST04SF, 1850
#   Written marc_1850_ctDST_SF_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctDST_DRY=DST01DD+DST02DD+DST03DD+DST04DD, 1850
#   Written marc_1850_ctDST_DRY_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctDST_WET=cDST01PP+cDST02PP+cDST03PP+cDST04PP, 1850
#   Written marc_1850_ctDST_WET_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctDST_SOURCE=ctDST_SF, 1850
#   Written marc_1850_ctDST_SOURCE_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctDST_SINK=ctDST_DRY-ctDST_WET, 1850
#   Written marc_1850_ctDST_SINK_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSSLT_SF=SSLT01SF+SSLT02SF+SSLT03SF+SSLT04SF, 1850
#   Written marc_1850_ctSSLT_SF_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSSLT_DRY=SSLT01DD+SSLT02DD+SSLT03DD+SSLT04DD, 1850
#   Written marc_1850_ctSSLT_DRY_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSSLT_WET=cSSLT01PP+cSSLT02PP+cSSLT03PP+cSSLT04PP, 1850
#   Written marc_1850_ctSSLT_WET_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSSLT_SOURCE=ctSSLT_SF, 1850
#   Written marc_1850_ctSSLT_SOURCE_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# ctSSLT_SINK=ctSSLT_DRY-ctSSLT_WET, 1850
#   Written marc_1850_ctSSLT_SINK_ANN.nc
#   Removing temp_1850_merge_ANN.nc
# Thu Jun 14 14:12:44 +08 2018
